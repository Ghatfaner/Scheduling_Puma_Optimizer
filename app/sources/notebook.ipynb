# %% [markdown]
# # **Experiments #3 - POA with Randomize Initialization Repsentative Solution then Optimized**
#
# ### **The knowledges we look for:**
# - Prove which timetable process is sequentially better
#     - Teachers -> rooms -> timeslots
#     - Rooms -> teachers -> timeslots
#     - Timeslots -> rooms -> teachers
# - Prove that timetable process based on Teacher in their own laboratorium expertise is more effective and efficient
# - Prove that there are percentage of teachers that does not teach linear with laboratorium expertise
# - Ptove that computational environment has difference impact to generate solution

# %% [markdown]
# # **Data Setup**

# %% [markdown]
# ## *Import Used Library*

# %% [markdown]
# ## *Dataset Understanding*
#
# Showing attributes of courses, teachers, laboratorium, rooms, and timeslots

# %% [markdown]
# ## *Splitting Course Ganjil - Genap*

# %% [markdown]
# ## *Splitting Selected Courses by Theory and Practicum*

# %% [markdown]
# ## *Generated Course Time based on SKS*

# %% [markdown]
# ## *Splitting Teachers based on Courses Coordinator or Not*

# %% [markdown]
# ## *Splitting Rooms with Practicum and Theory*

# %% [markdown]
# ## *Generated Timeslots per Rooms*
#
# - Has 13 slots per day @slot 50 mins

# %% [markdown]
# # **Experiments Setup**

# %% [markdown]
# ## *Generated Courses with Assigned Rooms and Timeslots*
#
# - `course with <=3 sks` only assigned with 100 mins of time (cost 2 slots)
# - `course with >=4 sks` assigned with 150 mins of time (cost 3 slots)

# %% [markdown]
# ## *Generated Teachers with Assigned Courses based on Laboratorium*
#
# - List of {teachers, list of assigned courses, working minutes(hour) a week}

# %% [markdown]
# ## *Objective (Fitness) Function - Setup*
#
# - `Hard Constraints`
#     - Two or more Course can not be assigned into the same room at the same time
#     - Teacher can not be assigned in two or more different rooms/courses at the same time
#     - Teacher can not be assigned in a courses that was not their laboratorium expertise
#     - Teacher can not has more than 2400 mins (40 hours) a week of teaching
#
# <br>
#
# - `Soft Constraints`
#     - Teacher movements between sequence of courses they teach
#     - Teacher chosing priority of courses - `from 1 (highest) to 2(lower)`

# %% [markdown]
# ## *Puma Optimizer Algorithm - Setup*

# %% [markdown]
# ## *Run the POA Algorithm*
