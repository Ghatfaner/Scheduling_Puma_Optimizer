# %% [markdown]
# ### Import library

# %%
import pandas as pd
import numpy as np
import random
import datetime
from collections import defaultdict
import copy
import matplotlib.pyplot as plt
import mlflow
import os

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ### Dataset Course, Rooms, Slots - Setup

# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import mlflow

def configure_courses(csv_path):
    df_courses = pd.read_csv(csv_path)
    df_courses['event_id'] = [f"EVT_{i:04d}" for i in range(len(df_courses))]
    df_courses['requires_practicum_room'] = df_courses['course_name'].str.contains('Praktikum', case=False, na=False)
    df_courses['slots_needed'] = df_courses['course_time_minute'] // 50
    
    cols_order = ['event_id', 'course_id', 'course_name', 'requires_practicum_room', 
                  'slots_needed', 'teacher_id', 'teacher_priority']
    available_cols = [c for c in cols_order if c in df_courses.columns]
    return df_courses[available_cols]

def configure_rooms_and_timeslots(rooms_csv_path):
    df_rooms = pd.read_csv(rooms_csv_path)
    
    theory_rooms = {'F2.1', 'F2.2', 'F2.4', 'F2.5', 'F2.6', 'F2.8', 'F2.9', 'F3.1', 'F3.10',
                    'F3.11', 'F3.12', 'F3.13', 'F3.14', 'F3.15', 'F3.16', 'F3.17', 'F3.18',
                    'F3.2', 'F3.3', 'F3.4', 'F3.5a', 'F3.5b', 'F3.6', 'F3.7a', 'F3.7b',
                    'F3.8', 'F3.9', 'F4.10', 'F4.11', 'F4.12', 'F4.13', 'F4.14', 'F4.2',
                    'F4.3', 'F4.4', 'F4.5', 'F4.6', 'F4.7', 'F4.9'}
    
    practicum_rooms = {'G1.2', 'G1.3', 'G1.4', 'G1.5', 'G1.6', 
                       'F2.1', 'F2.2', 'F2.4', 'F2.5', 'F2.6', 'F2.8', 'F2.9'}
    
    df_rooms['is_theory'] = df_rooms['room_id'].isin(theory_rooms)
    df_rooms['is_practicum'] = df_rooms['room_id'].isin(practicum_rooms)

    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
    granularity_minutes = 50
    all_timeslots = []
    slot_id_counter = 0
    
    for day in days:
        sessions = [
            {'type': 'Morning', 'start': "07:00", 'end': "12:00"},
            {'type': 'Afternoon', 'start': "12:30", 'end': "18:20"}
        ]
        for session in sessions:
            curr_time = datetime.strptime(session['start'], "%H:%M")
            end_time = datetime.strptime(session['end'], "%H:%M")
            while curr_time < end_time:
                all_timeslots.append({
                    'slot_id': f"T_{slot_id_counter:04d}",
                    'day': day,
                    'session_type': session['type'],
                    'time_start': curr_time.strftime("%H:%M"),
                    'time_end': (curr_time + timedelta(minutes=granularity_minutes)).strftime("%H:%M")
                })
                curr_time += timedelta(minutes=granularity_minutes)
                slot_id_counter += 1
                
    return df_rooms, pd.DataFrame(all_timeslots)

# Eksekusi Pembuatan Data
df_courses = configure_courses('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/data/mk_dsi_ganjil_praktikum_v1.csv')
df_rooms, df_timeslots = configure_rooms_and_timeslots('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/data/rooms.csv')
print(f"Dataset Aktif -> Courses: {len(df_courses)} | Rooms: {len(df_rooms)} | Timeslots: {len(df_timeslots)}")

df_courses.to_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_ganjil_praktikum_processed_v1.csv', index=False)
df_rooms.to_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv', index=False)
df_timeslots.to_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv', index=False)
# Out:
# Dataset Aktif -> Courses: 474 | Rooms: 44 | Timeslots: 65

# %% [markdown]
# ### Optimized POA from Claude

# %%
import numpy as np
import pandas as pd
import time
from concurrent.futures import ProcessPoolExecutor, as_completed
import os

# ==========================================
# 1. Deklarasi & Persiapan Dataset
# ==========================================
print("[INFO] Memuat dan memproses dataset...")
mk_df_raw = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_genap_praktikum_processed.csv')
rooms_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv')
timeslots_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv')

# ── Pre-compute valid consecutive timeslot pairs ──────────────────────────────
valid_starts = [
    i for i in range(len(timeslots_df) - 1)
    if (timeslots_df.iloc[i]['day'] == timeslots_df.iloc[i+1]['day'] and
        timeslots_df.iloc[i]['time_end'] == timeslots_df.iloc[i+1]['time_start'])
]

rooms_prac = rooms_df[rooms_df['is_practicum'] == True].index.tolist()
rooms_theo = rooms_df[rooms_df['is_theory'] == True].index.tolist()

# ── Teacher workload heuristic ────────────────────────────────────────────────
teacher_workload = mk_df_raw['teacher_id'].value_counts().to_dict()
mk_df_raw['teacher_degree'] = mk_df_raw['teacher_id'].map(teacher_workload)

# ── Pre-build candidate slot lists PER room type (computed ONCE globally) ─────
# Shape: list of (room_idx, start_timeslot_idx)
PRAC_SLOTS = [(r, s) for r in rooms_prac for s in valid_starts]
THEO_SLOTS = [(r, s) for r in rooms_theo for s in valid_starts]

# Pre-extract arrays for O(1) column access inside hot loop
_REQ_PRAC   = mk_df_raw['requires_practicum_room'].to_numpy()
_TEACHER    = mk_df_raw['teacher_id'].to_numpy()
_T_PRIORITY = mk_df_raw['teacher_priority'].to_numpy()
_T_DEGREE   = mk_df_raw['teacher_degree'].to_numpy()
_TS_DAY     = timeslots_df['day'].to_numpy()
_TS_SESSION = timeslots_df['session_type'].to_numpy()
_N_COURSES  = len(mk_df_raw)

# ── Cache session-type arrays for SC penalty (avoids repeated iloc) ───────────
SESSION_MORNING   = (_TS_SESSION == 'Morning')
SESSION_AFTERNOON = (_TS_SESSION == 'Afternoon')

# ==========================================
# 2. Optimized Fitness Function
# ==========================================
def fitness_function(sol_x):
    """
    Optimizations vs v1:
    - Pre-extracted numpy arrays for column access (no pandas iloc in hot loop)
    - Available-slot SETS updated incrementally (no scan of all R×S per course)
    - Early SC break: skip remaining slot checks once penalty=0 found
    - Vectorized priority sorting with numpy argsort
    """
    hc_value = 0
    sc_value = 0
    hc_count = 0
    sc_count = 0
    assignments = []

    # ── Available-slot sets (copied per call, updated as slots are booked) ────
    avail_prac = set(range(len(PRAC_SLOTS)))
    avail_theo = set(range(len(THEO_SLOTS)))

    # Fast lookup: (room, ts_idx) → booked?
    room_time_booked  = set()
    teacher_time_booked = set()
    teacher_day_rooms = {}   # teacher → {day → [rooms]}

    # ── Decode priority: base heuristic + PO random key ───────────────────────
    base_scores = (_REQ_PRAC.astype(float) * 1000) + (_T_DEGREE * 10)
    priorities  = base_scores + (sol_x * 100)
    queue_order = np.argsort(-priorities)   # descending, no Python sort()

    for idx in queue_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])

        slot_list  = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set  = avail_prac  if req_prac else avail_theo

        best_choice    = None
        best_sc_penalty = float('inf')

        # ── Greedy: scan only available (non-booked) slots ───────────────────
        # Iterate over a snapshot of available indices
        for si in list(avail_set):
            r, start_idx = slot_list[si]
            t1, t2 = start_idx, start_idx + 1

            # Hard constraint check  (O(1) set lookup)
            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                continue
            if (teacher, t1) in teacher_time_booked or (teacher, t2) in teacher_time_booked:
                continue

            # Soft constraint evaluation
            day   = _TS_DAY[start_idx]
            temp_sc = 0

            if t_priority == 1:
                if not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
                    temp_sc += 10
            elif t_priority == 2:
                if not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
                    temp_sc += 10

            if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
                if r not in teacher_day_rooms[teacher][day]:
                    temp_sc += 50

            if temp_sc < best_sc_penalty:
                best_sc_penalty = temp_sc
                best_choice     = (r, start_idx, day, t1, t2, si)
                if temp_sc == 0:
                    break          # Perfect slot found — no need to continue

        # ── Assign or record hard conflict ────────────────────────────────────
        if best_choice is not None:
            r, start_idx, day, t1, t2, si = best_choice

            room_time_booked.add((r, t1));    room_time_booked.add((r, t2))
            teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))

            # Remove booked room-slots from available sets to prune future searches
            # (keep set accurate: remove any slot that now overlaps)
            target_set = avail_prac if req_prac else avail_theo
            target_list = PRAC_SLOTS if req_prac else THEO_SLOTS
            for si2 in list(target_set):
                r2, s2 = target_list[si2]
                if r2 == r and (s2 == t1 or s2 == t2 or s2 + 1 == t1):
                    target_set.discard(si2)

            sc_value += best_sc_penalty
            assignments.append({
                'course_i': int(idx), 'room': r,
                'start_slot': start_idx, 'end_slot': t2,
                'teacher': teacher, 'priority': t_priority, 'day': day
            })

            if teacher not in teacher_day_rooms:
                teacher_day_rooms[teacher] = {}
            if day not in teacher_day_rooms[teacher]:
                teacher_day_rooms[teacher][day] = []
            teacher_day_rooms[teacher][day].append(r)

        else:
            hc_count += 1
            hc_value += 100_000

    # ── Re-evaluate room-switching SC ─────────────────────────────────────────
    for teacher, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    total_penalty = hc_value + sc_value
    metrics = {
        'hc_count': hc_count, 'hc_value': hc_value,
        'sc_count': sc_count, 'sc_value': sc_value
    }
    return total_penalty, assignments, metrics


# ── Wrapper for parallel worker (top-level so it's picklable) ─────────────────
def _eval_worker(x):
    return fitness_function(x)


# ==========================================
# 3. Solution Class
# ==========================================
class Solution:
    __slots__ = ('X', 'Cost', 'assignments', 'metrics')

    def __init__(self, x, cost, assignments=None, metrics=None):
        self.X           = x
        self.Cost        = cost
        self.assignments = assignments
        self.metrics     = metrics

    def clone(self):
        return Solution(self.X.copy(), self.Cost, self.assignments, self.metrics)


# ==========================================
# 4. Parallel Population Evaluator
# ==========================================
def parallel_eval(vectors, n_workers=None):
    """Evaluate a list of numpy vectors in parallel. Falls back to serial if n_workers=1."""
    n_workers = n_workers or min(os.cpu_count(), len(vectors))
    if n_workers <= 1 or len(vectors) <= 4:
        return [fitness_function(v) for v in vectors]

    results = [None] * len(vectors)
    with ProcessPoolExecutor(max_workers=n_workers) as pool:
        futures = {pool.submit(_eval_worker, v): i for i, v in enumerate(vectors)}
        for fut in as_completed(futures):
            results[futures[fut]] = fut.result()
    return results


# ==========================================
# 5. Puma Optimizer – Optimized
# ==========================================
def print_iteration_log(Iter, Sol, Best, elapsed):
    worst_cost = max(s.Cost for s in Sol)
    m = Best.metrics
    print(
        f"Iter {Iter:03d} | Best: {Best.Cost:8.0f} | Worst: {worst_cost:8.0f} | "
        f"HC: {m['hc_count']:3d} ({m['hc_value']:7.0f}) | SC: {m['sc_value']:5.0f} | "
        f"Time: {elapsed:.1f}s"
    )


def exploration(Sol, lb, ub, dim, nSol, n_workers):
    pCR = 0.20
    PCR = 1 - pCR
    p   = PCR / nSol
    Sol.sort(key=lambda s: s.Cost)

    new_vectors = []
    for i in range(nSol):
        x = Sol[i].X
        A = list(range(nSol)); A.remove(i); np.random.shuffle(A)
        a, b, c, d, e, f = A[:6]
        G = 2 * np.random.rand() - 1
        if np.random.rand() < 0.5:
            y = np.random.rand(dim) * (ub - lb) + lb
        else:
            da = Sol[a].X - Sol[b].X
            db = Sol[c].X - Sol[d].X
            dc = Sol[e].X - Sol[f].X
            y  = Sol[a].X + G * da + G * ((da - db) + (db - dc))
        y  = np.clip(y, lb, ub)
        z  = x.copy()
        j0 = np.random.randint(dim)
        mask = (np.random.rand(dim) <= pCR)
        mask[j0] = True
        z[mask] = y[mask]
        new_vectors.append(z)

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
        else:
            pCR = pCR + p
    return Sol


def exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers):
    Q, Beta = 0.67, 2
    mbest = np.mean([s.X for s in Sol], axis=0)

    new_vectors = []
    for i in range(nSol):
        beta1 = 2 * np.random.rand()
        beta2 = np.random.randn(dim)
        w, v  = np.random.randn(dim), np.random.randn(dim)
        F1    = np.random.randn(dim) * np.exp(2 - Iter * (2 / MaxIter))
        F2    = w * (v ** 2) * np.cos(2 * np.random.rand() * w)
        R_1   = 2 * np.random.rand() - 1
        S1    = (2 * np.random.rand() - 1 + np.random.randn(dim))
        S2    = F1 * R_1 * Sol[i].X + F2 * (1 - R_1) * Best.X
        VEC   = S2 / (S1 + 1e-10)

        if np.random.rand() <= 0.5:
            if np.random.rand() > Q:
                r_idx = np.random.randint(nSol)
                x_new = Best.X + beta1 * np.exp(beta2) * (Sol[r_idx].X - Sol[i].X)
            else:
                x_new = beta1 * VEC - Best.X
        else:
            r1   = np.random.randint(nSol)
            sign = (-1) ** np.random.randint(0, 2)
            x_new = (mbest * Sol[r1].X - sign * Sol[i].X) / (1 + Beta * np.random.rand())

        new_vectors.append(np.clip(x_new, lb, ub))

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
    return Sol


def run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), nSol)
    print(f"[INFO] Parallel workers: {n_workers}")

    # ── Initial population ────────────────────────────────────────────────────
    print("Mengevaluasi populasi inisial...")
    init_vectors = [lb + (ub - lb) * np.random.rand(dim) for _ in range(nSol)]

    # Seed one individual with pure-heuristic order (all X=0.5 → rely on base score)
    init_vectors[0] = np.full(dim, 0.5)

    results = parallel_eval(init_vectors, n_workers)
    Sol  = [Solution(init_vectors[i], *results[i]) for i in range(nSol)]
    Best = min(Sol, key=lambda s: s.Cost)
    Initial_Best = Best.clone()

    print(f"\nInitial Best Fitness: {Best.Cost:.0f} | "
          f"HC: {Best.metrics['hc_count']} | SC: {Best.metrics['sc_value']:.0f}")

    # ── Early exit if already zero conflicts ──────────────────────────────────
    if Best.metrics['hc_count'] == 0:
        print("[INFO] Zero HC violations in initial population — skipping optimization!")
        return Best

    UnSelected = [1, 1]
    F3_Explore = F3_Exploit = 0
    Seq_Time_Explore  = [1, 1, 1]; Seq_Time_Exploit  = [1, 1, 1]
    Seq_Cost_Explore  = [1, 1, 1]; Seq_Cost_Exploit  = [1, 1, 1]
    PF     = [0.5, 0.5, 0.3]
    PF_F3  = []
    Mega_Explor = Mega_Exploit = 0.99
    Costs_Explor  = np.zeros(3)
    Costs_Exploit = np.zeros(3)
    Flag_Change   = 1

    print("\n" + "=" * 95)
    print("MEMULAI PROSES OPTIMASI PUMA (v2)".center(95))
    print("=" * 95)

    t_start = time.perf_counter()

    # ── Bootstrap: first 3 iterations (both explore + exploit to seed PF) ────
    for Iter in range(1, 4):
        t0 = time.perf_counter()
        Sol_E1 = exploration ([s.clone() for s in Sol], lb, ub, dim, nSol, n_workers)
        Sol_E2 = exploitation([s.clone() for s in Sol], lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
        Costs_Explor[Iter-1]  = min(s.Cost for s in Sol_E1)
        Costs_Exploit[Iter-1] = min(s.Cost for s in Sol_E2)

        # Keep top nSol across all candidates
        merged = Sol + Sol_E1 + Sol_E2
        merged.sort(key=lambda s: s.Cost)
        Sol  = merged[:nSol]
        Best = Sol[0]
        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start)

        # ── Early exit ────────────────────────────────────────────────────────
        if Best.metrics['hc_count'] == 0:
            print("[INFO] Zero HC achieved — stopping early.")
            return Best

    Seq_Cost_Explore[0] = abs(Initial_Best.Cost - Costs_Explor[0])
    Seq_Cost_Explore[1] = abs(Costs_Explor[1]  - Costs_Explor[0])
    Seq_Cost_Explore[2] = abs(Costs_Explor[2]  - Costs_Explor[1])
    Seq_Cost_Exploit[0] = abs(Initial_Best.Cost - Costs_Exploit[0])
    Seq_Cost_Exploit[1] = abs(Costs_Exploit[1] - Costs_Exploit[0])
    Seq_Cost_Exploit[2] = abs(Costs_Exploit[2] - Costs_Exploit[1])

    for v in Seq_Cost_Explore + Seq_Cost_Exploit:
        if v != 0: PF_F3.append(v)

    # ── Main loop ─────────────────────────────────────────────────────────────
    stagnation = 0
    prev_best  = Best.Cost

    for Iter in range(4, MaxIter + 1):
        F1_Explor  = PF[0] * (Seq_Cost_Explore[0] / Seq_Time_Explore[0])
        F1_Exploit = PF[0] * (Seq_Cost_Exploit[0] / Seq_Time_Exploit[0])
        F2_Explor  = PF[1] * (sum(Seq_Cost_Explore) / sum(Seq_Time_Explore))
        F2_Exploit = PF[1] * (sum(Seq_Cost_Exploit) / sum(Seq_Time_Exploit))
        Score_Explore  = Mega_Explor  * (F1_Explor  + F2_Explor)
        Score_Exploit  = Mega_Exploit * (F1_Exploit + F2_Exploit)

        if Score_Explore > Score_Exploit:
            SelectFlag = 1
            Sol = exploration(Sol, lb, ub, dim, nSol, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[1] += 1; UnSelected[0] = 1
            F3_Explore = PF[2]; F3_Exploit += PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Explore[2], Seq_Cost_Explore[1] = Seq_Cost_Explore[1], Seq_Cost_Explore[0]
            Seq_Cost_Explore[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Explore[0]: PF_F3.append(Seq_Cost_Explore[0])
        else:
            SelectFlag = 2
            Sol = exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[0] += 1; UnSelected[1] = 1
            F3_Explore += PF[2]; F3_Exploit = PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Exploit[2], Seq_Cost_Exploit[1] = Seq_Cost_Exploit[1], Seq_Cost_Exploit[0]
            Seq_Cost_Exploit[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Exploit[0]: PF_F3.append(Seq_Cost_Exploit[0])

        if TBest.Cost < Best.Cost:
            Best = TBest

        if Flag_Change != SelectFlag:
            Flag_Change = SelectFlag
            Seq_Time_Explore[2], Seq_Time_Explore[1], Seq_Time_Explore[0] = \
                Seq_Time_Explore[1], Seq_Time_Explore[0], Count_select[0]
            Seq_Time_Exploit[2], Seq_Time_Exploit[1], Seq_Time_Exploit[0] = \
                Seq_Time_Exploit[1], Seq_Time_Exploit[0], Count_select[1]

        if Score_Explore < Score_Exploit:
            Mega_Explor  = max(Mega_Explor  - 0.01, 0.01); Mega_Exploit = 0.99
        else:
            Mega_Explor  = 0.99; Mega_Exploit = max(Mega_Exploit - 0.01, 0.01)

        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start)

        # ── Early exit on zero HC ─────────────────────────────────────────────
        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC violations achieved at iteration {Iter} — stopping early.")
            break

        # ── Stagnation restart (inject random diversity after 10 flat iters) ──
        if Best.Cost >= prev_best:
            stagnation += 1
        else:
            stagnation = 0
            prev_best  = Best.Cost

        if stagnation >= 10:
            print(f"[WARN] Stagnation detected at iter {Iter} — injecting diversity...")
            n_replace = nSol // 3
            for k in range(1, n_replace + 1):
                x_new = lb + (ub - lb) * np.random.rand(dim)
                c, a, m = fitness_function(x_new)
                Sol[-k] = Solution(x_new, c, a, m)
            stagnation = 0

    total_time = time.perf_counter() - t_start
    print(f"\n[INFO] Optimasi selesai dalam {total_time:.1f}s")
    return Best


# ==========================================
# 6. Eksekusi & Ekspor
# ==========================================
if __name__ == '__main__':
    nSol    = 100
    MaxIter = 100
    dim     = _N_COURSES
    lb, ub  = 0.0, 1.0

    t0 = time.perf_counter()
    best_solution = run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None)
    print(f"\nTotal elapsed: {time.perf_counter() - t0:.1f}s")

    # ── Build result DataFrame ────────────────────────────────────────────────
    res_list = []
    for a in best_solution.assignments:
        course = mk_df_raw.iloc[a['course_i']]
        room   = rooms_df.iloc[a['room']]
        t1     = timeslots_df.iloc[a['start_slot']]
        t2     = timeslots_df.iloc[a['end_slot']]
        res_list.append({
            'event_id':    course['event_id'],
            'course_name': course['course_name'],
            'teacher_id':  course['teacher_id'],
            'room_id':     room['room_id'],
            'day':         t1['day'],
            'time_start':  t1['time_start'],
            'time_end':    t2['time_end'],
        })

    res_df = pd.DataFrame(res_list)
    out_path = 'scheduled_courses_poa_v2.csv'
    res_df.to_csv(out_path, index=False)

    m = best_solution.metrics
    print(f"\n{'='*60}")
    print(f"  FINAL RESULT")
    print(f"  HC Violations : {m['hc_count']}  (penalty: {m['hc_value']})")
    print(f"  SC Violations : {m['sc_count']}  (penalty: {m['sc_value']})")
    print(f"  Total Fitness : {best_solution.Cost}")
    print(f"  Courses scheduled: {len(res_list)} / {_N_COURSES}")
    print(f"{'='*60}")
    print(f"[INFO] Solusi disimpan di '{out_path}'")

# %% [markdown]
# ### POA by Claude with Repaired Mechanism

# %%
import numpy as np
import pandas as pd
import time
from concurrent.futures import ProcessPoolExecutor, as_completed
import os

# ==========================================
# 1. Deklarasi & Persiapan Dataset
# ==========================================
print("[INFO] Memuat dan memproses dataset...")
mk_df_raw = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_genap_praktikum_processed_v1.csv')
rooms_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv')
timeslots_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv')

# ── Pre-compute valid consecutive timeslot pairs ──────────────────────────────
valid_starts = [
    i for i in range(len(timeslots_df) - 1)
    if (timeslots_df.iloc[i]['day'] == timeslots_df.iloc[i + 1]['day'] and
        timeslots_df.iloc[i]['time_end'] == timeslots_df.iloc[i + 1]['time_start'])
]

rooms_prac = rooms_df[rooms_df['is_practicum'] == True].index.tolist()
rooms_theo = rooms_df[rooms_df['is_theory'] == True].index.tolist()

# ── Teacher workload heuristic ────────────────────────────────────────────────
teacher_workload = mk_df_raw['teacher_id'].value_counts().to_dict()
mk_df_raw['teacher_degree'] = mk_df_raw['teacher_id'].map(teacher_workload)

# ── Pre-build global slot lists (computed ONCE) ───────────────────────────────
PRAC_SLOTS = [(r, s) for r in rooms_prac for s in valid_starts]
THEO_SLOTS = [(r, s) for r in rooms_theo for s in valid_starts]

# ── Pre-extracted numpy arrays for O(1) hot-loop access ──────────────────────
_REQ_PRAC   = mk_df_raw['requires_practicum_room'].to_numpy()
_TEACHER    = mk_df_raw['teacher_id'].to_numpy()
_T_PRIORITY = mk_df_raw['teacher_priority'].to_numpy()
_T_DEGREE   = mk_df_raw['teacher_degree'].to_numpy()
_TS_DAY     = timeslots_df['day'].to_numpy()
_TS_SESSION = timeslots_df['session_type'].to_numpy()
_N_COURSES  = len(mk_df_raw)

SESSION_MORNING   = (_TS_SESSION == 'Morning')
SESSION_AFTERNOON = (_TS_SESSION == 'Afternoon')

# ── HC weight: any 1 HC violation > any possible SC total ────────────────────
HC_WEIGHT = 10_000_000


# ==========================================
# 2. Fitness Function with Conflict-Directed Repair
# ==========================================
def fitness_function(sol_x):
    """
    Three-phase decoder:

    PHASE 1 — Greedy HC-aware assignment
        Courses ordered by Most-Constrained-First + PO random key.
        For each course, find the best HC-free slot (with bounded SC scan).
        Unassigned courses are collected for repair rather than immediately
        counted as violations.

    PHASE 2 — Conflict-Directed Repair
        For each unassigned course (no HC-free slot found in Phase 1):
          1. Scan ALL slots of the correct room type.
          2. For each slot blocked only by a TEACHER conflict (room is free):
             - Identify the "blocker" assignment occupying that teacher-timeslot.
             - Try to relocate the blocker to any other HC-free slot.
             - If relocation succeeds → free the slot, assign the waiting course.
          3. Try up to _MAX_REPAIR_ATTEMPTS relocations per unassigned course.
        This directly resolves the root cause: courses stuck because a
        previously placed course holds the only viable teacher-timeslot.

    PHASE 3 — SC Re-evaluation
        Full SC recalculation after all assignments (including repairs) are final.

    FITNESS = hc_count × HC_WEIGHT + sc_value
    """
    hc_count = 0
    sc_value = 0
    sc_count = 0
    assignments     = []    # list of assigned course dicts
    unassigned_idxs = []    # course indices that Phase 1 could not place

    # Per-call booking state
    room_time_booked      = set()   # (room_idx, ts_idx)
    teacher_time_booked   = set()   # (teacher_id, ts_idx)
    teacher_day_rooms     = {}      # teacher → {day → [room, ...]}

    # Reverse index: (teacher_id, ts_idx) → assignment list index
    # Used in Phase 2 to quickly find which assignment blocks a slot
    teacher_ts_to_asgn = {}         # (teacher, ts_idx) → index in `assignments`

    # Available-slot sets (pruned as rooms get booked)
    avail_prac = set(range(len(PRAC_SLOTS)))
    avail_theo = set(range(len(THEO_SLOTS)))

    # ── MCF + PO random-key ordering ─────────────────────────────────────────
    base_scores = (_REQ_PRAC.astype(float) * 1000) + (_T_DEGREE * 10)
    priorities  = base_scores + (sol_x * 100)
    queue_order = np.argsort(-priorities)

    # =========================================================================
    # PHASE 1 — GREEDY ASSIGNMENT
    # =========================================================================
    for idx in queue_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set = avail_prac  if req_prac else avail_theo

        hc_fallback    = None      # first HC-free slot (guaranteed commit)
        best_sc        = float('inf')
        best_slot_info = None
        sc_scan_count  = 0

        for si in list(avail_set):
            r, s = slot_list[si]
            t1, t2 = s, s + 1

            # Teacher conflict check (room already filtered by avail_set)
            if (teacher, t1) in teacher_time_booked or (teacher, t2) in teacher_time_booked:
                continue

            # First HC-free slot → save as fallback
            if hc_fallback is None:
                hc_fallback = (r, s, _TS_DAY[s], t1, t2, si)

            # Bounded SC evaluation
            day    = _TS_DAY[s]
            temp_sc = 0
            if t_priority == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
                temp_sc += 10
            elif t_priority == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
                temp_sc += 10
            if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
                if r not in teacher_day_rooms[teacher][day]:
                    temp_sc += 50

            if temp_sc < best_sc:
                best_sc        = temp_sc
                best_slot_info = (r, s, day, t1, t2, si)
                if temp_sc == 0:
                    break
            sc_scan_count += 1
            if sc_scan_count >= 50:
                break

        chosen = best_slot_info if best_slot_info is not None else hc_fallback

        if chosen is not None:
            r, s, day, t1, t2, si = chosen
            _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                       assignments, room_time_booked, teacher_time_booked,
                       teacher_day_rooms, teacher_ts_to_asgn,
                       avail_prac, avail_theo)
        else:
            # No HC-free slot — queue for repair
            unassigned_idxs.append(int(idx))

    # =========================================================================
    # PHASE 2 — CONFLICT-DIRECTED REPAIR
    # Attempt to place every unassigned course by relocating its blocker.
    # =========================================================================
    still_unassigned = []

    for idx in unassigned_idxs:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set = avail_prac  if req_prac else avail_theo

        placed = False

        # Scan ALL slots of the correct room type (not just avail_set —
        # we need to inspect booked slots to find swappable blockers)
        for r, s in slot_list:
            t1, t2 = s, s + 1

            # Room must be free (we can only swap teacher conflicts, not room conflicts)
            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                continue

            # Check which timeslot the teacher is blocked on
            blocked_t1 = (teacher, t1) in teacher_time_booked
            blocked_t2 = (teacher, t2) in teacher_time_booked

            if not blocked_t1 and not blocked_t2:
                # Slot is actually free — assign directly (safety net)
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn,
                           avail_prac, avail_theo)
                placed = True
                break

            # Identify the blocker assignment(s) for this teacher at t1 or t2
            blocker_key = (teacher, t1) if blocked_t1 else (teacher, t2)
            blocker_asgn_idx = teacher_ts_to_asgn.get(blocker_key)
            if blocker_asgn_idx is None:
                continue

            blocker = assignments[blocker_asgn_idx]
            b_idx       = blocker['course_i']
            b_req_prac  = bool(_REQ_PRAC[b_idx])
            b_teacher   = blocker['teacher']
            b_t1_old    = blocker['start_slot']
            b_t2_old    = blocker['end_slot']
            b_r_old     = blocker['room']
            b_priority  = blocker['priority']

            # Temporarily unbook the blocker
            room_time_booked.discard((b_r_old, b_t1_old))
            room_time_booked.discard((b_r_old, b_t2_old))
            teacher_time_booked.discard((b_teacher, b_t1_old))
            teacher_time_booked.discard((b_teacher, b_t2_old))
            teacher_ts_to_asgn.pop((b_teacher, b_t1_old), None)
            teacher_ts_to_asgn.pop((b_teacher, b_t2_old), None)

            # Also remove from teacher_day_rooms
            b_day_old = blocker['day']
            if b_teacher in teacher_day_rooms and b_day_old in teacher_day_rooms[b_teacher]:
                try:
                    teacher_day_rooms[b_teacher][b_day_old].remove(b_r_old)
                except ValueError:
                    pass
                if not teacher_day_rooms[b_teacher][b_day_old]:
                    del teacher_day_rooms[b_teacher][b_day_old]

            # Re-add blocker's old room-slot to avail sets so it can be rescanned
            b_slot_list = PRAC_SLOTS if b_req_prac else THEO_SLOTS
            b_avail_set = avail_prac  if b_req_prac else avail_theo
            try:
                b_si = b_slot_list.index((b_r_old, b_t1_old))
                b_avail_set.add(b_si)
            except ValueError:
                pass

            # Try to find a new slot for the blocker
            reloc_found = None
            b_avail     = avail_prac if b_req_prac else avail_theo
            b_slots     = PRAC_SLOTS if b_req_prac else THEO_SLOTS
            for si2 in list(b_avail):
                r2, s2 = b_slots[si2]
                t1n, t2n = s2, s2 + 1
                if (r2, t1n) in room_time_booked or (r2, t2n) in room_time_booked:
                    continue
                if (b_teacher, t1n) in teacher_time_booked or (b_teacher, t2n) in teacher_time_booked:
                    continue
                # Valid relocation slot found
                reloc_found = (r2, s2, _TS_DAY[s2], t1n, t2n, si2)
                break

            if reloc_found is not None:
                # Commit blocker to its new slot
                r2, s2, day2, t1n, t2n, si2 = reloc_found
                _do_assign(b_idx, r2, s2, day2, t1n, t2n, b_priority, b_teacher,
                           b_req_prac, assignments, room_time_booked,
                           teacher_time_booked, teacher_day_rooms,
                           teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=blocker_asgn_idx)

                # Now assign the waiting course to the freed slot
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn,
                           avail_prac, avail_theo)
                placed = True
                break
            else:
                # Relocation failed — restore the blocker to its original slot
                room_time_booked.add((b_r_old, b_t1_old))
                room_time_booked.add((b_r_old, b_t2_old))
                teacher_time_booked.add((b_teacher, b_t1_old))
                teacher_time_booked.add((b_teacher, b_t2_old))
                teacher_ts_to_asgn[(b_teacher, b_t1_old)] = blocker_asgn_idx
                teacher_ts_to_asgn[(b_teacher, b_t2_old)] = blocker_asgn_idx
                if b_teacher not in teacher_day_rooms:
                    teacher_day_rooms[b_teacher] = {}
                if b_day_old not in teacher_day_rooms[b_teacher]:
                    teacher_day_rooms[b_teacher][b_day_old] = []
                teacher_day_rooms[b_teacher][b_day_old].append(b_r_old)
                # Remove the slot we temporarily re-added
                b_avail_set.discard(b_si if 'b_si' in dir() else -1)

        if not placed:
            still_unassigned.append(idx)

    hc_count = len(still_unassigned)

    # =========================================================================
    # PHASE 3 — SC TOTAL EVALUATION
    # =========================================================================
    for asgn in assignments:
        t1 = asgn['start_slot']
        t2 = asgn['end_slot']
        tp = asgn['priority']
        if tp == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
            sc_value += 10
        elif tp == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
            sc_value += 10

    for teacher_id, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    fitness = hc_count * HC_WEIGHT + sc_value
    metrics = {
        'hc_count': hc_count,
        'hc_value': hc_count * HC_WEIGHT,
        'sc_count': sc_count,
        'sc_value': sc_value,
        'repaired': len(unassigned_idxs) - hc_count,   # how many Phase 2 fixed
    }
    return fitness, assignments, metrics


# ==========================================
# 3. Assignment Helper (DRY – used by both phases)
# ==========================================
def _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
               assignments, room_time_booked, teacher_time_booked,
               teacher_day_rooms, teacher_ts_to_asgn,
               avail_prac, avail_theo, update_idx=None):
    """Book a slot and record the assignment.
    If update_idx is given, update an existing assignment in-place (for repair swaps).
    """
    room_time_booked.add((r, t1));      room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))

    # Prune available sets for this room
    slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
    avail_set = avail_prac  if req_prac else avail_theo
    for si2 in list(avail_set):
        r2, s2 = slot_list[si2]
        if r2 == r and (s2 == t1 or s2 == t2 or s2 + 1 == t1):
            avail_set.discard(si2)

    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)

    asgn = {
        'course_i': int(idx), 'room': r,
        'start_slot': s, 'end_slot': t2,
        'teacher': teacher, 'priority': t_priority, 'day': day
    }

    if update_idx is not None:
        assignments[update_idx] = asgn
        teacher_ts_to_asgn[(teacher, t1)] = update_idx
        teacher_ts_to_asgn[(teacher, t2)] = update_idx
    else:
        new_idx = len(assignments)
        assignments.append(asgn)
        teacher_ts_to_asgn[(teacher, t1)] = new_idx
        teacher_ts_to_asgn[(teacher, t2)] = new_idx


# ── Parallel worker wrapper ────────────────────────────────────────────────────
def _eval_worker(x):
    return fitness_function(x)


# ==========================================
# 4. Solution Class
# ==========================================
class Solution:
    __slots__ = ('X', 'Cost', 'assignments', 'metrics')

    def __init__(self, x, cost, assignments=None, metrics=None):
        self.X           = x
        self.Cost        = cost
        self.assignments = assignments
        self.metrics     = metrics

    def clone(self):
        return Solution(self.X.copy(), self.Cost, self.assignments, self.metrics)


# ==========================================
# 5. Parallel Population Evaluator
# ==========================================
def parallel_eval(vectors, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), len(vectors))
    if n_workers <= 1 or len(vectors) <= 4:
        return [fitness_function(v) for v in vectors]
    results = [None] * len(vectors)
    with ProcessPoolExecutor(max_workers=n_workers) as pool:
        futures = {pool.submit(_eval_worker, v): i for i, v in enumerate(vectors)}
        for fut in as_completed(futures):
            results[futures[fut]] = fut.result()
    return results


# ==========================================
# 6. Puma Optimizer — MECHANISM UNCHANGED
# ==========================================
def print_iteration_log(Iter, Sol, Best, elapsed):
    worst_cost = max(s.Cost for s in Sol)
    m = Best.metrics
    repaired = m.get('repaired', 0)
    print(
        f"Iter {Iter:03d} | Best: {Best.Cost:12.0f} | Worst: {worst_cost:12.0f} | "
        f"HC: {m['hc_count']:3d} | Repaired: {repaired:3d} | "
        f"SC: {m['sc_value']:6.0f} | {elapsed:.1f}s"
    )


def exploration(Sol, lb, ub, dim, nSol, n_workers):
    pCR = 0.20
    PCR = 1 - pCR
    p   = PCR / nSol
    Sol.sort(key=lambda s: s.Cost)

    new_vectors = []
    for i in range(nSol):
        x = Sol[i].X
        A = list(range(nSol)); A.remove(i); np.random.shuffle(A)
        a, b, c, d, e, f = A[:6]
        G = 2 * np.random.rand() - 1
        if np.random.rand() < 0.5:
            y = np.random.rand(dim) * (ub - lb) + lb
        else:
            da = Sol[a].X - Sol[b].X
            db = Sol[c].X - Sol[d].X
            dc = Sol[e].X - Sol[f].X
            y  = Sol[a].X + G * da + G * ((da - db) + (db - dc))
        y  = np.clip(y, lb, ub)
        z  = x.copy()
        j0 = np.random.randint(dim)
        mask = (np.random.rand(dim) <= pCR)
        mask[j0] = True
        z[mask] = y[mask]
        new_vectors.append(z)

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
        else:
            pCR = pCR + p
    return Sol


def exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers):
    Q, Beta = 0.67, 2
    mbest   = np.mean([s.X for s in Sol], axis=0)

    new_vectors = []
    for i in range(nSol):
        beta1 = 2 * np.random.rand()
        beta2 = np.random.randn(dim)
        w, v  = np.random.randn(dim), np.random.randn(dim)
        F1    = np.random.randn(dim) * np.exp(2 - Iter * (2 / MaxIter))
        F2    = w * (v ** 2) * np.cos(2 * np.random.rand() * w)
        R_1   = 2 * np.random.rand() - 1
        S1    = (2 * np.random.rand() - 1 + np.random.randn(dim))
        S2    = F1 * R_1 * Sol[i].X + F2 * (1 - R_1) * Best.X
        VEC   = S2 / (S1 + 1e-10)

        if np.random.rand() <= 0.5:
            if np.random.rand() > Q:
                r_idx = np.random.randint(nSol)
                x_new = Best.X + beta1 * np.exp(beta2) * (Sol[r_idx].X - Sol[i].X)
            else:
                x_new = beta1 * VEC - Best.X
        else:
            r1    = np.random.randint(nSol)
            sign  = (-1) ** np.random.randint(0, 2)
            x_new = (mbest * Sol[r1].X - sign * Sol[i].X) / (1 + Beta * np.random.rand())

        new_vectors.append(np.clip(x_new, lb, ub))

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
    return Sol


def run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), nSol)
    print(f"[INFO] Parallel workers : {n_workers}")
    print(f"[INFO] HC weight        : {HC_WEIGHT:,}")
    print(f"[INFO] Total courses    : {_N_COURSES}")

    # ── Initial population ────────────────────────────────────────────────────
    print("\nMengevaluasi populasi inisial...")
    init_vectors = [lb + (ub - lb) * np.random.rand(dim) for _ in range(nSol)]
    init_vectors[0] = np.full(dim, 0.5)   # Seed: pure MCF order

    results      = parallel_eval(init_vectors, n_workers)
    Sol          = [Solution(init_vectors[i], *results[i]) for i in range(nSol)]
    Best         = min(Sol, key=lambda s: s.Cost)
    Initial_Best = Best.clone()

    m = Best.metrics
    print(f"\nInitial Best  | Fitness: {Best.Cost:12.0f} | "
          f"HC: {m['hc_count']:3d} | Repaired: {m.get('repaired',0):3d} | "
          f"SC: {m['sc_value']:.0f}")

    if Best.metrics['hc_count'] == 0:
        print("[INFO] Zero HC violations at initialisation — skipping optimisation.")
        return Best

    # ── PO state variables (UNCHANGED) ───────────────────────────────────────
    UnSelected = [1, 1]
    F3_Explore = F3_Exploit = 0
    Seq_Time_Explore  = [1, 1, 1];  Seq_Time_Exploit  = [1, 1, 1]
    Seq_Cost_Explore  = [1, 1, 1];  Seq_Cost_Exploit  = [1, 1, 1]
    PF            = [0.5, 0.5, 0.3]
    PF_F3         = []
    Mega_Explor   = Mega_Exploit = 0.99
    Costs_Explor  = np.zeros(3)
    Costs_Exploit = np.zeros(3)
    Flag_Change   = 1

    print("\n" + "=" * 100)
    print("MEMULAI PROSES OPTIMASI PUMA v4 — CONFLICT-DIRECTED REPAIR".center(100))
    print("=" * 100)

    t_start = time.perf_counter()

    # ── Bootstrap iterations 1–3 ──────────────────────────────────────────────
    for Iter in range(1, 4):
        Sol_E1 = exploration ([s.clone() for s in Sol], lb, ub, dim, nSol, n_workers)
        Sol_E2 = exploitation([s.clone() for s in Sol], lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
        Costs_Explor[Iter - 1]  = min(s.Cost for s in Sol_E1)
        Costs_Exploit[Iter - 1] = min(s.Cost for s in Sol_E2)

        merged = Sol + Sol_E1 + Sol_E2
        merged.sort(key=lambda s: s.Cost)
        Sol  = merged[:nSol]
        Best = Sol[0]
        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start)

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC achieved at bootstrap iteration {Iter}.")
            return Best

    Seq_Cost_Explore[0] = abs(Initial_Best.Cost  - Costs_Explor[0])
    Seq_Cost_Explore[1] = abs(Costs_Explor[1]    - Costs_Explor[0])
    Seq_Cost_Explore[2] = abs(Costs_Explor[2]    - Costs_Explor[1])
    Seq_Cost_Exploit[0] = abs(Initial_Best.Cost  - Costs_Exploit[0])
    Seq_Cost_Exploit[1] = abs(Costs_Exploit[1]   - Costs_Exploit[0])
    Seq_Cost_Exploit[2] = abs(Costs_Exploit[2]   - Costs_Exploit[1])

    for v in Seq_Cost_Explore + Seq_Cost_Exploit:
        if v != 0:
            PF_F3.append(v)

    # ── Main loop (PO mechanism UNCHANGED) ───────────────────────────────────
    stagnation = 0
    prev_best  = Best.Cost

    for Iter in range(4, MaxIter + 1):
        F1_Explor  = PF[0] * (Seq_Cost_Explore[0] / Seq_Time_Explore[0])
        F1_Exploit = PF[0] * (Seq_Cost_Exploit[0] / Seq_Time_Exploit[0])
        F2_Explor  = PF[1] * (sum(Seq_Cost_Explore) / sum(Seq_Time_Explore))
        F2_Exploit = PF[1] * (sum(Seq_Cost_Exploit) / sum(Seq_Time_Exploit))
        Score_Explore  = Mega_Explor  * (F1_Explor  + F2_Explor)
        Score_Exploit  = Mega_Exploit * (F1_Exploit + F2_Exploit)

        if Score_Explore > Score_Exploit:
            SelectFlag = 1
            Sol = exploration(Sol, lb, ub, dim, nSol, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[1] += 1;  UnSelected[0] = 1
            F3_Explore = PF[2];  F3_Exploit += PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Explore[2], Seq_Cost_Explore[1] = Seq_Cost_Explore[1], Seq_Cost_Explore[0]
            Seq_Cost_Explore[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Explore[0]:
                PF_F3.append(Seq_Cost_Explore[0])
        else:
            SelectFlag = 2
            Sol = exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[0] += 1;  UnSelected[1] = 1
            F3_Explore += PF[2];  F3_Exploit = PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Exploit[2], Seq_Cost_Exploit[1] = Seq_Cost_Exploit[1], Seq_Cost_Exploit[0]
            Seq_Cost_Exploit[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Exploit[0]:
                PF_F3.append(Seq_Cost_Exploit[0])

        if TBest.Cost < Best.Cost:
            Best = TBest

        if Flag_Change != SelectFlag:
            Flag_Change = SelectFlag
            Seq_Time_Explore[2], Seq_Time_Explore[1], Seq_Time_Explore[0] = \
                Seq_Time_Explore[1], Seq_Time_Explore[0], Count_select[0]
            Seq_Time_Exploit[2], Seq_Time_Exploit[1], Seq_Time_Exploit[0] = \
                Seq_Time_Exploit[1], Seq_Time_Exploit[0], Count_select[1]

        if Score_Explore < Score_Exploit:
            Mega_Explor  = max(Mega_Explor  - 0.01, 0.01)
            Mega_Exploit = 0.99
        else:
            Mega_Explor  = 0.99
            Mega_Exploit = max(Mega_Exploit - 0.01, 0.01)

        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start)

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC violations achieved at iteration {Iter}.")
            break

        # ── Stagnation recovery ───────────────────────────────────────────────
        if Best.Cost >= prev_best:
            stagnation += 1
        else:
            stagnation = 0
            prev_best  = Best.Cost

        if stagnation >= 10:
            print(f"[WARN] Stagnation at iter {Iter} — injecting diversity...")
            n_replace = nSol // 3
            new_vecs  = [lb + (ub - lb) * np.random.rand(dim) for _ in range(n_replace)]
            res       = parallel_eval(new_vecs, n_workers)
            for k, (c, a, met) in enumerate(res):
                Sol[-(k + 1)] = Solution(new_vecs[k], c, a, met)
            stagnation = 0

    print(f"\n[INFO] Optimasi selesai dalam {time.perf_counter() - t_start:.1f}s")
    return Best


# ==========================================
# 7. Eksekusi & Ekspor
# ==========================================
if __name__ == '__main__':
    nSol    = 50
    MaxIter = 100
    dim     = _N_COURSES
    lb, ub  = 0.0, 1.0

    t0 = time.perf_counter()
    best_solution = run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None)
    print(f"Total elapsed: {time.perf_counter() - t0:.1f}s")

    res_list = []
    for a in best_solution.assignments:
        course = mk_df_raw.iloc[a['course_i']]
        room   = rooms_df.iloc[a['room']]
        t1     = timeslots_df.iloc[a['start_slot']]
        t2     = timeslots_df.iloc[a['end_slot']]
        res_list.append({
            'event_id':    course['event_id'],
            'course_name': course['course_name'],
            'teacher_id':  course['teacher_id'],
            'room_id':     room['room_id'],
            'day':         t1['day'],
            'time_start':  t1['time_start'],
            'time_end':    t2['time_end'],
        })

    res_df   = pd.DataFrame(res_list)
    out_path = 'scheduled_courses_poa_v5.2.csv'
    res_df.to_csv(out_path, index=False)

    m = best_solution.metrics
    print(f"\n{'=' * 65}")
    print(f"  FINAL RESULT")
    print(f"  HC Violations  : {m['hc_count']}  (penalty: {m['hc_value']:,})")
    print(f"  Repaired by P2 : {m.get('repaired', 0)}")
    print(f"  SC Violations  : {m['sc_count']}  (penalty: {m['sc_value']})")
    print(f"  Total Fitness  : {best_solution.Cost:,}")
    print(f"  Courses scheduled: {len(res_list)} / {_N_COURSES}")
    print(f"{'=' * 65}")
    print(f"[INFO] Solusi disimpan di '{out_path}'")
# Out:
# [INFO] Memuat dan memproses dataset...
# [INFO] Parallel workers : 8
# [INFO] HC weight        : 10,000,000
# [INFO] Total courses    : 725
#
# Mengevaluasi populasi inisial...
#
# Initial Best  | Fitness:         3080 | HC:   0 | Repaired:  23 | SC: 3080
# [INFO] Zero HC violations at initialisation — skipping optimisation.
# Total elapsed: 1.7s
#
# =================================================================
#   FINAL RESULT
#   HC Violations  : 0  (penalty: 0)
#   Repaired by P2 : 23
#   SC Violations  : 10  (penalty: 3080)
#   Total Fitness  : 3,080
#   Courses scheduled: 725 / 725
# =================================================================
# [INFO] Solusi disimpan di 'scheduled_courses_poa_v5.2.csv'

# %% [markdown]
# ### Repaired Mechanism with Logs

# %%
import numpy as np
import pandas as pd
import time
from concurrent.futures import ProcessPoolExecutor, as_completed
import os

# ==========================================
# 1. Deklarasi & Persiapan Dataset
# ==========================================
print("[INFO] Memuat dan memproses dataset...")
mk_df_raw = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_genap_praktikum_processed.csv')
rooms_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv')
timeslots_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv')

# ── Pre-compute valid consecutive timeslot pairs ──────────────────────────────
valid_starts = [
    i for i in range(len(timeslots_df) - 1)
    if (timeslots_df.iloc[i]['day'] == timeslots_df.iloc[i + 1]['day'] and
        timeslots_df.iloc[i]['time_end'] == timeslots_df.iloc[i + 1]['time_start'])
]

rooms_prac = rooms_df[rooms_df['is_practicum'] == True].index.tolist()
rooms_theo = rooms_df[rooms_df['is_theory'] == True].index.tolist()

# ── Teacher workload heuristic ────────────────────────────────────────────────
teacher_workload = mk_df_raw['teacher_id'].value_counts().to_dict()
mk_df_raw['teacher_degree'] = mk_df_raw['teacher_id'].map(teacher_workload)

# ── Pre-build global slot lists (computed ONCE) ───────────────────────────────
PRAC_SLOTS = [(r, s) for r in rooms_prac for s in valid_starts]
THEO_SLOTS = [(r, s) for r in rooms_theo for s in valid_starts]

# ── Pre-extracted numpy arrays for O(1) hot-loop access ──────────────────────
_REQ_PRAC   = mk_df_raw['requires_practicum_room'].to_numpy()
_TEACHER    = mk_df_raw['teacher_id'].to_numpy()
_T_PRIORITY = mk_df_raw['teacher_priority'].to_numpy()
_T_DEGREE   = mk_df_raw['teacher_degree'].to_numpy()
_TS_DAY     = timeslots_df['day'].to_numpy()
_TS_SESSION = timeslots_df['session_type'].to_numpy()
_N_COURSES  = len(mk_df_raw)

SESSION_MORNING   = (_TS_SESSION == 'Morning')
SESSION_AFTERNOON = (_TS_SESSION == 'Afternoon')

# ── HC weight: any 1 HC violation > any possible SC total ────────────────────
HC_WEIGHT = 10_000_000

# ── Global flag: controls whether repair logs are printed (disabled in workers) ──
_VERBOSE_REPAIR = False


# ==========================================
# 2. Fitness Function with Conflict-Directed Repair
# ==========================================
def fitness_function(sol_x, verbose_repair=False):
    """
    Three-phase decoder with detailed repair logging.

    PHASE 1 — Greedy HC-aware assignment
    PHASE 2 — Conflict-Directed Repair (with per-course trace when verbose_repair=True)
    PHASE 3 — SC Re-evaluation
    """
    hc_count     = 0
    sc_value     = 0
    sc_count     = 0
    assignments      = []
    unassigned_idxs  = []

    room_time_booked    = set()
    teacher_time_booked = set()
    teacher_day_rooms   = {}
    teacher_ts_to_asgn  = {}

    avail_prac = set(range(len(PRAC_SLOTS)))
    avail_theo = set(range(len(THEO_SLOTS)))

    # Repair trace: list of dicts, one per unassigned course processed
    repair_log = []

    # ── MCF + PO random-key ordering ─────────────────────────────────────────
    base_scores = (_REQ_PRAC.astype(float) * 1000) + (_T_DEGREE * 10)
    priorities  = base_scores + (sol_x * 100)
    queue_order = np.argsort(-priorities)

    # =========================================================================
    # PHASE 1 — GREEDY ASSIGNMENT
    # =========================================================================
    for idx in queue_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set = avail_prac  if req_prac else avail_theo

        hc_fallback    = None
        best_sc        = float('inf')
        best_slot_info = None
        sc_scan_count  = 0

        for si in list(avail_set):
            r, s = slot_list[si]
            t1, t2 = s, s + 1

            if (teacher, t1) in teacher_time_booked or (teacher, t2) in teacher_time_booked:
                continue

            if hc_fallback is None:
                hc_fallback = (r, s, _TS_DAY[s], t1, t2, si)

            day     = _TS_DAY[s]
            temp_sc = 0
            if t_priority == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
                temp_sc += 10
            elif t_priority == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
                temp_sc += 10
            if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
                if r not in teacher_day_rooms[teacher][day]:
                    temp_sc += 50

            if temp_sc < best_sc:
                best_sc        = temp_sc
                best_slot_info = (r, s, day, t1, t2, si)
                if temp_sc == 0:
                    break
            sc_scan_count += 1
            if sc_scan_count >= 50:
                break

        chosen = best_slot_info if best_slot_info is not None else hc_fallback

        if chosen is not None:
            r, s, day, t1, t2, si = chosen
            _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                       assignments, room_time_booked, teacher_time_booked,
                       teacher_day_rooms, teacher_ts_to_asgn,
                       avail_prac, avail_theo)
        else:
            unassigned_idxs.append(int(idx))

    # =========================================================================
    # PHASE 2 — CONFLICT-DIRECTED REPAIR
    # =========================================================================
    still_unassigned = []

    for idx in unassigned_idxs:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])
        course_name = mk_df_raw['course_name'].iloc[idx] if verbose_repair else None

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set = avail_prac  if req_prac else avail_theo

        placed           = False
        attempts         = 0
        failed_relocations = 0
        trace_steps      = []   # repair steps for this course

        for r, s in slot_list:
            t1, t2 = s, s + 1

            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                continue

            blocked_t1 = (teacher, t1) in teacher_time_booked
            blocked_t2 = (teacher, t2) in teacher_time_booked

            # ── Slot is unexpectedly free → direct assign ─────────────────────
            if not blocked_t1 and not blocked_t2:
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn,
                           avail_prac, avail_theo)
                placed = True
                if verbose_repair:
                    trace_steps.append({
                        'action': 'DIRECT',
                        'detail': f"Room {rooms_df.iloc[r]['room_id']} | "
                                  f"{_TS_DAY[s]} {timeslots_df.iloc[s]['time_start']}–"
                                  f"{timeslots_df.iloc[t2]['time_end']} (no blocker)"
                    })
                break

            # ── Find blocker ──────────────────────────────────────────────────
            blocker_key      = (teacher, t1) if blocked_t1 else (teacher, t2)
            blocker_asgn_idx = teacher_ts_to_asgn.get(blocker_key)
            if blocker_asgn_idx is None:
                continue

            blocker    = assignments[blocker_asgn_idx]
            b_idx      = blocker['course_i']
            b_req_prac = bool(_REQ_PRAC[b_idx])
            b_teacher  = blocker['teacher']
            b_t1_old   = blocker['start_slot']
            b_t2_old   = blocker['end_slot']
            b_r_old    = blocker['room']
            b_priority = blocker['priority']
            b_day_old  = blocker['day']
            b_course_name = mk_df_raw['course_name'].iloc[b_idx] if verbose_repair else None

            attempts += 1

            # ── Temporarily unbook blocker ────────────────────────────────────
            room_time_booked.discard((b_r_old, b_t1_old))
            room_time_booked.discard((b_r_old, b_t2_old))
            teacher_time_booked.discard((b_teacher, b_t1_old))
            teacher_time_booked.discard((b_teacher, b_t2_old))
            teacher_ts_to_asgn.pop((b_teacher, b_t1_old), None)
            teacher_ts_to_asgn.pop((b_teacher, b_t2_old), None)

            if b_teacher in teacher_day_rooms and b_day_old in teacher_day_rooms[b_teacher]:
                try:
                    teacher_day_rooms[b_teacher][b_day_old].remove(b_r_old)
                except ValueError:
                    pass
                if not teacher_day_rooms[b_teacher][b_day_old]:
                    del teacher_day_rooms[b_teacher][b_day_old]

            b_slot_list = PRAC_SLOTS if b_req_prac else THEO_SLOTS
            b_avail_set = avail_prac  if b_req_prac else avail_theo
            b_si = -1
            try:
                b_si = b_slot_list.index((b_r_old, b_t1_old))
                b_avail_set.add(b_si)
            except ValueError:
                pass

            # ── Search for blocker relocation ─────────────────────────────────
            reloc_found = None
            b_avail     = avail_prac if b_req_prac else avail_theo
            b_slots     = PRAC_SLOTS if b_req_prac else THEO_SLOTS
            for si2 in list(b_avail):
                r2, s2 = b_slots[si2]
                t1n, t2n = s2, s2 + 1
                if (r2, t1n) in room_time_booked or (r2, t2n) in room_time_booked:
                    continue
                if (b_teacher, t1n) in teacher_time_booked or (b_teacher, t2n) in teacher_time_booked:
                    continue
                reloc_found = (r2, s2, _TS_DAY[s2], t1n, t2n, si2)
                break

            if reloc_found is not None:
                r2, s2, day2, t1n, t2n, si2 = reloc_found

                _do_assign(b_idx, r2, s2, day2, t1n, t2n, b_priority, b_teacher,
                           b_req_prac, assignments, room_time_booked,
                           teacher_time_booked, teacher_day_rooms,
                           teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=blocker_asgn_idx)

                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn,
                           avail_prac, avail_theo)
                placed = True

                if verbose_repair:
                    trace_steps.append({
                        'action': 'SWAP_SUCCESS',
                        'detail': (
                            f"Blocker [{b_course_name} | T:{b_teacher}] moved "
                            f"{rooms_df.iloc[b_r_old]['room_id']} "
                            f"{_TS_DAY[b_t1_old]} {timeslots_df.iloc[b_t1_old]['time_start']}–"
                            f"{timeslots_df.iloc[b_t2_old]['time_end']}"
                            f"  →  "
                            f"{rooms_df.iloc[r2]['room_id']} "
                            f"{day2} {timeslots_df.iloc[s2]['time_start']}–"
                            f"{timeslots_df.iloc[t2n]['time_end']}"
                        )
                    })
                break

            else:
                failed_relocations += 1
                if verbose_repair:
                    trace_steps.append({
                        'action': 'SWAP_FAILED',
                        'detail': (
                            f"Blocker [{b_course_name} | T:{b_teacher}] at "
                            f"{rooms_df.iloc[b_r_old]['room_id']} "
                            f"{_TS_DAY[b_t1_old]} {timeslots_df.iloc[b_t1_old]['time_start']} "
                            f"has no free alternative slot"
                        )
                    })

                # Restore blocker
                room_time_booked.add((b_r_old, b_t1_old))
                room_time_booked.add((b_r_old, b_t2_old))
                teacher_time_booked.add((b_teacher, b_t1_old))
                teacher_time_booked.add((b_teacher, b_t2_old))
                teacher_ts_to_asgn[(b_teacher, b_t1_old)] = blocker_asgn_idx
                teacher_ts_to_asgn[(b_teacher, b_t2_old)] = blocker_asgn_idx
                if b_teacher not in teacher_day_rooms:
                    teacher_day_rooms[b_teacher] = {}
                if b_day_old not in teacher_day_rooms[b_teacher]:
                    teacher_day_rooms[b_teacher][b_day_old] = []
                teacher_day_rooms[b_teacher][b_day_old].append(b_r_old)
                if b_si >= 0:
                    b_avail_set.discard(b_si)

        # Record repair outcome for this course
        if verbose_repair:
            repair_log.append({
                'course_i':    idx,
                'course_name': course_name,
                'teacher':     teacher,
                'type':        'Practicum' if req_prac else 'Theory',
                'placed':      placed,
                'attempts':    attempts,
                'failed_relocs': failed_relocations,
                'steps':       trace_steps,
            })

        if not placed:
            still_unassigned.append(idx)

    hc_count = len(still_unassigned)

    # =========================================================================
    # PHASE 3 — SC TOTAL EVALUATION
    # =========================================================================
    for asgn in assignments:
        t1 = asgn['start_slot']
        t2 = asgn['end_slot']
        tp = asgn['priority']
        if tp == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
            sc_value += 10
        elif tp == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
            sc_value += 10

    for teacher_id, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    fitness = hc_count * HC_WEIGHT + sc_value
    metrics = {
        'hc_count':   hc_count,
        'hc_value':   hc_count * HC_WEIGHT,
        'sc_count':   sc_count,
        'sc_value':   sc_value,
        'repaired':   len(unassigned_idxs) - hc_count,
        'unassigned': len(unassigned_idxs),
        'repair_log': repair_log,
    }
    return fitness, assignments, metrics


# ==========================================
# 3. Assignment Helper
# ==========================================
def _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
               assignments, room_time_booked, teacher_time_booked,
               teacher_day_rooms, teacher_ts_to_asgn,
               avail_prac, avail_theo, update_idx=None):
    room_time_booked.add((r, t1)); room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))

    slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
    avail_set = avail_prac  if req_prac else avail_theo
    for si2 in list(avail_set):
        r2, s2 = slot_list[si2]
        if r2 == r and (s2 == t1 or s2 == t2 or s2 + 1 == t1):
            avail_set.discard(si2)

    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)

    asgn = {
        'course_i': int(idx), 'room': r,
        'start_slot': s, 'end_slot': t2,
        'teacher': teacher, 'priority': t_priority, 'day': day
    }

    if update_idx is not None:
        assignments[update_idx] = asgn
        teacher_ts_to_asgn[(teacher, t1)] = update_idx
        teacher_ts_to_asgn[(teacher, t2)] = update_idx
    else:
        new_idx = len(assignments)
        assignments.append(asgn)
        teacher_ts_to_asgn[(teacher, t1)] = new_idx
        teacher_ts_to_asgn[(teacher, t2)] = new_idx


def _eval_worker(x):
    return fitness_function(x, verbose_repair=False)


# ==========================================
# 4. Solution Class
# ==========================================
class Solution:
    __slots__ = ('X', 'Cost', 'assignments', 'metrics')

    def __init__(self, x, cost, assignments=None, metrics=None):
        self.X           = x
        self.Cost        = cost
        self.assignments = assignments
        self.metrics     = metrics

    def clone(self):
        return Solution(self.X.copy(), self.Cost, self.assignments, self.metrics)


# ==========================================
# 5. Parallel Population Evaluator
# ==========================================
def parallel_eval(vectors, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), len(vectors))
    if n_workers <= 1 or len(vectors) <= 4:
        return [fitness_function(v) for v in vectors]
    results = [None] * len(vectors)
    with ProcessPoolExecutor(max_workers=n_workers) as pool:
        futures = {pool.submit(_eval_worker, v): i for i, v in enumerate(vectors)}
        for fut in as_completed(futures):
            results[futures[fut]] = fut.result()
    return results


# ==========================================
# 6. Logging Helpers
# ==========================================
_LOG_SEP  = "─" * 110
_LOG_HDR  = "═" * 110

def print_iteration_log(Iter, Sol, Best, elapsed, phase_label=""):
    """Full per-iteration summary line."""
    worst_cost = max(s.Cost for s in Sol)
    m = Best.metrics
    tag = f"[{phase_label}] " if phase_label else ""
    print(
        f"{tag}Iter {Iter:03d} | "
        f"Best Fitness: {Best.Cost:>14,.0f} | Worst Fitness: {worst_cost:>14,.0f} | "
        f"HC Viol: {m['hc_count']:>3d} (Penalty: {m['hc_value']:>14,.0f}) | "
        f"SC Viol: {m['sc_count']:>4d} (Penalty: {m['sc_value']:>7,.0f}) | "
        f"Time: {elapsed:>7.1f}s"
    )


def print_repair_detail(metrics, iter_label="Best Solution"):
    """Print the per-course repair trace stored in metrics['repair_log']."""
    log = metrics.get('repair_log', [])
    if not log:
        return

    n_unassigned = metrics['unassigned']
    n_repaired   = metrics['repaired']
    n_failed     = metrics['hc_count']

    print()
    print(_LOG_HDR)
    print(f"  REPAIR DETAIL — {iter_label}".center(110))
    print(f"  Courses sent to Phase 2: {n_unassigned}  |  "
          f"Successfully repaired: {n_repaired}  |  "
          f"Still unassigned (HC): {n_failed}".center(110))
    print(_LOG_HDR)

    for i, entry in enumerate(log, 1):
        status = "✔ PLACED" if entry['placed'] else "✘ FAILED"
        room_type = entry['type']
        print(f"\n  [{i:02d}/{len(log)}] {status} | "
              f"Course : {entry['course_name']}  "
              f"| Teacher: {entry['teacher']}  "
              f"| Type: {room_type}")
        print(f"         Swap attempts: {entry['attempts']}  |  "
              f"Failed relocations: {entry['failed_relocs']}")

        if entry['steps']:
            for step in entry['steps']:
                icon = "  ↳ " if step['action'] != 'SWAP_FAILED' else "  ✗ "
                print(f"    {icon}[{step['action']:>14s}] {step['detail']}")
        else:
            print("    (no blocker swap required — assigned directly)")

    print(_LOG_SEP)


def print_header(title):
    print("\n" + _LOG_HDR)
    print(f"  {title}".center(110))
    print(_LOG_HDR)
    print(
        f"{'Iter':>6} | "
        f"{'Best Fitness':>14} | {'Worst Fitness':>14} | "
        f"{'HC Viol':>7} | {'HC Penalty':>14} | "
        f"{'SC Viol':>7} | {'SC Penalty':>10} | "
        f"{'Time':>8}"
    )
    print(_LOG_SEP)


def print_summary_line(Iter, Sol, Best, elapsed):
    """Compact tabular line (used inside the header table)."""
    worst_cost = max(s.Cost for s in Sol)
    m = Best.metrics
    print(
        f"{Iter:>6} | "
        f"{Best.Cost:>14,.0f} | {worst_cost:>14,.0f} | "
        f"{m['hc_count']:>7d} | {m['hc_value']:>14,.0f} | "
        f"{m['sc_count']:>7d} | {m['sc_value']:>10,.0f} | "
        f"{elapsed:>7.1f}s"
    )


# ==========================================
# 7. Puma Optimizer — MECHANISM UNCHANGED
# ==========================================
def exploration(Sol, lb, ub, dim, nSol, n_workers):
    pCR = 0.20
    PCR = 1 - pCR
    p   = PCR / nSol
    Sol.sort(key=lambda s: s.Cost)

    new_vectors = []
    for i in range(nSol):
        x = Sol[i].X
        A = list(range(nSol)); A.remove(i); np.random.shuffle(A)
        a, b, c, d, e, f = A[:6]
        G = 2 * np.random.rand() - 1
        if np.random.rand() < 0.5:
            y = np.random.rand(dim) * (ub - lb) + lb
        else:
            da = Sol[a].X - Sol[b].X
            db = Sol[c].X - Sol[d].X
            dc = Sol[e].X - Sol[f].X
            y  = Sol[a].X + G * da + G * ((da - db) + (db - dc))
        y  = np.clip(y, lb, ub)
        z  = x.copy()
        j0 = np.random.randint(dim)
        mask = (np.random.rand(dim) <= pCR)
        mask[j0] = True
        z[mask] = y[mask]
        new_vectors.append(z)

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
        else:
            pCR = pCR + p
    return Sol


def exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers):
    Q, Beta = 0.67, 2
    mbest   = np.mean([s.X for s in Sol], axis=0)

    new_vectors = []
    for i in range(nSol):
        beta1 = 2 * np.random.rand()
        beta2 = np.random.randn(dim)
        w, v  = np.random.randn(dim), np.random.randn(dim)
        F1    = np.random.randn(dim) * np.exp(2 - Iter * (2 / MaxIter))
        F2    = w * (v ** 2) * np.cos(2 * np.random.rand() * w)
        R_1   = 2 * np.random.rand() - 1
        S1    = (2 * np.random.rand() - 1 + np.random.randn(dim))
        S2    = F1 * R_1 * Sol[i].X + F2 * (1 - R_1) * Best.X
        VEC   = S2 / (S1 + 1e-10)

        if np.random.rand() <= 0.5:
            if np.random.rand() > Q:
                r_idx = np.random.randint(nSol)
                x_new = Best.X + beta1 * np.exp(beta2) * (Sol[r_idx].X - Sol[i].X)
            else:
                x_new = beta1 * VEC - Best.X
        else:
            r1    = np.random.randint(nSol)
            sign  = (-1) ** np.random.randint(0, 2)
            x_new = (mbest * Sol[r1].X - sign * Sol[i].X) / (1 + Beta * np.random.rand())

        new_vectors.append(np.clip(x_new, lb, ub))

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
    return Sol


def run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), nSol)

    print(_LOG_HDR)
    print("  PUMA OPTIMIZER v5 — CONFIGURATION".center(110))
    print(_LOG_HDR)
    print(f"  Parallel workers  : {n_workers}")
    print(f"  Population (nSol) : {nSol}")
    print(f"  Max iterations    : {MaxIter}")
    print(f"  Dimensions (courses): {_N_COURSES}")
    print(f"  HC weight         : {HC_WEIGHT:,}")
    print(f"  Rooms (theory)    : {len(rooms_theo)}  |  Rooms (practicum): {len(rooms_prac)}")
    print(f"  Valid timeslot pairs: {len(valid_starts)}")
    print(_LOG_SEP)

    # ── Initial population ────────────────────────────────────────────────────
    print("\n[INIT] Evaluating initial population...")
    init_vectors    = [lb + (ub - lb) * np.random.rand(dim) for _ in range(nSol)]
    init_vectors[0] = np.full(dim, 0.5)

    results      = parallel_eval(init_vectors, n_workers)
    Sol          = [Solution(init_vectors[i], *results[i]) for i in range(nSol)]
    Best         = min(Sol, key=lambda s: s.Cost)
    Initial_Best = Best.clone()

    m = Best.metrics
    print(f"\n[INIT] Initial Best Solution:")
    print(f"       Fitness     : {Best.Cost:,.0f}")
    print(f"       HC Violations: {m['hc_count']}  (Penalty: {m['hc_value']:,})")
    print(f"       SC Violations: {m['sc_count']}  (Penalty: {m['sc_value']:,})")
    print(f"       Courses sent to repair: {m['unassigned']}  |  Repaired: {m['repaired']}")

    # Show repair detail for initial best
    if m['unassigned'] > 0:
        # Re-evaluate with verbose to get repair trace
        _, _, m_verbose = fitness_function(Best.X, verbose_repair=True)
        print_repair_detail(m_verbose, iter_label="INITIAL POPULATION")

    if Best.metrics['hc_count'] == 0:
        print("\n[INFO] Zero HC violations at initialisation — skipping optimisation.")
        return Best

    # ── PO state variables (UNCHANGED) ───────────────────────────────────────
    UnSelected = [1, 1]
    F3_Explore = F3_Exploit = 0
    Seq_Time_Explore  = [1, 1, 1];  Seq_Time_Exploit  = [1, 1, 1]
    Seq_Cost_Explore  = [1, 1, 1];  Seq_Cost_Exploit  = [1, 1, 1]
    PF            = [0.5, 0.5, 0.3]
    PF_F3         = []
    Mega_Explor   = Mega_Exploit = 0.99
    Costs_Explor  = np.zeros(3)
    Costs_Exploit = np.zeros(3)
    Flag_Change   = 1

    print_header("PUMA OPTIMISATION PROGRESS")
    t_start      = time.perf_counter()
    prev_best_hc = Best.metrics['hc_count']  # track HC drops for repair-detail triggers

    # ── Bootstrap iterations 1–3 ──────────────────────────────────────────────
    for Iter in range(1, 4):
        Sol_E1 = exploration ([s.clone() for s in Sol], lb, ub, dim, nSol, n_workers)
        Sol_E2 = exploitation([s.clone() for s in Sol], lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
        Costs_Explor[Iter - 1]  = min(s.Cost for s in Sol_E1)
        Costs_Exploit[Iter - 1] = min(s.Cost for s in Sol_E2)

        merged = Sol + Sol_E1 + Sol_E2
        merged.sort(key=lambda s: s.Cost)
        Sol  = merged[:nSol]
        Best = Sol[0]
        elapsed = time.perf_counter() - t_start
        print_summary_line(Iter, Sol, Best, elapsed)

        # Show repair detail whenever HC count drops
        if Best.metrics['hc_count'] < prev_best_hc and Best.metrics['unassigned'] > 0:
            _, _, m_v = fitness_function(Best.X, verbose_repair=True)
            print_repair_detail(m_v, iter_label=f"Iter {Iter:03d} (HC improved: "
                                                 f"{prev_best_hc} → {Best.metrics['hc_count']})")
            prev_best_hc = Best.metrics['hc_count']

        if Best.metrics['hc_count'] == 0:
            print(_LOG_SEP)
            print(f"[INFO] Zero HC achieved at bootstrap iteration {Iter}.")
            return Best

    Seq_Cost_Explore[0] = abs(Initial_Best.Cost  - Costs_Explor[0])
    Seq_Cost_Explore[1] = abs(Costs_Explor[1]    - Costs_Explor[0])
    Seq_Cost_Explore[2] = abs(Costs_Explor[2]    - Costs_Explor[1])
    Seq_Cost_Exploit[0] = abs(Initial_Best.Cost  - Costs_Exploit[0])
    Seq_Cost_Exploit[1] = abs(Costs_Exploit[1]   - Costs_Exploit[0])
    Seq_Cost_Exploit[2] = abs(Costs_Exploit[2]   - Costs_Exploit[1])

    for v in Seq_Cost_Explore + Seq_Cost_Exploit:
        if v != 0:
            PF_F3.append(v)

    # ── Main loop (PO mechanism UNCHANGED) ───────────────────────────────────
    stagnation = 0
    prev_best  = Best.Cost

    for Iter in range(4, MaxIter + 1):
        F1_Explor  = PF[0] * (Seq_Cost_Explore[0] / Seq_Time_Explore[0])
        F1_Exploit = PF[0] * (Seq_Cost_Exploit[0] / Seq_Time_Exploit[0])
        F2_Explor  = PF[1] * (sum(Seq_Cost_Explore) / sum(Seq_Time_Explore))
        F2_Exploit = PF[1] * (sum(Seq_Cost_Exploit) / sum(Seq_Time_Exploit))
        Score_Explore  = Mega_Explor  * (F1_Explor  + F2_Explor)
        Score_Exploit  = Mega_Exploit * (F1_Exploit + F2_Exploit)

        if Score_Explore > Score_Exploit:
            SelectFlag = 1
            Sol = exploration(Sol, lb, ub, dim, nSol, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[1] += 1;  UnSelected[0] = 1
            F3_Explore = PF[2];  F3_Exploit += PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Explore[2], Seq_Cost_Explore[1] = Seq_Cost_Explore[1], Seq_Cost_Explore[0]
            Seq_Cost_Explore[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Explore[0]:
                PF_F3.append(Seq_Cost_Explore[0])
        else:
            SelectFlag = 2
            Sol = exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[0] += 1;  UnSelected[1] = 1
            F3_Explore += PF[2];  F3_Exploit = PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Exploit[2], Seq_Cost_Exploit[1] = Seq_Cost_Exploit[1], Seq_Cost_Exploit[0]
            Seq_Cost_Exploit[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Exploit[0]:
                PF_F3.append(Seq_Cost_Exploit[0])

        if TBest.Cost < Best.Cost:
            Best = TBest

        if Flag_Change != SelectFlag:
            Flag_Change = SelectFlag
            Seq_Time_Explore[2], Seq_Time_Explore[1], Seq_Time_Explore[0] = \
                Seq_Time_Explore[1], Seq_Time_Explore[0], Count_select[0]
            Seq_Time_Exploit[2], Seq_Time_Exploit[1], Seq_Time_Exploit[0] = \
                Seq_Time_Exploit[1], Seq_Time_Exploit[0], Count_select[1]

        if Score_Explore < Score_Exploit:
            Mega_Explor  = max(Mega_Explor  - 0.01, 0.01)
            Mega_Exploit = 0.99
        else:
            Mega_Explor  = 0.99
            Mega_Exploit = max(Mega_Exploit - 0.01, 0.01)

        elapsed = time.perf_counter() - t_start
        print_summary_line(Iter, Sol, Best, elapsed)

        # Show repair detail on every HC improvement
        if Best.metrics['hc_count'] < prev_best_hc and Best.metrics['unassigned'] > 0:
            _, _, m_v = fitness_function(Best.X, verbose_repair=True)
            print_repair_detail(m_v, iter_label=f"Iter {Iter:03d} (HC improved: "
                                                 f"{prev_best_hc} → {Best.metrics['hc_count']})")
            prev_best_hc = Best.metrics['hc_count']

        if Best.metrics['hc_count'] == 0:
            print(_LOG_SEP)
            print(f"[INFO] Zero HC violations achieved at iteration {Iter}.")
            break

        # ── Stagnation recovery ───────────────────────────────────────────────
        if Best.Cost >= prev_best:
            stagnation += 1
        else:
            stagnation = 0
            prev_best  = Best.Cost

        if stagnation >= 10:
            print(_LOG_SEP)
            print(f"[WARN] Stagnation at iter {Iter} — injecting diversity into bottom third...")
            n_replace = nSol // 3
            new_vecs  = [lb + (ub - lb) * np.random.rand(dim) for _ in range(n_replace)]
            res       = parallel_eval(new_vecs, n_workers)
            for k, (c, a, met) in enumerate(res):
                Sol[-(k + 1)] = Solution(new_vecs[k], c, a, met)
            stagnation = 0
            print(_LOG_SEP)

    total_time = time.perf_counter() - t_start
    print(f"\n[INFO] Optimisation finished in {total_time:.1f}s")
    return Best


# ==========================================
# 8. Eksekusi & Ekspor
# ==========================================
if __name__ == '__main__':
    nSol    = 300
    MaxIter = 500
    dim     = _N_COURSES
    lb, ub  = 0.0, 1.0

    t0            = time.perf_counter()
    best_solution = run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None)
    total_elapsed = time.perf_counter() - t0

    # ── Final repair detail ───────────────────────────────────────────────────
    if best_solution.metrics['unassigned'] > 0:
        _, _, m_final = fitness_function(best_solution.X, verbose_repair=True)
        print_repair_detail(m_final, iter_label="FINAL BEST SOLUTION")

    # ── Build result DataFrame ────────────────────────────────────────────────
    res_list = []
    for a in best_solution.assignments:
        course = mk_df_raw.iloc[a['course_i']]
        room   = rooms_df.iloc[a['room']]
        t1     = timeslots_df.iloc[a['start_slot']]
        t2     = timeslots_df.iloc[a['end_slot']]
        res_list.append({
            'event_id':    course['event_id'],
            'course_name': course['course_name'],
            'teacher_id':  course['teacher_id'],
            'room_id':     room['room_id'],
            'day':         t1['day'],
            'time_start':  t1['time_start'],
            'time_end':    t2['time_end'],
        })

    res_df   = pd.DataFrame(res_list)
    out_path = 'scheduled_courses_poa_v6.csv'
    res_df.to_csv(out_path, index=False)

    m = best_solution.metrics
    print("\n" + _LOG_HDR)
    print("  FINAL RESULT SUMMARY".center(110))
    print(_LOG_HDR)
    print(f"  Total elapsed         : {total_elapsed:.1f}s")
    print(f"  Courses scheduled     : {len(res_list)} / {_N_COURSES}")
    print(f"  HC Violations         : {m['hc_count']}   (Penalty: {m['hc_value']:,})")
    print(f"  SC Violations         : {m['sc_count']}   (Penalty: {m['sc_value']:,})")
    print(f"  Total Fitness Score   : {best_solution.Cost:,}")
    print(f"  Courses repaired (P2) : {m['repaired']} / {m['unassigned']}")
    print(f"  Output saved to       : '{out_path}'")
    print(_LOG_HDR)
# Out:
# [INFO] Memuat dan memproses dataset...
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#                                        PUMA OPTIMIZER v5 — CONFIGURATION
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#   Parallel workers  : 8
#   Population (nSol) : 300
#   Max iterations    : 500
#   Dimensions (courses): 725
#   HC weight         : 10,000,000
#   Rooms (theory)    : 39  |  Rooms (practicum): 12
#   Valid timeslot pairs: 55
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# [INIT] Evaluating initial population...
#
# [INIT] Initial Best Solution:
#        Fitness     : 5,370
#        HC Violations: 0  (Penalty: 0)
#        SC Violations: 55  (Penalty: 5,370)
#        Courses sent to repair: 40  |  Repaired: 40
#
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#                                        REPAIR DETAIL — INITIAL POPULATION
#              Courses sent to Phase 2: 40  |  Successfully repaired: 40  |  Still unassigned (HC): 0
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
#   [01/40] ✔ PLACED | Course : Probabilitas dan Statistika  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman SQL - Praktikum | T:16] moved G1.2 Monday 12:30–14:10  →  G1.2 Monday 12:30–14:10
#
#   [02/40] ✔ PLACED | Course : Sistem Pendukung Keputusan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Web Lanjut | T:16] moved F2.1 Monday 14:10–15:50  →  F2.1 Monday 14:10–15:50
#
#   [03/40] ✔ PLACED | Course : Desain Basis Data  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Aplikasi Mobile | T:16] moved F2.1 Monday 15:50–17:30  →  F2.1 Monday 15:50–17:30
#
#   [04/40] ✔ PLACED | Course : Sistem Pembelajaran Jarak Jauh  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Implementasi dan Pengujian Sistem Informasi | T:16] moved F2.1 Tuesday 12:30–14:10  →  F2.1 Tuesday 12:30–14:10
#
#   [05/40] ✔ PLACED | Course : Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Antarmuka Pengguna | T:16] moved F2.1 Tuesday 14:10–15:50  →  F2.1 Tuesday 14:10–15:50
#
#   [06/40] ✔ PLACED | Course : Desain Antar Muka Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Integrasi Sistem | T:16] moved F2.1 Tuesday 15:50–17:30  →  F2.1 Tuesday 15:50–17:30
#
#   [07/40] ✔ PLACED | Course : Perancangan Pengalaman Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Berbasis Cloud | T:16] moved F2.1 Wednesday 12:30–14:10  →  F2.1 Wednesday 12:30–14:10
#
#   [08/40] ✔ PLACED | Course : Data Warehouse  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Gim | T:16] moved F2.1 Wednesday 14:10–15:50  →  F2.1 Wednesday 14:10–15:50
#
#   [09/40] ✔ PLACED | Course : Dasar Desain Antarmuka Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Basis Data Non Relational | T:16] moved F2.1 Wednesday 15:50–17:30  →  F2.1 Wednesday 15:50–17:30
#
#   [10/40] ✔ PLACED | Course : Analisis Data Penelitian Kuantitatif  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman SQL | T:16] moved F2.1 Thursday 12:30–14:10  →  F2.1 Thursday 12:30–14:10
#
#   [11/40] ✔ PLACED | Course : Perancangan Pengalaman Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemodelan Proses Bisnis | T:16] moved F2.1 Thursday 14:10–15:50  →  F2.1 Thursday 14:10–15:50
#
#   [12/40] ✔ PLACED | Course : Pengembangan Aplikasi Mobile Lanjut  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Kecerdasan Artifisial | T:16] moved F2.1 Thursday 15:50–17:30  →  F3.3 Thursday 15:50–17:30
#
#   [13/40] ✔ PLACED | Course : Sistem Pembelajaran Berbasis Multimedia, Gim, dan Peranti Bergerak  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Aplikasi Mobile Lanjut | T:16] moved F3.3 Thursday 15:50–17:30  →  F3.3 Thursday 15:50–17:30
#
#   [14/40] ✔ PLACED | Course : Perkembangan dan Tren Teknologi Digital  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Kecerdasan Buatan dan Pembelajaran Mesin | T:16] moved F2.1 Friday 12:30–14:10  →  F2.1 Friday 12:30–14:10
#
#   [15/40] ✔ PLACED | Course : Big Data dan Analitik  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Berbasis Objek | T:16] moved F2.1 Friday 14:10–15:50  →  F2.1 Friday 14:10–15:50
#
#   [16/40] ✔ PLACED | Course : Sistem Operasi  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Lanjut | T:16] moved F2.1 Friday 15:50–17:30  →  F2.1 Friday 15:50–17:30
#
#   [17/40] ✔ PLACED | Course : Analisis Data Penelitian Kuantitatif  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Probabilitas dan Statistika | T:16] moved F3.3 Monday 12:30–14:10  →  F3.3 Monday 12:30–14:10
#
#   [18/40] ✔ PLACED | Course : Sistem Informasi Berkelanjutan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pendukung Keputusan | T:16] moved F3.3 Monday 14:10–15:50  →  F3.3 Monday 14:10–15:50
#
#   [19/40] ✔ PLACED | Course : Pola-Pola Perancangan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Desain Basis Data | T:16] moved F3.3 Monday 15:50–17:30  →  F3.3 Monday 15:50–17:30
#
#   [20/40] ✔ PLACED | Course : Pengembangan dan Manajemen Perangkat Lunak  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Jarak Jauh | T:16] moved F3.3 Tuesday 12:30–14:10  →  F3.3 Tuesday 12:30–14:10
#
#   [21/40] ✔ PLACED | Course : Evaluasi Pengalaman dan Antarmuka Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi | T:16] moved F3.3 Tuesday 14:10–15:50  →  F3.3 Tuesday 14:10–15:50
#
#   [22/40] ✔ PLACED | Course : Probabilitas dan Statistika  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Desain Antar Muka Pengguna | T:16] moved F3.3 Tuesday 15:50–17:30  →  F3.3 Tuesday 15:50–17:30
#
#   [23/40] ✔ PLACED | Course : Aljabar Linear dan Matriks  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Pengalaman Pengguna | T:16] moved F3.3 Wednesday 12:30–14:10  →  F3.3 Wednesday 12:30–14:10
#
#   [24/40] ✔ PLACED | Course : Pengembangan Aplikasi Mobile Terapan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Data Warehouse | T:16] moved F3.3 Wednesday 14:10–15:50  →  F3.3 Wednesday 14:10–15:50
#
#   [25/40] ✔ PLACED | Course : Gudang Data  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Dasar Desain Antarmuka Pengguna | T:16] moved F3.3 Wednesday 15:50–17:30  →  F3.3 Wednesday 15:50–17:30
#
#   [26/40] ✔ PLACED | Course : Pengembangan Aplikasi Web Lanjut  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Penambangan Data | T:16] moved F2.1 Thursday 08:40–10:20  →  F2.1 Thursday 08:40–10:20
#
#   [27/40] ✔ PLACED | Course : Pengembangan Aplikasi Multiplatform  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengantar Sains Data | T:16] moved F2.1 Thursday 10:20–12:00  →  F2.1 Thursday 10:20–12:00
#
#   [28/40] ✔ PLACED | Course : Teknologi Platform  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Analisis Data Penelitian Kuantitatif | T:16] moved F3.3 Thursday 12:30–14:10  →  F3.3 Thursday 12:30–14:10
#
#   [29/40] ✔ PLACED | Course : Teknologi Peranti Internet  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Pengalaman Pengguna | T:16] moved F3.3 Thursday 14:10–15:50  →  F3.3 Thursday 14:10–15:50
#
#   [30/40] ✔ PLACED | Course : Evaluasi Pengalaman dan Antarmuka Pengguna  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Smart City | T:47] moved F2.2 Thursday 15:50–17:30  →  F2.2 Thursday 15:50–17:30
#
#   [31/40] ✔ PLACED | Course : Inovasi Digital Kompetitif  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Antarmuka Pengguna - Praktikum | T:47] moved G1.2 Friday 07:00–08:40  →  G1.2 Friday 07:00–08:40
#
#   [32/40] ✔ PLACED | Course : Pemrograman Web  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan dan Manajemen Perangkat Lunak - Praktikum | T:47] moved G1.2 Friday 08:40–10:20  →  G1.2 Friday 08:40–10:20
#
#   [33/40] ✔ PLACED | Course : Perancangan Antarmuka Pengguna  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Aplikasi Mobile - Praktikum | T:47] moved G1.2 Friday 10:20–12:00  →  G1.2 Friday 10:20–12:00
#
#   [34/40] ✔ PLACED | Course : Teknologi Blockchain dan Platform Keuangan Digital  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Multimodal Storytelling | T:47] moved F2.2 Friday 12:30–14:10  →  F2.2 Friday 12:30–14:10
#
#   [35/40] ✔ PLACED | Course : Teknologi Blockchain dan Platform Keuangan Digital  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Jarak Jauh | T:47] moved F2.2 Friday 14:10–15:50  →  F2.2 Friday 14:10–15:50
#
#   [36/40] ✔ PLACED | Course : Desain Antar Muka Pengguna  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan dan Manajemen Perangkat Lunak | T:47] moved F2.2 Friday 15:50–17:30  →  F2.2 Friday 15:50–17:30
#
#   [37/40] ✔ PLACED | Course : Teknologi Platform  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Lingkungan Pembelajaran Digital - Praktikum | T:47] moved G1.3 Monday 07:00–08:40  →  G1.3 Monday 07:00–08:40
#
#   [38/40] ✔ PLACED | Course : Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Lingkungan Pembelajaran Digital | T:47] moved F2.1 Monday 08:40–10:20  →  F2.1 Monday 08:40–10:20
#
#   [39/40] ✔ PLACED | Course : Manajemen Layanan Teknologi Informasi  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Lanjut | T:47] moved F2.1 Monday 10:20–12:00  →  F2.1 Monday 10:20–12:00
#
#   [40/40] ✔ PLACED | Course : Pengembangan Aplikasi Web Lanjut  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Berbasis Multimedia, Gim, dan Peranti Bergerak | T:47] moved F2.1 Monday 12:30–14:10  →  F2.1 Monday 12:30–14:10
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# [INFO] Zero HC violations at initialisation — skipping optimisation.
#
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#                                       REPAIR DETAIL — FINAL BEST SOLUTION
#              Courses sent to Phase 2: 40  |  Successfully repaired: 40  |  Still unassigned (HC): 0
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#
#   [01/40] ✔ PLACED | Course : Probabilitas dan Statistika  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman SQL - Praktikum | T:16] moved G1.2 Monday 12:30–14:10  →  G1.2 Monday 12:30–14:10
#
#   [02/40] ✔ PLACED | Course : Sistem Pendukung Keputusan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Web Lanjut | T:16] moved F2.1 Monday 14:10–15:50  →  F2.1 Monday 14:10–15:50
#
#   [03/40] ✔ PLACED | Course : Desain Basis Data  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Aplikasi Mobile | T:16] moved F2.1 Monday 15:50–17:30  →  F2.1 Monday 15:50–17:30
#
#   [04/40] ✔ PLACED | Course : Sistem Pembelajaran Jarak Jauh  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Implementasi dan Pengujian Sistem Informasi | T:16] moved F2.1 Tuesday 12:30–14:10  →  F2.1 Tuesday 12:30–14:10
#
#   [05/40] ✔ PLACED | Course : Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Antarmuka Pengguna | T:16] moved F2.1 Tuesday 14:10–15:50  →  F2.1 Tuesday 14:10–15:50
#
#   [06/40] ✔ PLACED | Course : Desain Antar Muka Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Integrasi Sistem | T:16] moved F2.1 Tuesday 15:50–17:30  →  F2.1 Tuesday 15:50–17:30
#
#   [07/40] ✔ PLACED | Course : Perancangan Pengalaman Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Berbasis Cloud | T:16] moved F2.1 Wednesday 12:30–14:10  →  F2.1 Wednesday 12:30–14:10
#
#   [08/40] ✔ PLACED | Course : Data Warehouse  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Gim | T:16] moved F2.1 Wednesday 14:10–15:50  →  F2.1 Wednesday 14:10–15:50
#
#   [09/40] ✔ PLACED | Course : Dasar Desain Antarmuka Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Basis Data Non Relational | T:16] moved F2.1 Wednesday 15:50–17:30  →  F2.1 Wednesday 15:50–17:30
#
#   [10/40] ✔ PLACED | Course : Analisis Data Penelitian Kuantitatif  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman SQL | T:16] moved F2.1 Thursday 12:30–14:10  →  F2.1 Thursday 12:30–14:10
#
#   [11/40] ✔ PLACED | Course : Perancangan Pengalaman Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemodelan Proses Bisnis | T:16] moved F2.1 Thursday 14:10–15:50  →  F2.1 Thursday 14:10–15:50
#
#   [12/40] ✔ PLACED | Course : Pengembangan Aplikasi Mobile Lanjut  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Kecerdasan Artifisial | T:16] moved F2.1 Thursday 15:50–17:30  →  F3.3 Thursday 15:50–17:30
#
#   [13/40] ✔ PLACED | Course : Sistem Pembelajaran Berbasis Multimedia, Gim, dan Peranti Bergerak  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Aplikasi Mobile Lanjut | T:16] moved F3.3 Thursday 15:50–17:30  →  F3.3 Thursday 15:50–17:30
#
#   [14/40] ✔ PLACED | Course : Perkembangan dan Tren Teknologi Digital  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Kecerdasan Buatan dan Pembelajaran Mesin | T:16] moved F2.1 Friday 12:30–14:10  →  F2.1 Friday 12:30–14:10
#
#   [15/40] ✔ PLACED | Course : Big Data dan Analitik  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Berbasis Objek | T:16] moved F2.1 Friday 14:10–15:50  →  F2.1 Friday 14:10–15:50
#
#   [16/40] ✔ PLACED | Course : Sistem Operasi  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Lanjut | T:16] moved F2.1 Friday 15:50–17:30  →  F2.1 Friday 15:50–17:30
#
#   [17/40] ✔ PLACED | Course : Analisis Data Penelitian Kuantitatif  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Probabilitas dan Statistika | T:16] moved F3.3 Monday 12:30–14:10  →  F3.3 Monday 12:30–14:10
#
#   [18/40] ✔ PLACED | Course : Sistem Informasi Berkelanjutan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pendukung Keputusan | T:16] moved F3.3 Monday 14:10–15:50  →  F3.3 Monday 14:10–15:50
#
#   [19/40] ✔ PLACED | Course : Pola-Pola Perancangan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Desain Basis Data | T:16] moved F3.3 Monday 15:50–17:30  →  F3.3 Monday 15:50–17:30
#
#   [20/40] ✔ PLACED | Course : Pengembangan dan Manajemen Perangkat Lunak  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Jarak Jauh | T:16] moved F3.3 Tuesday 12:30–14:10  →  F3.3 Tuesday 12:30–14:10
#
#   [21/40] ✔ PLACED | Course : Evaluasi Pengalaman dan Antarmuka Pengguna  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi | T:16] moved F3.3 Tuesday 14:10–15:50  →  F3.3 Tuesday 14:10–15:50
#
#   [22/40] ✔ PLACED | Course : Probabilitas dan Statistika  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Desain Antar Muka Pengguna | T:16] moved F3.3 Tuesday 15:50–17:30  →  F3.3 Tuesday 15:50–17:30
#
#   [23/40] ✔ PLACED | Course : Aljabar Linear dan Matriks  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Pengalaman Pengguna | T:16] moved F3.3 Wednesday 12:30–14:10  →  F3.3 Wednesday 12:30–14:10
#
#   [24/40] ✔ PLACED | Course : Pengembangan Aplikasi Mobile Terapan  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Data Warehouse | T:16] moved F3.3 Wednesday 14:10–15:50  →  F3.3 Wednesday 14:10–15:50
#
#   [25/40] ✔ PLACED | Course : Gudang Data  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Dasar Desain Antarmuka Pengguna | T:16] moved F3.3 Wednesday 15:50–17:30  →  F3.3 Wednesday 15:50–17:30
#
#   [26/40] ✔ PLACED | Course : Pengembangan Aplikasi Web Lanjut  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Penambangan Data | T:16] moved F2.1 Thursday 08:40–10:20  →  F2.1 Thursday 08:40–10:20
#
#   [27/40] ✔ PLACED | Course : Pengembangan Aplikasi Multiplatform  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengantar Sains Data | T:16] moved F2.1 Thursday 10:20–12:00  →  F2.1 Thursday 10:20–12:00
#
#   [28/40] ✔ PLACED | Course : Teknologi Platform  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Analisis Data Penelitian Kuantitatif | T:16] moved F3.3 Thursday 12:30–14:10  →  F3.3 Thursday 12:30–14:10
#
#   [29/40] ✔ PLACED | Course : Teknologi Peranti Internet  | Teacher: 16  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Pengalaman Pengguna | T:16] moved F3.3 Thursday 14:10–15:50  →  F3.3 Thursday 14:10–15:50
#
#   [30/40] ✔ PLACED | Course : Evaluasi Pengalaman dan Antarmuka Pengguna  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Teknologi Smart City | T:47] moved F2.2 Thursday 15:50–17:30  →  F2.2 Thursday 15:50–17:30
#
#   [31/40] ✔ PLACED | Course : Inovasi Digital Kompetitif  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Perancangan Antarmuka Pengguna - Praktikum | T:47] moved G1.2 Friday 07:00–08:40  →  G1.2 Friday 07:00–08:40
#
#   [32/40] ✔ PLACED | Course : Pemrograman Web  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan dan Manajemen Perangkat Lunak - Praktikum | T:47] moved G1.2 Friday 08:40–10:20  →  G1.2 Friday 08:40–10:20
#
#   [33/40] ✔ PLACED | Course : Perancangan Antarmuka Pengguna  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan Aplikasi Mobile - Praktikum | T:47] moved G1.2 Friday 10:20–12:00  →  G1.2 Friday 10:20–12:00
#
#   [34/40] ✔ PLACED | Course : Teknologi Blockchain dan Platform Keuangan Digital  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Multimodal Storytelling | T:47] moved F2.2 Friday 12:30–14:10  →  F2.2 Friday 12:30–14:10
#
#   [35/40] ✔ PLACED | Course : Teknologi Blockchain dan Platform Keuangan Digital  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Jarak Jauh | T:47] moved F2.2 Friday 14:10–15:50  →  F2.2 Friday 14:10–15:50
#
#   [36/40] ✔ PLACED | Course : Desain Antar Muka Pengguna  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pengembangan dan Manajemen Perangkat Lunak | T:47] moved F2.2 Friday 15:50–17:30  →  F2.2 Friday 15:50–17:30
#
#   [37/40] ✔ PLACED | Course : Teknologi Platform  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Lingkungan Pembelajaran Digital - Praktikum | T:47] moved G1.3 Monday 07:00–08:40  →  G1.3 Monday 07:00–08:40
#
#   [38/40] ✔ PLACED | Course : Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Lingkungan Pembelajaran Digital | T:47] moved F2.1 Monday 08:40–10:20  →  F2.1 Monday 08:40–10:20
#
#   [39/40] ✔ PLACED | Course : Manajemen Layanan Teknologi Informasi  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Pemrograman Lanjut | T:47] moved F2.1 Monday 10:20–12:00  →  F2.1 Monday 10:20–12:00
#
#   [40/40] ✔ PLACED | Course : Pengembangan Aplikasi Web Lanjut  | Teacher: 47  | Type: Theory
#          Swap attempts: 1  |  Failed relocations: 0
#       ↳ [  SWAP_SUCCESS] Blocker [Sistem Pembelajaran Berbasis Multimedia, Gim, dan Peranti Bergerak | T:47] moved F2.1 Monday 12:30–14:10  →  F2.1 Monday 12:30–14:10
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#                                               FINAL RESULT SUMMARY
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════
#   Total elapsed         : 9.4s
#   Courses scheduled     : 725 / 725
#   HC Violations         : 0   (Penalty: 0)
#   SC Violations         : 55   (Penalty: 5,370)
#   Total Fitness Score   : 5,370
#   Courses repaired (P2) : 40 / 40
#   Output saved to       : 'scheduled_courses_poa_v6.csv'
# ══════════════════════════════════════════════════════════════════════════════════════════════════════════════

# %%
import numpy as np
import pandas as pd
import time
from concurrent.futures import ProcessPoolExecutor, as_completed
import os

# ==========================================
# 1. Deklarasi & Persiapan Dataset
# ==========================================
print("[INFO] Memuat dan memproses dataset...")
mk_df_raw    = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_genap_praktikum_processed.csv')
rooms_df     = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv')
timeslots_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv')

# ── Pre-compute valid consecutive timeslot pairs ──────────────────────────────
valid_starts = [
    i for i in range(len(timeslots_df) - 1)
    if (timeslots_df.iloc[i]['day'] == timeslots_df.iloc[i + 1]['day'] and
        timeslots_df.iloc[i]['time_end'] == timeslots_df.iloc[i + 1]['time_start'])
]

rooms_prac = rooms_df[rooms_df['is_practicum'] == True].index.tolist()
rooms_theo = rooms_df[rooms_df['is_theory'] == True].index.tolist()

# ── Teacher workload heuristic ────────────────────────────────────────────────
teacher_workload = mk_df_raw['teacher_id'].value_counts().to_dict()
mk_df_raw['teacher_degree'] = mk_df_raw['teacher_id'].map(teacher_workload)

# ── Pre-build global slot lists (computed ONCE) ───────────────────────────────
PRAC_SLOTS = [(r, s) for r in rooms_prac for s in valid_starts]
THEO_SLOTS = [(r, s) for r in rooms_theo for s in valid_starts]

# ── Pre-extracted numpy arrays for O(1) hot-loop access ──────────────────────
_REQ_PRAC   = mk_df_raw['requires_practicum_room'].to_numpy()
_TEACHER    = mk_df_raw['teacher_id'].to_numpy()
_T_PRIORITY = mk_df_raw['teacher_priority'].to_numpy()
_T_DEGREE   = mk_df_raw['teacher_degree'].to_numpy()
_TS_DAY     = timeslots_df['day'].to_numpy()
_TS_SESSION = timeslots_df['session_type'].to_numpy()
_N_COURSES  = len(mk_df_raw)

SESSION_MORNING   = (_TS_SESSION == 'Morning')
SESSION_AFTERNOON = (_TS_SESSION == 'Afternoon')

# ── HC weight: any 1 HC violation > any possible SC total ────────────────────
HC_WEIGHT = 10_000_000


# ==========================================
# 2. Fitness Function with Conflict-Directed Repair
# ==========================================
def fitness_function(sol_x, verbose_repair=False):
    """
    Three-phase decoder.

    PHASE 1 — Greedy assignment (Most-Constrained-First + PO random key).
    PHASE 2 — Conflict-Directed Repair: courses that Phase 1 couldn't place are
              rescued by temporarily relocating the assignment that blocks them.
    PHASE 3 — Full SC evaluation.
    """
    sc_value        = 0
    sc_count        = 0
    assignments     = []
    unassigned_idxs = []

    room_time_booked    = set()
    teacher_time_booked = set()
    teacher_day_rooms   = {}
    teacher_ts_to_asgn  = {}   # (teacher, ts_idx) → index in assignments

    avail_prac = set(range(len(PRAC_SLOTS)))
    avail_theo = set(range(len(THEO_SLOTS)))

    repair_log = []   # populated only when verbose_repair=True

    # ── MCF + PO random-key ordering ─────────────────────────────────────────
    base_scores = (_REQ_PRAC.astype(float) * 1000) + (_T_DEGREE * 10)
    priorities  = base_scores + (sol_x * 100)
    queue_order = np.argsort(-priorities)

    # =========================================================================
    # PHASE 1 — GREEDY ASSIGNMENT
    # =========================================================================
    for idx in queue_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set = avail_prac  if req_prac else avail_theo

        hc_fallback    = None
        best_sc        = float('inf')
        best_slot_info = None
        sc_scan_count  = 0

        for si in list(avail_set):
            r, s = slot_list[si]
            t1, t2 = s, s + 1
            if (teacher, t1) in teacher_time_booked or (teacher, t2) in teacher_time_booked:
                continue
            if hc_fallback is None:
                hc_fallback = (r, s, _TS_DAY[s], t1, t2, si)
            day     = _TS_DAY[s]
            temp_sc = 0
            if t_priority == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
                temp_sc += 10
            elif t_priority == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
                temp_sc += 10
            if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
                if r not in teacher_day_rooms[teacher][day]:
                    temp_sc += 50
            if temp_sc < best_sc:
                best_sc        = temp_sc
                best_slot_info = (r, s, day, t1, t2, si)
                if temp_sc == 0:
                    break
            sc_scan_count += 1
            if sc_scan_count >= 50:
                break

        chosen = best_slot_info if best_slot_info is not None else hc_fallback
        if chosen is not None:
            r, s, day, t1, t2, si = chosen
            _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                       assignments, room_time_booked, teacher_time_booked,
                       teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
        else:
            unassigned_idxs.append(int(idx))

    # =========================================================================
    # PHASE 2 — CONFLICT-DIRECTED REPAIR
    # =========================================================================
    still_unassigned = []

    for idx in unassigned_idxs:
        req_prac    = bool(_REQ_PRAC[idx])
        teacher     = _TEACHER[idx]
        t_priority  = int(_T_PRIORITY[idx])
        course_name = mk_df_raw['course_name'].iloc[idx] if verbose_repair else None

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
        placed              = False
        attempts            = 0
        failed_relocations  = 0
        trace_steps         = []

        for r, s in slot_list:
            t1, t2 = s, s + 1
            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                continue

            blocked_t1 = (teacher, t1) in teacher_time_booked
            blocked_t2 = (teacher, t2) in teacher_time_booked

            # ── Case A: slot is actually free (Phase 1 missed it) ────────────
            if not blocked_t1 and not blocked_t2:
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                placed = True
                if verbose_repair:
                    trace_steps.append({'action': 'DIRECT',
                        'detail': (f"Assigned directly → Room {rooms_df.iloc[r]['room_id']} | "
                                   f"{_TS_DAY[s]} {timeslots_df.iloc[s]['time_start']}–"
                                   f"{timeslots_df.iloc[t2]['time_end']}")})
                break

            # ── Case B: teacher is blocked — try to relocate the blocker ─────
            blocker_key      = (teacher, t1) if blocked_t1 else (teacher, t2)
            blocker_asgn_idx = teacher_ts_to_asgn.get(blocker_key)
            if blocker_asgn_idx is None:
                continue

            blocker    = assignments[blocker_asgn_idx]
            b_idx      = blocker['course_i']
            b_req_prac = bool(_REQ_PRAC[b_idx])
            b_teacher  = blocker['teacher']
            b_t1_old   = blocker['start_slot']
            b_t2_old   = blocker['end_slot']
            b_r_old    = blocker['room']
            b_priority = blocker['priority']
            b_day_old  = blocker['day']
            b_cname    = mk_df_raw['course_name'].iloc[b_idx] if verbose_repair else ''
            attempts  += 1

            # Temporarily unbook blocker
            room_time_booked.discard((b_r_old, b_t1_old))
            room_time_booked.discard((b_r_old, b_t2_old))
            teacher_time_booked.discard((b_teacher, b_t1_old))
            teacher_time_booked.discard((b_teacher, b_t2_old))
            teacher_ts_to_asgn.pop((b_teacher, b_t1_old), None)
            teacher_ts_to_asgn.pop((b_teacher, b_t2_old), None)
            if b_teacher in teacher_day_rooms and b_day_old in teacher_day_rooms[b_teacher]:
                try:
                    teacher_day_rooms[b_teacher][b_day_old].remove(b_r_old)
                except ValueError:
                    pass
                if not teacher_day_rooms[b_teacher][b_day_old]:
                    del teacher_day_rooms[b_teacher][b_day_old]

            b_slot_list = PRAC_SLOTS if b_req_prac else THEO_SLOTS
            b_avail_set = avail_prac  if b_req_prac else avail_theo
            b_si = -1
            try:
                b_si = b_slot_list.index((b_r_old, b_t1_old))
                b_avail_set.add(b_si)
            except ValueError:
                pass

            # Find new slot for blocker
            reloc_found = None
            for si2 in list(avail_prac if b_req_prac else avail_theo):
                r2, s2   = b_slot_list[si2]
                t1n, t2n = s2, s2 + 1
                if (r2, t1n) in room_time_booked or (r2, t2n) in room_time_booked:
                    continue
                if (b_teacher, t1n) in teacher_time_booked or (b_teacher, t2n) in teacher_time_booked:
                    continue
                reloc_found = (r2, s2, _TS_DAY[s2], t1n, t2n, si2)
                break

            if reloc_found is not None:
                r2, s2, day2, t1n, t2n, si2 = reloc_found
                _do_assign(b_idx, r2, s2, day2, t1n, t2n, b_priority, b_teacher,
                           b_req_prac, assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=blocker_asgn_idx)
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                placed = True
                if verbose_repair:
                    trace_steps.append({'action': 'SWAP_SUCCESS', 'detail': (
                        f"Blocker '{b_cname}' (T:{b_teacher}) relocated "
                        f"{rooms_df.iloc[b_r_old]['room_id']} {_TS_DAY[b_t1_old]} "
                        f"{timeslots_df.iloc[b_t1_old]['time_start']}–{timeslots_df.iloc[b_t2_old]['time_end']}"
                        f"  →  "
                        f"{rooms_df.iloc[r2]['room_id']} {day2} "
                        f"{timeslots_df.iloc[s2]['time_start']}–{timeslots_df.iloc[t2n]['time_end']}"
                    )})
                break
            else:
                failed_relocations += 1
                if verbose_repair:
                    trace_steps.append({'action': 'SWAP_FAILED', 'detail': (
                        f"Blocker '{b_cname}' (T:{b_teacher}) at "
                        f"{rooms_df.iloc[b_r_old]['room_id']} {_TS_DAY[b_t1_old]} "
                        f"{timeslots_df.iloc[b_t1_old]['time_start']} "
                        f"— no alternative slot available"
                    )})
                # Restore blocker
                room_time_booked.add((b_r_old, b_t1_old))
                room_time_booked.add((b_r_old, b_t2_old))
                teacher_time_booked.add((b_teacher, b_t1_old))
                teacher_time_booked.add((b_teacher, b_t2_old))
                teacher_ts_to_asgn[(b_teacher, b_t1_old)] = blocker_asgn_idx
                teacher_ts_to_asgn[(b_teacher, b_t2_old)] = blocker_asgn_idx
                if b_teacher not in teacher_day_rooms:
                    teacher_day_rooms[b_teacher] = {}
                if b_day_old not in teacher_day_rooms[b_teacher]:
                    teacher_day_rooms[b_teacher][b_day_old] = []
                teacher_day_rooms[b_teacher][b_day_old].append(b_r_old)
                if b_si >= 0:
                    b_avail_set.discard(b_si)

        if verbose_repair:
            repair_log.append({
                'course_i':     idx,
                'course_name':  course_name,
                'teacher':      teacher,
                'type':         'Practicum' if req_prac else 'Theory',
                'placed':       placed,
                'attempts':     attempts,
                'failed_relocs': failed_relocations,
                'steps':        trace_steps,
            })

        if not placed:
            still_unassigned.append(idx)

    hc_count = len(still_unassigned)

    # =========================================================================
    # PHASE 3 — SC EVALUATION
    # =========================================================================
    for asgn in assignments:
        t1 = asgn['start_slot']
        t2 = asgn['end_slot']
        tp = asgn['priority']
        if tp == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
            sc_value += 10
        elif tp == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
            sc_value += 10

    for teacher_id, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    fitness = hc_count * HC_WEIGHT + sc_value
    metrics = {
        'hc_count':   hc_count,
        'hc_value':   hc_count * HC_WEIGHT,
        'sc_count':   sc_count,
        'sc_value':   sc_value,
        'repaired':   len(unassigned_idxs) - hc_count,
        'unassigned': len(unassigned_idxs),
        'repair_log': repair_log,
    }
    return fitness, assignments, metrics


# ==========================================
# 3. Assignment Helper
# ==========================================
def _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
               assignments, room_time_booked, teacher_time_booked,
               teacher_day_rooms, teacher_ts_to_asgn,
               avail_prac, avail_theo, update_idx=None):
    room_time_booked.add((r, t1)); room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))

    slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
    avail_set = avail_prac  if req_prac else avail_theo
    for si2 in list(avail_set):
        r2, s2 = slot_list[si2]
        if r2 == r and (s2 == t1 or s2 == t2 or s2 + 1 == t1):
            avail_set.discard(si2)

    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)

    asgn = {'course_i': int(idx), 'room': r, 'start_slot': s, 'end_slot': t2,
             'teacher': teacher, 'priority': t_priority, 'day': day}

    if update_idx is not None:
        assignments[update_idx] = asgn
        teacher_ts_to_asgn[(teacher, t1)] = update_idx
        teacher_ts_to_asgn[(teacher, t2)] = update_idx
    else:
        new_idx = len(assignments)
        assignments.append(asgn)
        teacher_ts_to_asgn[(teacher, t1)] = new_idx
        teacher_ts_to_asgn[(teacher, t2)] = new_idx


def _eval_worker(x):
    return fitness_function(x, verbose_repair=False)


# ==========================================
# 4. Solution Class
# ==========================================
class Solution:
    __slots__ = ('X', 'Cost', 'assignments', 'metrics')

    def __init__(self, x, cost, assignments=None, metrics=None):
        self.X           = x
        self.Cost        = cost
        self.assignments = assignments
        self.metrics     = metrics

    def clone(self):
        return Solution(self.X.copy(), self.Cost, self.assignments, self.metrics)


# ==========================================
# 5. Parallel Population Evaluator
# ==========================================
def parallel_eval(vectors, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), len(vectors))
    if n_workers <= 1 or len(vectors) <= 4:
        return [fitness_function(v) for v in vectors]
    results = [None] * len(vectors)
    with ProcessPoolExecutor(max_workers=n_workers) as pool:
        futures = {pool.submit(_eval_worker, v): i for i, v in enumerate(vectors)}
        for fut in as_completed(futures):
            results[futures[fut]] = fut.result()
    return results


# ==========================================
# 6. Display Helpers
# ==========================================
SEP  = "=" * 95

def print_iter(Iter, Sol, Best, elapsed):
    """Single iteration log line — matches the style of the reference output."""
    worst = max(s.Cost for s in Sol)
    m     = Best.metrics
    print(
        f"Iter {Iter:03d} | "
        f"Best: {Best.Cost:>12,.0f} | Worst: {worst:>12,.0f} | "
        f"HC: {m['hc_count']:>3d} ({m['hc_value']:>12,.0f}) | "
        f"SC: {m['sc_count']:>3d} ({m['sc_value']:>7,.0f}) | "
        f"Time: {elapsed:.1f}s"
    )


def print_repair_report(metrics, label="FINAL SOLUTION"):
    """
    Detailed per-course repair report — printed once after the run ends.
    Shows every course that went through Phase 2, what happened to it,
    and the exact swap steps taken.
    """
    log        = metrics.get('repair_log', [])
    n_sent     = metrics['unassigned']
    n_repaired = metrics['repaired']
    n_failed   = metrics['hc_count']

    print()
    print(SEP)
    print(f"  PHASE 2 REPAIR REPORT — {label}".center(95))
    print(f"  Courses sent to repair : {n_sent}".center(95))
    print(f"  Successfully repaired  : {n_repaired}".center(95))
    print(f"  Still unassigned (HC)  : {n_failed}".center(95))
    print(SEP)

    if not log:
        print("  (No repair trace available — re-run with verbose_repair=True)")
        print(SEP)
        return

    placed_entries = [e for e in log if e['placed']]
    failed_entries = [e for e in log if not e['placed']]

    # ── Successfully repaired courses ────────────────────────────────────────
    if placed_entries:
        print(f"\n  {'─'*40}  REPAIRED ({len(placed_entries)})  {'─'*40}")
        for i, e in enumerate(placed_entries, 1):
            print(f"\n  [{i:02d}] PLACED  | {e['course_name']:<40} | Teacher: {e['teacher']} | {e['type']}")
            print(f"       Swap attempts: {e['attempts']}   Failed relocations: {e['failed_relocs']}")
            for step in e['steps']:
                icon = "  ✔" if step['action'] != 'SWAP_FAILED' else "  ✘"
                print(f"  {icon} [{step['action']:>14s}]  {step['detail']}")

    # ── Courses that could not be placed ─────────────────────────────────────
    if failed_entries:
        print(f"\n  {'─'*39}  UNRESOLVED ({len(failed_entries)})  {'─'*39}")
        for i, e in enumerate(failed_entries, 1):
            print(f"\n  [{i:02d}] FAILED  | {e['course_name']:<40} | Teacher: {e['teacher']} | {e['type']}")
            print(f"       Swap attempts: {e['attempts']}   Failed relocations: {e['failed_relocs']}")
            for step in e['steps']:
                icon = "  ✔" if step['action'] != 'SWAP_FAILED' else "  ✘"
                print(f"  {icon} [{step['action']:>14s}]  {step['detail']}")
            if not e['steps']:
                print("       (No HC-free room slot exists for this room type — capacity exceeded)")

    print()
    print(SEP)


# ==========================================
# 7. Puma Optimizer — MECHANISM UNCHANGED
# ==========================================
def exploration(Sol, lb, ub, dim, nSol, n_workers):
    pCR = 0.20
    PCR = 1 - pCR
    p   = PCR / nSol
    Sol.sort(key=lambda s: s.Cost)
    new_vectors = []
    for i in range(nSol):
        x = Sol[i].X
        A = list(range(nSol)); A.remove(i); np.random.shuffle(A)
        a, b, c, d, e, f = A[:6]
        G = 2 * np.random.rand() - 1
        if np.random.rand() < 0.5:
            y = np.random.rand(dim) * (ub - lb) + lb
        else:
            da = Sol[a].X - Sol[b].X
            db = Sol[c].X - Sol[d].X
            dc = Sol[e].X - Sol[f].X
            y  = Sol[a].X + G * da + G * ((da - db) + (db - dc))
        y  = np.clip(y, lb, ub)
        z  = x.copy()
        j0 = np.random.randint(dim)
        mask = (np.random.rand(dim) <= pCR)
        mask[j0] = True
        z[mask] = y[mask]
        new_vectors.append(z)
    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
        else:
            pCR += p
    return Sol


def exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers):
    Q, Beta = 0.67, 2
    mbest   = np.mean([s.X for s in Sol], axis=0)
    new_vectors = []
    for i in range(nSol):
        beta1 = 2 * np.random.rand()
        beta2 = np.random.randn(dim)
        w, v  = np.random.randn(dim), np.random.randn(dim)
        F1    = np.random.randn(dim) * np.exp(2 - Iter * (2 / MaxIter))
        F2    = w * (v ** 2) * np.cos(2 * np.random.rand() * w)
        R_1   = 2 * np.random.rand() - 1
        S1    = (2 * np.random.rand() - 1 + np.random.randn(dim))
        S2    = F1 * R_1 * Sol[i].X + F2 * (1 - R_1) * Best.X
        VEC   = S2 / (S1 + 1e-10)
        if np.random.rand() <= 0.5:
            if np.random.rand() > Q:
                r_idx = np.random.randint(nSol)
                x_new = Best.X + beta1 * np.exp(beta2) * (Sol[r_idx].X - Sol[i].X)
            else:
                x_new = beta1 * VEC - Best.X
        else:
            r1    = np.random.randint(nSol)
            sign  = (-1) ** np.random.randint(0, 2)
            x_new = (mbest * Sol[r1].X - sign * Sol[i].X) / (1 + Beta * np.random.rand())
        new_vectors.append(np.clip(x_new, lb, ub))
    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
    return Sol


def run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), nSol)
    print(f"[INFO] Parallel workers: {n_workers}")

    # ── Initial population ────────────────────────────────────────────────────
    print("Mengevaluasi populasi inisial...")
    init_vectors    = [lb + (ub - lb) * np.random.rand(dim) for _ in range(nSol)]
    init_vectors[0] = np.full(dim, 0.5)    # seed: pure MCF order

    results      = parallel_eval(init_vectors, n_workers)
    Sol          = [Solution(init_vectors[i], *results[i]) for i in range(nSol)]
    Best         = min(Sol, key=lambda s: s.Cost)
    Initial_Best = Best.clone()

    m = Best.metrics
    print(f"\nInitial Best Fitness: {Best.Cost:,.0f} | "
          f"HC: {m['hc_count']} ({m['hc_value']:,}) | "
          f"SC: {m['sc_count']} ({m['sc_value']:,})")

    if Best.metrics['hc_count'] == 0:
        print("[INFO] Zero HC violations in initial population — skipping optimisation.")
        return Best

    # ── PO state variables (UNCHANGED) ───────────────────────────────────────
    UnSelected = [1, 1]
    F3_Explore = F3_Exploit = 0
    Seq_Time_Explore  = [1, 1, 1];  Seq_Time_Exploit  = [1, 1, 1]
    Seq_Cost_Explore  = [1, 1, 1];  Seq_Cost_Exploit  = [1, 1, 1]
    PF            = [0.5, 0.5, 0.3]
    PF_F3         = []
    Mega_Explor   = Mega_Exploit = 0.99
    Costs_Explor  = np.zeros(3)
    Costs_Exploit = np.zeros(3)
    Flag_Change   = 1

    print()
    print(SEP)
    print("MEMULAI PROSES OPTIMASI PUMA (v6)".center(95))
    print(SEP)

    t_start    = time.perf_counter()
    stagnation = 0
    prev_best  = Best.Cost

    # ── Bootstrap iterations 1–3 ─────────────────────────────────────────────
    for Iter in range(1, 4):
        Sol_E1 = exploration ([s.clone() for s in Sol], lb, ub, dim, nSol, n_workers)
        Sol_E2 = exploitation([s.clone() for s in Sol], lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
        Costs_Explor[Iter - 1]  = min(s.Cost for s in Sol_E1)
        Costs_Exploit[Iter - 1] = min(s.Cost for s in Sol_E2)
        merged = Sol + Sol_E1 + Sol_E2
        merged.sort(key=lambda s: s.Cost)
        Sol  = merged[:nSol]
        Best = Sol[0]
        print_iter(Iter, Sol, Best, time.perf_counter() - t_start)
        if Best.metrics['hc_count'] == 0:
            print(f"\n[INFO] Zero HC achieved at bootstrap iteration {Iter} — stopping early.")
            return Best

    Seq_Cost_Explore[0] = abs(Initial_Best.Cost  - Costs_Explor[0])
    Seq_Cost_Explore[1] = abs(Costs_Explor[1]    - Costs_Explor[0])
    Seq_Cost_Explore[2] = abs(Costs_Explor[2]    - Costs_Explor[1])
    Seq_Cost_Exploit[0] = abs(Initial_Best.Cost  - Costs_Exploit[0])
    Seq_Cost_Exploit[1] = abs(Costs_Exploit[1]   - Costs_Exploit[0])
    Seq_Cost_Exploit[2] = abs(Costs_Exploit[2]   - Costs_Exploit[1])
    for v in Seq_Cost_Explore + Seq_Cost_Exploit:
        if v != 0: PF_F3.append(v)

    # ── Main loop (PO mechanism UNCHANGED) ───────────────────────────────────
    for Iter in range(4, MaxIter + 1):
        F1_Explor  = PF[0] * (Seq_Cost_Explore[0] / Seq_Time_Explore[0])
        F1_Exploit = PF[0] * (Seq_Cost_Exploit[0] / Seq_Time_Exploit[0])
        F2_Explor  = PF[1] * (sum(Seq_Cost_Explore) / sum(Seq_Time_Explore))
        F2_Exploit = PF[1] * (sum(Seq_Cost_Exploit) / sum(Seq_Time_Exploit))
        Score_Explore  = Mega_Explor  * (F1_Explor  + F2_Explor)
        Score_Exploit  = Mega_Exploit * (F1_Exploit + F2_Exploit)

        if Score_Explore > Score_Exploit:
            SelectFlag   = 1
            Sol          = exploration(Sol, lb, ub, dim, nSol, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[1] += 1;  UnSelected[0] = 1
            F3_Explore    = PF[2];  F3_Exploit += PF[2]
            TBest         = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Explore[2], Seq_Cost_Explore[1] = Seq_Cost_Explore[1], Seq_Cost_Explore[0]
            Seq_Cost_Explore[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Explore[0]: PF_F3.append(Seq_Cost_Explore[0])
        else:
            SelectFlag   = 2
            Sol          = exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[0] += 1;  UnSelected[1] = 1
            F3_Explore   += PF[2];  F3_Exploit = PF[2]
            TBest         = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Exploit[2], Seq_Cost_Exploit[1] = Seq_Cost_Exploit[1], Seq_Cost_Exploit[0]
            Seq_Cost_Exploit[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Exploit[0]: PF_F3.append(Seq_Cost_Exploit[0])

        if TBest.Cost < Best.Cost:
            Best = TBest

        if Flag_Change != SelectFlag:
            Flag_Change = SelectFlag
            Seq_Time_Explore[2], Seq_Time_Explore[1], Seq_Time_Explore[0] = \
                Seq_Time_Explore[1], Seq_Time_Explore[0], Count_select[0]
            Seq_Time_Exploit[2], Seq_Time_Exploit[1], Seq_Time_Exploit[0] = \
                Seq_Time_Exploit[1], Seq_Time_Exploit[0], Count_select[1]

        if Score_Explore < Score_Exploit:
            Mega_Explor  = max(Mega_Explor  - 0.01, 0.01); Mega_Exploit = 0.99
        else:
            Mega_Explor  = 0.99; Mega_Exploit = max(Mega_Exploit - 0.01, 0.01)

        print_iter(Iter, Sol, Best, time.perf_counter() - t_start)

        if Best.metrics['hc_count'] == 0:
            print(f"\n[INFO] Zero HC violations achieved at iteration {Iter} — stopping early.")
            break

        # ── Stagnation recovery ───────────────────────────────────────────────
        if Best.Cost >= prev_best:
            stagnation += 1
        else:
            stagnation = 0
            prev_best  = Best.Cost

        if stagnation >= 10:
            print(f"[WARN] Stagnation detected at iter {Iter} — injecting diversity...")
            n_replace = nSol // 3
            new_vecs  = [lb + (ub - lb) * np.random.rand(dim) for _ in range(n_replace)]
            res       = parallel_eval(new_vecs, n_workers)
            for k, (c, a, met) in enumerate(res):
                Sol[-(k + 1)] = Solution(new_vecs[k], c, a, met)
            stagnation = 0

    total_time = time.perf_counter() - t_start
    print(f"\n[INFO] Optimasi selesai dalam {total_time:.1f}s")
    return Best


# ==========================================
# 8. Eksekusi & Ekspor
# ==========================================
if __name__ == '__main__':
    nSol    = 100
    MaxIter = 100
    dim     = _N_COURSES
    lb, ub  = 0.0, 1.0

    t0            = time.perf_counter()
    best_solution = run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None)
    total_elapsed = time.perf_counter() - t0
    print(f"\nTotal elapsed: {total_elapsed:.1f}s")

    # ── Repair report (re-evaluate best solution with verbose trace) ──────────
    if best_solution.metrics['unassigned'] > 0:
        print("\n[INFO] Re-evaluating best solution for repair trace...")
        _, _, m_verbose = fitness_function(best_solution.X, verbose_repair=True)
        print_repair_report(m_verbose, label="FINAL BEST SOLUTION")
    else:
        print("\n[INFO] All courses assigned — no repair report needed.")

    # ── Build result DataFrame ────────────────────────────────────────────────
    res_list = []
    for a in best_solution.assignments:
        course = mk_df_raw.iloc[a['course_i']]
        room   = rooms_df.iloc[a['room']]
        t1     = timeslots_df.iloc[a['start_slot']]
        t2     = timeslots_df.iloc[a['end_slot']]
        res_list.append({
            'event_id':    course['event_id'],
            'course_name': course['course_name'],
            'teacher_id':  course['teacher_id'],
            'room_id':     room['room_id'],
            'day':         t1['day'],
            'time_start':  t1['time_start'],
            'time_end':    t2['time_end'],
        })

    res_df   = pd.DataFrame(res_list)
    out_path = 'scheduled_courses_poa_v6.csv'
    res_df.to_csv(out_path, index=False)

    m = best_solution.metrics
    print()
    print(SEP)
    print("  FINAL RESULT".center(95))
    print(SEP)
    print(f"  HC Violations  : {m['hc_count']}   (penalty: {m['hc_value']:,})")
    print(f"  SC Violations  : {m['sc_count']}   (penalty: {m['sc_value']:,})")
    print(f"  Total Fitness  : {best_solution.Cost:,}")
    print(f"  Courses scheduled : {len(res_list)} / {_N_COURSES}")
    print(f"  Repaired by P2    : {m['repaired']} / {m['unassigned']}")
    print(SEP)
    print(f"[INFO] Solusi disimpan di '{out_path}'")
# Out:
# [INFO] Memuat dan memproses dataset...
# [INFO] Parallel workers: 8
# Mengevaluasi populasi inisial...
#
# Initial Best Fitness: 5,370 | HC: 0 (0) | SC: 55 (5,370)
# [INFO] Zero HC violations in initial population — skipping optimisation.
#
# Total elapsed: 3.7s
#
# [INFO] Re-evaluating best solution for repair trace...
#
# ===============================================================================================
#                            PHASE 2 REPAIR REPORT — FINAL BEST SOLUTION
#                                    Courses sent to repair : 40
#                                    Successfully repaired  : 40
#                                     Still unassigned (HC)  : 0
# ===============================================================================================
#
#   ────────────────────────────────────────  REPAIRED (40)  ────────────────────────────────────────
#
#   [01] PLACED  | Probabilitas dan Statistika              | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pemrograman SQL - Praktikum' (T:16) relocated G1.2 Monday 12:30–14:10  →  G1.2 Monday 12:30–14:10
#
#   [02] PLACED  | Sistem Pendukung Keputusan               | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pemrograman Web Lanjut' (T:16) relocated F2.1 Monday 14:10–15:50  →  F2.1 Monday 14:10–15:50
#
#   [03] PLACED  | Desain Basis Data                        | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pengembangan Aplikasi Mobile' (T:16) relocated F2.1 Monday 15:50–17:30  →  F2.1 Monday 15:50–17:30
#
#   [04] PLACED  | Sistem Pembelajaran Jarak Jauh           | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Implementasi dan Pengujian Sistem Informasi' (T:16) relocated F2.1 Tuesday 12:30–14:10  →  F2.1 Tuesday 12:30–14:10
#
#   [05] PLACED  | Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Perancangan Antarmuka Pengguna' (T:16) relocated F2.1 Tuesday 14:10–15:50  →  F2.1 Tuesday 14:10–15:50
#
#   [06] PLACED  | Desain Antar Muka Pengguna               | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Teknologi Integrasi Sistem' (T:16) relocated F2.1 Tuesday 15:50–17:30  →  F2.1 Tuesday 15:50–17:30
#
#   [07] PLACED  | Perancangan Pengalaman Pengguna          | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Teknologi Berbasis Cloud' (T:16) relocated F2.1 Wednesday 12:30–14:10  →  F2.1 Wednesday 12:30–14:10
#
#   [08] PLACED  | Data Warehouse                           | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pengembangan Gim' (T:16) relocated F2.1 Wednesday 14:10–15:50  →  F2.1 Wednesday 14:10–15:50
#
#   [09] PLACED  | Dasar Desain Antarmuka Pengguna          | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Teknologi Basis Data Non Relational' (T:16) relocated F2.1 Wednesday 15:50–17:30  →  F2.1 Wednesday 15:50–17:30
#
#   [10] PLACED  | Analisis Data Penelitian Kuantitatif     | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pemrograman SQL' (T:16) relocated F2.1 Thursday 12:30–14:10  →  F2.1 Thursday 12:30–14:10
#
#   [11] PLACED  | Perancangan Pengalaman Pengguna          | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pemodelan Proses Bisnis' (T:16) relocated F2.1 Thursday 14:10–15:50  →  F2.1 Thursday 14:10–15:50
#
#   [12] PLACED  | Pengembangan Aplikasi Mobile Lanjut      | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Kecerdasan Artifisial' (T:16) relocated F2.1 Thursday 15:50–17:30  →  F3.3 Thursday 15:50–17:30
#
#   [13] PLACED  | Sistem Pembelajaran Berbasis Multimedia, Gim, dan Peranti Bergerak | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pengembangan Aplikasi Mobile Lanjut' (T:16) relocated F3.3 Thursday 15:50–17:30  →  F3.3 Thursday 15:50–17:30
#
#   [14] PLACED  | Perkembangan dan Tren Teknologi Digital  | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Kecerdasan Buatan dan Pembelajaran Mesin' (T:16) relocated F2.1 Friday 12:30–14:10  →  F2.1 Friday 12:30–14:10
#
#   [15] PLACED  | Big Data dan Analitik                    | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pemrograman Berbasis Objek' (T:16) relocated F2.1 Friday 14:10–15:50  →  F2.1 Friday 14:10–15:50
#
#   [16] PLACED  | Sistem Operasi                           | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pemrograman Lanjut' (T:16) relocated F2.1 Friday 15:50–17:30  →  F2.1 Friday 15:50–17:30
#
#   [17] PLACED  | Analisis Data Penelitian Kuantitatif     | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Probabilitas dan Statistika' (T:16) relocated F3.3 Monday 12:30–14:10  →  F3.3 Monday 12:30–14:10
#
#   [18] PLACED  | Sistem Informasi Berkelanjutan           | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Sistem Pendukung Keputusan' (T:16) relocated F3.3 Monday 14:10–15:50  →  F3.3 Monday 14:10–15:50
#
#   [19] PLACED  | Pola-Pola Perancangan                    | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Desain Basis Data' (T:16) relocated F3.3 Monday 15:50–17:30  →  F3.3 Monday 15:50–17:30
#
#   [20] PLACED  | Pengembangan dan Manajemen Perangkat Lunak | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Sistem Pembelajaran Jarak Jauh' (T:16) relocated F3.3 Tuesday 12:30–14:10  →  F3.3 Tuesday 12:30–14:10
#
#   [21] PLACED  | Evaluasi Pengalaman dan Antarmuka Pengguna | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi' (T:16) relocated F3.3 Tuesday 14:10–15:50  →  F3.3 Tuesday 14:10–15:50
#
#   [22] PLACED  | Probabilitas dan Statistika              | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Desain Antar Muka Pengguna' (T:16) relocated F3.3 Tuesday 15:50–17:30  →  F3.3 Tuesday 15:50–17:30
#
#   [23] PLACED  | Aljabar Linear dan Matriks               | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Perancangan Pengalaman Pengguna' (T:16) relocated F3.3 Wednesday 12:30–14:10  →  F3.3 Wednesday 12:30–14:10
#
#   [24] PLACED  | Pengembangan Aplikasi Mobile Terapan     | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Data Warehouse' (T:16) relocated F3.3 Wednesday 14:10–15:50  →  F3.3 Wednesday 14:10–15:50
#
#   [25] PLACED  | Gudang Data                              | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Dasar Desain Antarmuka Pengguna' (T:16) relocated F3.3 Wednesday 15:50–17:30  →  F3.3 Wednesday 15:50–17:30
#
#   [26] PLACED  | Pengembangan Aplikasi Web Lanjut         | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Penambangan Data' (T:16) relocated F2.1 Thursday 08:40–10:20  →  F2.1 Thursday 08:40–10:20
#
#   [27] PLACED  | Pengembangan Aplikasi Multiplatform      | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pengantar Sains Data' (T:16) relocated F2.1 Thursday 10:20–12:00  →  F2.1 Thursday 10:20–12:00
#
#   [28] PLACED  | Teknologi Platform                       | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Analisis Data Penelitian Kuantitatif' (T:16) relocated F3.3 Thursday 12:30–14:10  →  F3.3 Thursday 12:30–14:10
#
#   [29] PLACED  | Teknologi Peranti Internet               | Teacher: 16 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Perancangan Pengalaman Pengguna' (T:16) relocated F3.3 Thursday 14:10–15:50  →  F3.3 Thursday 14:10–15:50
#
#   [30] PLACED  | Evaluasi Pengalaman dan Antarmuka Pengguna | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Teknologi Smart City' (T:47) relocated F2.2 Thursday 15:50–17:30  →  F2.2 Thursday 15:50–17:30
#
#   [31] PLACED  | Inovasi Digital Kompetitif               | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Perancangan Antarmuka Pengguna - Praktikum' (T:47) relocated G1.2 Friday 07:00–08:40  →  G1.2 Friday 07:00–08:40
#
#   [32] PLACED  | Pemrograman Web                          | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pengembangan dan Manajemen Perangkat Lunak - Praktikum' (T:47) relocated G1.2 Friday 08:40–10:20  →  G1.2 Friday 08:40–10:20
#
#   [33] PLACED  | Perancangan Antarmuka Pengguna           | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pengembangan Aplikasi Mobile - Praktikum' (T:47) relocated G1.2 Friday 10:20–12:00  →  G1.2 Friday 10:20–12:00
#
#   [34] PLACED  | Teknologi Blockchain dan Platform Keuangan Digital | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Multimodal Storytelling' (T:47) relocated F2.2 Friday 12:30–14:10  →  F2.2 Friday 12:30–14:10
#
#   [35] PLACED  | Teknologi Blockchain dan Platform Keuangan Digital | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Sistem Pembelajaran Jarak Jauh' (T:47) relocated F2.2 Friday 14:10–15:50  →  F2.2 Friday 14:10–15:50
#
#   [36] PLACED  | Desain Antar Muka Pengguna               | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pengembangan dan Manajemen Perangkat Lunak' (T:47) relocated F2.2 Friday 15:50–17:30  →  F2.2 Friday 15:50–17:30
#
#   [37] PLACED  | Teknologi Platform                       | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Lingkungan Pembelajaran Digital - Praktikum' (T:47) relocated G1.3 Monday 07:00–08:40  →  G1.3 Monday 07:00–08:40
#
#   [38] PLACED  | Sistem Pembelajaran Bergamifikasi dan Terpersonalisasi | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Lingkungan Pembelajaran Digital' (T:47) relocated F2.1 Monday 08:40–10:20  →  F2.1 Monday 08:40–10:20
#
#   [39] PLACED  | Manajemen Layanan Teknologi Informasi    | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Pemrograman Lanjut' (T:47) relocated F2.1 Monday 10:20–12:00  →  F2.1 Monday 10:20–12:00
#
#   [40] PLACED  | Pengembangan Aplikasi Web Lanjut         | Teacher: 47 | Theory
#        Swap attempts: 1   Failed relocations: 0
#     ✔ [  SWAP_SUCCESS]  Blocker 'Sistem Pembelajaran Berbasis Multimedia, Gim, dan Peranti Bergerak' (T:47) relocated F2.1 Monday 12:30–14:10  →  F2.1 Monday 12:30–14:10
#
# ===============================================================================================
#
# ===============================================================================================
#                                            FINAL RESULT
# ===============================================================================================
#   HC Violations  : 0   (penalty: 0)
#   SC Violations  : 55   (penalty: 5,370)
#   Total Fitness  : 5,370
#   Courses scheduled : 725 / 725
#   Repaired by P2    : 40 / 40
# ===============================================================================================
# [INFO] Solusi disimpan di 'scheduled_courses_poa_v6.csv'

# %% [markdown]
# ### V5.2

# %%
import numpy as np
import pandas as pd
import time
from concurrent.futures import ProcessPoolExecutor, as_completed
import os

# ==========================================
# 1. Deklarasi & Persiapan Dataset
# ==========================================
print("[INFO] Memuat dan memproses dataset...")
mk_df_raw = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_genap_praktikum_processed_v1.csv')
rooms_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv')
timeslots_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv')

# ── Pre-compute valid consecutive timeslot pairs ──────────────────────────────
valid_starts = [
    i for i in range(len(timeslots_df) - 1)
    if (timeslots_df.iloc[i]['day'] == timeslots_df.iloc[i + 1]['day'] and
        timeslots_df.iloc[i]['time_end'] == timeslots_df.iloc[i + 1]['time_start'])
]

rooms_prac = rooms_df[rooms_df['is_practicum'] == True].index.tolist()
rooms_theo = rooms_df[rooms_df['is_theory'] == True].index.tolist()

# ── Teacher workload heuristic ────────────────────────────────────────────────
teacher_workload = mk_df_raw['teacher_id'].value_counts().to_dict()
mk_df_raw['teacher_degree'] = mk_df_raw['teacher_id'].map(teacher_workload)

# ── Pre-build global slot lists (computed ONCE) ───────────────────────────────
PRAC_SLOTS = [(r, s) for r in rooms_prac for s in valid_starts]
THEO_SLOTS = [(r, s) for r in rooms_theo for s in valid_starts]

# ── Pre-extracted numpy arrays for O(1) hot-loop access ──────────────────────
_REQ_PRAC   = mk_df_raw['requires_practicum_room'].to_numpy()
_TEACHER    = mk_df_raw['teacher_id'].to_numpy()
_T_PRIORITY = mk_df_raw['teacher_priority'].to_numpy()
_T_DEGREE   = mk_df_raw['teacher_degree'].to_numpy()
_TS_DAY     = timeslots_df['day'].to_numpy()
_TS_SESSION = timeslots_df['session_type'].to_numpy()
_N_COURSES  = len(mk_df_raw)

SESSION_MORNING   = (_TS_SESSION == 'Morning')
SESSION_AFTERNOON = (_TS_SESSION == 'Afternoon')

# ── HC weight: any 1 HC violation > any possible SC total ────────────────────
HC_WEIGHT = 10_000_000


# ==========================================
# 2. Fitness Function with Conflict-Directed Repair
# ==========================================
def fitness_function(sol_x):
    """
    Three-phase decoder:

    PHASE 1 — Greedy HC-aware assignment
    PHASE 2 — Conflict-Directed Repair
    PHASE 3 — SC Re-evaluation + HC Conflict Audit

    FITNESS = hc_count × HC_WEIGHT + sc_value

    ── FIXES APPLIED (v5.2 → v5.2-fixed) ────────────────────────────────────

    FIX A  [Phase 1]  Added explicit room_time_booked guard in the greedy loop.
                      `avail_set` normally handles room pruning, but stale entries
                      can exist in edge cases. Any such entry is cleaned up on the
                      fly, preventing a silent room double-booking.

    FIX B  [Phase 2]  Detect when a teacher is blocked at BOTH t1 AND t2 by
                      *different* assignments. Previously the code relocated only
                      the t1 blocker and placed the current course, silently
                      leaving the t2 blocker's teacher-booking intact — creating
                      a "ghost" teacher conflict. The course was marked placed=True
                      so hc_count stayed 0, POA saw a perfect solution and exited
                      immediately without running any iterations.
                      Fix: skip the slot entirely when two distinct blockers own t1
                      and t2 respectively.

    FIX C  [Phase 2]  Exclude the current course's own target slot (r, s) from the
                      blocker's relocation candidates. Without this, the blocker
                      could be relocated into the exact slot the current course is
                      about to occupy, producing an immediate room conflict.

    FIX D  [Phase 2]  Re-verify teacher AND room availability for (r, s) *after*
                      the blocker has been relocated. Relocation can have cascading
                      side-effects. If the slot is no longer clean, skip it and
                      continue searching rather than placing blindly.

    FIX E  [Phase 3]  Added a post-assignment HC audit that counts any real teacher
                      or room conflicts remaining in `assignments`. This is the
                      critical safety net: even if a ghost conflict somehow slips
                      through, it is counted here so hc_count > 0, which prevents
                      POA from terminating early with a false "zero HC" result.

    ── WHY POA WAS BEING SKIPPED ─────────────────────────────────────────────
    In the original code, `hc_count = len(still_unassigned)` only. Phase 2's
    ghost-conflict bug caused courses to be marked placed=True even when they
    shared a teacher timeslot with another course (teacher_time_booked is a set —
    a duplicate .add() is a silent no-op). Every course appeared placed, so
    hc_count=0. The POA then hit:

        if Best.metrics['hc_count'] == 0:
            return Best   # ← exits before any POA iteration runs

    Fixes B–D prevent the ghost conflicts from being created; Fix E catches
    anything residual, ensuring hc_count truthfully reflects the schedule state.
    """
    hc_count = 0
    sc_value = 0
    sc_count = 0
    assignments     = []
    unassigned_idxs = []

    room_time_booked    = set()
    teacher_time_booked = set()
    teacher_day_rooms   = {}
    teacher_ts_to_asgn  = {}

    avail_prac = set(range(len(PRAC_SLOTS)))
    avail_theo = set(range(len(THEO_SLOTS)))

    # ── MCF + PO random-key ordering ─────────────────────────────────────────
    base_scores = (_REQ_PRAC.astype(float) * 1000) + (_T_DEGREE * 10)
    priorities  = base_scores + (sol_x * 100)
    queue_order = np.argsort(-priorities)

    # =========================================================================
    # PHASE 1 — GREEDY ASSIGNMENT
    # =========================================================================
    for idx in queue_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set = avail_prac  if req_prac else avail_theo

        hc_fallback    = None
        best_sc        = float('inf')
        best_slot_info = None
        sc_scan_count  = 0

        for si in list(avail_set):
            r, s = slot_list[si]
            t1, t2 = s, s + 1

            # FIX A: Defensive room guard — cleans up any stale avail_set entry.
            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                avail_set.discard(si)
                continue

            if (teacher, t1) in teacher_time_booked or (teacher, t2) in teacher_time_booked:
                continue

            if hc_fallback is None:
                hc_fallback = (r, s, _TS_DAY[s], t1, t2, si)

            day    = _TS_DAY[s]
            temp_sc = 0
            if t_priority == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
                temp_sc += 10
            elif t_priority == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
                temp_sc += 10
            if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
                if r not in teacher_day_rooms[teacher][day]:
                    temp_sc += 50

            if temp_sc < best_sc:
                best_sc        = temp_sc
                best_slot_info = (r, s, day, t1, t2, si)
                if temp_sc == 0:
                    break
            sc_scan_count += 1
            if sc_scan_count >= 50:
                break

        chosen = best_slot_info if best_slot_info is not None else hc_fallback

        if chosen is not None:
            r, s, day, t1, t2, si = chosen
            _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                       assignments, room_time_booked, teacher_time_booked,
                       teacher_day_rooms, teacher_ts_to_asgn,
                       avail_prac, avail_theo)
        else:
            unassigned_idxs.append(int(idx))

    # =========================================================================
    # PHASE 2 — CONFLICT-DIRECTED REPAIR
    # =========================================================================
    still_unassigned = []

    for idx in unassigned_idxs:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])

        slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS

        placed = False

        for r, s in slot_list:
            t1, t2 = s, s + 1

            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                continue

            blocked_t1 = (teacher, t1) in teacher_time_booked
            blocked_t2 = (teacher, t2) in teacher_time_booked

            # ── Direct assign (safety net) ────────────────────────────────────
            if not blocked_t1 and not blocked_t2:
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn,
                           avail_prac, avail_theo)
                placed = True
                break

            # FIX B: Skip when t1 and t2 are owned by TWO DIFFERENT assignments.
            # Relocating only one of them would leave a ghost teacher conflict
            # with the other — the root cause of the false hc_count=0 that made
            # POA exit immediately without running any iterations.
            if blocked_t1 and blocked_t2:
                b1_idx = teacher_ts_to_asgn.get((teacher, t1))
                b2_idx = teacher_ts_to_asgn.get((teacher, t2))
                if b1_idx != b2_idx:
                    continue   # two distinct blockers — cannot resolve with one swap
                blocker_key = (teacher, t1)
            else:
                blocker_key = (teacher, t1) if blocked_t1 else (teacher, t2)

            # ── Find the single blocker ───────────────────────────────────────
            blocker_asgn_idx = teacher_ts_to_asgn.get(blocker_key)
            if blocker_asgn_idx is None:
                continue

            blocker    = assignments[blocker_asgn_idx]
            b_idx      = blocker['course_i']
            b_req_prac = bool(_REQ_PRAC[b_idx])
            b_teacher  = blocker['teacher']
            b_t1_old   = blocker['start_slot']
            b_t2_old   = blocker['end_slot']
            b_r_old    = blocker['room']
            b_priority = blocker['priority']
            b_day_old  = blocker['day']

            # ── Temporarily unbook blocker ────────────────────────────────────
            room_time_booked.discard((b_r_old, b_t1_old))
            room_time_booked.discard((b_r_old, b_t2_old))
            teacher_time_booked.discard((b_teacher, b_t1_old))
            teacher_time_booked.discard((b_teacher, b_t2_old))
            teacher_ts_to_asgn.pop((b_teacher, b_t1_old), None)
            teacher_ts_to_asgn.pop((b_teacher, b_t2_old), None)

            if b_teacher in teacher_day_rooms and b_day_old in teacher_day_rooms[b_teacher]:
                try:
                    teacher_day_rooms[b_teacher][b_day_old].remove(b_r_old)
                except ValueError:
                    pass
                if not teacher_day_rooms[b_teacher][b_day_old]:
                    del teacher_day_rooms[b_teacher][b_day_old]

            b_slot_list = PRAC_SLOTS if b_req_prac else THEO_SLOTS
            b_avail_set = avail_prac  if b_req_prac else avail_theo
            b_si = -1
            try:
                b_si = b_slot_list.index((b_r_old, b_t1_old))
                b_avail_set.add(b_si)
            except ValueError:
                pass

            # ── Search for a valid relocation slot for the blocker ────────────
            reloc_found = None
            b_avail = avail_prac if b_req_prac else avail_theo
            b_slots = PRAC_SLOTS if b_req_prac else THEO_SLOTS
            for si2 in list(b_avail):
                r2, s2 = b_slots[si2]
                t1n, t2n = s2, s2 + 1

                # FIX C: Never relocate the blocker INTO the current course's
                # own target slot — that would create an immediate room conflict.
                if r2 == r and (s2 == s or s2 == s + 1 or s2 + 1 == s):
                    continue

                if (r2, t1n) in room_time_booked or (r2, t2n) in room_time_booked:
                    continue
                if (b_teacher, t1n) in teacher_time_booked or (b_teacher, t2n) in teacher_time_booked:
                    continue
                reloc_found = (r2, s2, _TS_DAY[s2], t1n, t2n, si2)
                break

            if reloc_found is not None:
                r2, s2, day2, t1n, t2n, si2 = reloc_found

                _do_assign(b_idx, r2, s2, day2, t1n, t2n, b_priority, b_teacher,
                           b_req_prac, assignments, room_time_booked,
                           teacher_time_booked, teacher_day_rooms,
                           teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=blocker_asgn_idx)

                # FIX D: Re-verify the target slot is still clean after the
                # blocker's relocation — side-effects could have invalidated it.
                day = _TS_DAY[s]
                if ((teacher, t1) in teacher_time_booked or
                        (teacher, t2) in teacher_time_booked or
                        (r, t1) in room_time_booked or
                        (r, t2) in room_time_booked):
                    # Slot invalidated by side-effect — blocker move stands,
                    # but we don't place the current course here; keep searching.
                    continue

                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn,
                           avail_prac, avail_theo)
                placed = True
                break

            else:
                # Restore blocker
                room_time_booked.add((b_r_old, b_t1_old))
                room_time_booked.add((b_r_old, b_t2_old))
                teacher_time_booked.add((b_teacher, b_t1_old))
                teacher_time_booked.add((b_teacher, b_t2_old))
                teacher_ts_to_asgn[(b_teacher, b_t1_old)] = blocker_asgn_idx
                teacher_ts_to_asgn[(b_teacher, b_t2_old)] = blocker_asgn_idx
                if b_teacher not in teacher_day_rooms:
                    teacher_day_rooms[b_teacher] = {}
                if b_day_old not in teacher_day_rooms[b_teacher]:
                    teacher_day_rooms[b_teacher][b_day_old] = []
                teacher_day_rooms[b_teacher][b_day_old].append(b_r_old)
                if b_si >= 0:
                    b_avail_set.discard(b_si)

        if not placed:
            still_unassigned.append(idx)

    # =========================================================================
    # PHASE 3 — SC + HC AUDIT
    # =========================================================================
    # SC evaluation
    for asgn in assignments:
        t1 = asgn['start_slot']
        t2 = asgn['end_slot']
        tp = asgn['priority']
        if tp == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
            sc_value += 10
        elif tp == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
            sc_value += 10

    for teacher_id, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    # FIX E: Post-assignment HC audit — scan `assignments` for any real
    # teacher or room conflicts that slipped through the repair phase.
    # This is the critical safety net that ensures hc_count can NEVER be 0
    # while the schedule contains genuine conflicts, so POA will always run
    # rather than exiting immediately on a false "perfect" solution.
    real_teacher_slots = {}   # (teacher, ts) → first course_i that claimed it
    real_room_slots    = {}   # (room, ts)    → first course_i that claimed it
    ghost_hc = 0

    for asgn in assignments:
        t1, t2 = asgn['start_slot'], asgn['end_slot']
        teacher, room = asgn['teacher'], asgn['room']

        for ts in (t1, t2):
            tk = (teacher, ts)
            if tk in real_teacher_slots:
                ghost_hc += 1   # teacher double-booked
            else:
                real_teacher_slots[tk] = asgn['course_i']

            rk = (room, ts)
            if rk in real_room_slots:
                ghost_hc += 1   # room double-booked
            else:
                real_room_slots[rk] = asgn['course_i']

    hc_count = len(still_unassigned) + ghost_hc

    fitness = hc_count * HC_WEIGHT + sc_value
    metrics = {
        'hc_count':      hc_count,
        'hc_value':      hc_count * HC_WEIGHT,
        'hc_unassigned': len(still_unassigned),
        'hc_ghost':      ghost_hc,
        'sc_count':      sc_count,
        'sc_value':      sc_value,
        'repaired':      len(unassigned_idxs) - len(still_unassigned),
    }
    return fitness, assignments, metrics


# ==========================================
# 3. Assignment Helper
# ==========================================
def _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
               assignments, room_time_booked, teacher_time_booked,
               teacher_day_rooms, teacher_ts_to_asgn,
               avail_prac, avail_theo, update_idx=None):
    room_time_booked.add((r, t1));          room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))

    # Update BOTH avail sets so a newly booked room is unavailable to either
    # type of course. The original code only pruned the same-type set; if a
    # room index appeared in both lists, the cross-type set would retain a
    # stale entry. Updating both is always correct.
    for _slot_list, _avail_set in [(PRAC_SLOTS, avail_prac), (THEO_SLOTS, avail_theo)]:
        for si2 in list(_avail_set):
            r2, s2 = _slot_list[si2]
            if r2 == r and (s2 == t1 or s2 == t2 or s2 + 1 == t1):
                _avail_set.discard(si2)

    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)

    asgn = {
        'course_i': int(idx), 'room': r,
        'start_slot': s, 'end_slot': t2,
        'teacher': teacher, 'priority': t_priority, 'day': day
    }

    if update_idx is not None:
        assignments[update_idx] = asgn
        teacher_ts_to_asgn[(teacher, t1)] = update_idx
        teacher_ts_to_asgn[(teacher, t2)] = update_idx
    else:
        new_idx = len(assignments)
        assignments.append(asgn)
        teacher_ts_to_asgn[(teacher, t1)] = new_idx
        teacher_ts_to_asgn[(teacher, t2)] = new_idx


def _eval_worker(x):
    return fitness_function(x)


# ==========================================
# 4. Solution Class
# ==========================================
class Solution:
    __slots__ = ('X', 'Cost', 'assignments', 'metrics')

    def __init__(self, x, cost, assignments=None, metrics=None):
        self.X           = x
        self.Cost        = cost
        self.assignments = assignments
        self.metrics     = metrics

    def clone(self):
        return Solution(self.X.copy(), self.Cost, self.assignments, self.metrics)


# ==========================================
# 5. Parallel Population Evaluator
# ==========================================
def parallel_eval(vectors, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), len(vectors))
    if n_workers <= 1 or len(vectors) <= 4:
        return [fitness_function(v) for v in vectors]
    results = [None] * len(vectors)
    with ProcessPoolExecutor(max_workers=n_workers) as pool:
        futures = {pool.submit(_eval_worker, v): i for i, v in enumerate(vectors)}
        for fut in as_completed(futures):
            results[futures[fut]] = fut.result()
    return results


# ==========================================
# 6. Puma Optimizer
# ==========================================
def print_iteration_log(Iter, Sol, Best, elapsed):
    worst_cost = max(s.Cost for s in Sol)
    m = Best.metrics
    print(
        f"Iter {Iter:03d} | Best: {Best.Cost:12.0f} | Worst: {worst_cost:12.0f} | "
        f"HC: {m['hc_count']:3d} (unassigned:{m['hc_unassigned']} ghost:{m['hc_ghost']}) | "
        f"Repaired: {m.get('repaired', 0):3d} | SC: {m['sc_value']:6.0f} | {elapsed:.1f}s"
    )


def exploration(Sol, lb, ub, dim, nSol, n_workers):
    pCR = 0.20
    PCR = 1 - pCR
    p   = PCR / nSol
    Sol.sort(key=lambda s: s.Cost)

    new_vectors = []
    for i in range(nSol):
        x = Sol[i].X
        A = list(range(nSol)); A.remove(i); np.random.shuffle(A)
        a, b, c, d, e, f = A[:6]
        G = 2 * np.random.rand() - 1
        if np.random.rand() < 0.5:
            y = np.random.rand(dim) * (ub - lb) + lb
        else:
            da = Sol[a].X - Sol[b].X
            db = Sol[c].X - Sol[d].X
            dc = Sol[e].X - Sol[f].X
            y  = Sol[a].X + G * da + G * ((da - db) + (db - dc))
        y  = np.clip(y, lb, ub)
        z  = x.copy()
        j0 = np.random.randint(dim)
        mask = (np.random.rand(dim) <= pCR)
        mask[j0] = True
        z[mask] = y[mask]
        new_vectors.append(z)

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
        else:
            pCR = pCR + p
    return Sol


def exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers):
    Q, Beta = 0.67, 2
    mbest   = np.mean([s.X for s in Sol], axis=0)

    new_vectors = []
    for i in range(nSol):
        beta1 = 2 * np.random.rand()
        beta2 = np.random.randn(dim)
        w, v  = np.random.randn(dim), np.random.randn(dim)
        F1    = np.random.randn(dim) * np.exp(2 - Iter * (2 / MaxIter))
        F2    = w * (v ** 2) * np.cos(2 * np.random.rand() * w)
        R_1   = 2 * np.random.rand() - 1
        S1    = (2 * np.random.rand() - 1 + np.random.randn(dim))
        S2    = F1 * R_1 * Sol[i].X + F2 * (1 - R_1) * Best.X
        VEC   = S2 / (S1 + 1e-10)

        if np.random.rand() <= 0.5:
            if np.random.rand() > Q:
                r_idx = np.random.randint(nSol)
                x_new = Best.X + beta1 * np.exp(beta2) * (Sol[r_idx].X - Sol[i].X)
            else:
                x_new = beta1 * VEC - Best.X
        else:
            r1    = np.random.randint(nSol)
            sign  = (-1) ** np.random.randint(0, 2)
            x_new = (mbest * Sol[r1].X - sign * Sol[i].X) / (1 + Beta * np.random.rand())

        new_vectors.append(np.clip(x_new, lb, ub))

    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
    return Sol


def run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), nSol)
    print(f"[INFO] Parallel workers : {n_workers}")
    print(f"[INFO] HC weight        : {HC_WEIGHT:,}")
    print(f"[INFO] Total courses    : {_N_COURSES}")

    print("\nMengevaluasi populasi inisial...")
    init_vectors    = [lb + (ub - lb) * np.random.rand(dim) for _ in range(nSol)]
    init_vectors[0] = np.full(dim, 0.5)

    results      = parallel_eval(init_vectors, n_workers)
    Sol          = [Solution(init_vectors[i], *results[i]) for i in range(nSol)]
    Best         = min(Sol, key=lambda s: s.Cost)
    Initial_Best = Best.clone()

    m = Best.metrics
    print(f"\nInitial Best  | Fitness: {Best.Cost:12.0f} | "
          f"HC: {m['hc_count']:3d} (unassigned:{m['hc_unassigned']} ghost:{m['hc_ghost']}) | "
          f"Repaired: {m.get('repaired', 0):3d} | SC: {m['sc_value']:.0f}")

    if Best.metrics['hc_count'] == 0:
        print("[INFO] Zero HC violations at initialisation — skipping optimisation.")
        return Best

    # ── PO state variables (UNCHANGED) ───────────────────────────────────────
    UnSelected = [1, 1]
    F3_Explore = F3_Exploit = 0
    Seq_Time_Explore  = [1, 1, 1];  Seq_Time_Exploit  = [1, 1, 1]
    Seq_Cost_Explore  = [1, 1, 1];  Seq_Cost_Exploit  = [1, 1, 1]
    PF            = [0.5, 0.5, 0.3]
    PF_F3         = []
    Mega_Explor   = Mega_Exploit = 0.99
    Costs_Explor  = np.zeros(3)
    Costs_Exploit = np.zeros(3)
    Flag_Change   = 1

    print("\n" + "=" * 100)
    print("MEMULAI PROSES OPTIMASI PUMA — CONFLICT-DIRECTED REPAIR (fixed)".center(100))
    print("=" * 100)

    t_start = time.perf_counter()

    for Iter in range(1, 4):
        Sol_E1 = exploration ([s.clone() for s in Sol], lb, ub, dim, nSol, n_workers)
        Sol_E2 = exploitation([s.clone() for s in Sol], lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
        Costs_Explor[Iter - 1]  = min(s.Cost for s in Sol_E1)
        Costs_Exploit[Iter - 1] = min(s.Cost for s in Sol_E2)

        merged = Sol + Sol_E1 + Sol_E2
        merged.sort(key=lambda s: s.Cost)
        Sol  = merged[:nSol]
        Best = Sol[0]
        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start)

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC achieved at bootstrap iteration {Iter}.")
            return Best

    Seq_Cost_Explore[0] = abs(Initial_Best.Cost  - Costs_Explor[0])
    Seq_Cost_Explore[1] = abs(Costs_Explor[1]    - Costs_Explor[0])
    Seq_Cost_Explore[2] = abs(Costs_Explor[2]    - Costs_Explor[1])
    Seq_Cost_Exploit[0] = abs(Initial_Best.Cost  - Costs_Exploit[0])
    Seq_Cost_Exploit[1] = abs(Costs_Exploit[1]   - Costs_Exploit[0])
    Seq_Cost_Exploit[2] = abs(Costs_Exploit[2]   - Costs_Exploit[1])

    for v in Seq_Cost_Explore + Seq_Cost_Exploit:
        if v != 0:
            PF_F3.append(v)

    stagnation = 0
    prev_best  = Best.Cost

    for Iter in range(4, MaxIter + 1):
        F1_Explor  = PF[0] * (Seq_Cost_Explore[0] / Seq_Time_Explore[0])
        F1_Exploit = PF[0] * (Seq_Cost_Exploit[0] / Seq_Time_Exploit[0])
        F2_Explor  = PF[1] * (sum(Seq_Cost_Explore) / sum(Seq_Time_Explore))
        F2_Exploit = PF[1] * (sum(Seq_Cost_Exploit) / sum(Seq_Time_Exploit))
        Score_Explore  = Mega_Explor  * (F1_Explor  + F2_Explor)
        Score_Exploit  = Mega_Exploit * (F1_Exploit + F2_Exploit)

        if Score_Explore > Score_Exploit:
            SelectFlag = 1
            Sol = exploration(Sol, lb, ub, dim, nSol, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[1] += 1;  UnSelected[0] = 1
            F3_Explore = PF[2];  F3_Exploit += PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Explore[2], Seq_Cost_Explore[1] = Seq_Cost_Explore[1], Seq_Cost_Explore[0]
            Seq_Cost_Explore[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Explore[0]:
                PF_F3.append(Seq_Cost_Explore[0])
        else:
            SelectFlag = 2
            Sol = exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[0] += 1;  UnSelected[1] = 1
            F3_Explore += PF[2];  F3_Exploit = PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Exploit[2], Seq_Cost_Exploit[1] = Seq_Cost_Exploit[1], Seq_Cost_Exploit[0]
            Seq_Cost_Exploit[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Exploit[0]:
                PF_F3.append(Seq_Cost_Exploit[0])

        if TBest.Cost < Best.Cost:
            Best = TBest

        if Flag_Change != SelectFlag:
            Flag_Change = SelectFlag
            Seq_Time_Explore[2], Seq_Time_Explore[1], Seq_Time_Explore[0] = \
                Seq_Time_Explore[1], Seq_Time_Explore[0], Count_select[0]
            Seq_Time_Exploit[2], Seq_Time_Exploit[1], Seq_Time_Exploit[0] = \
                Seq_Time_Exploit[1], Seq_Time_Exploit[0], Count_select[1]

        if Score_Explore < Score_Exploit:
            Mega_Explor  = max(Mega_Explor  - 0.01, 0.01)
            Mega_Exploit = 0.99
        else:
            Mega_Explor  = 0.99
            Mega_Exploit = max(Mega_Exploit - 0.01, 0.01)

        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start)

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC violations achieved at iteration {Iter}.")
            break

        if Best.Cost >= prev_best:
            stagnation += 1
        else:
            stagnation = 0
            prev_best  = Best.Cost

        if stagnation >= 10:
            print(f"[WARN] Stagnation at iter {Iter} — injecting diversity...")
            n_replace = nSol // 3
            new_vecs  = [lb + (ub - lb) * np.random.rand(dim) for _ in range(n_replace)]
            res       = parallel_eval(new_vecs, n_workers)
            for k, (c, a, met) in enumerate(res):
                Sol[-(k + 1)] = Solution(new_vecs[k], c, a, met)
            stagnation = 0

    print(f"\n[INFO] Optimasi selesai dalam {time.perf_counter() - t_start:.1f}s")
    return Best


# ==========================================
# 7. Eksekusi & Ekspor
# ==========================================
if __name__ == '__main__':
    nSol    = 50
    MaxIter = 100
    dim     = _N_COURSES
    lb, ub  = 0.0, 1.0

    t0 = time.perf_counter()
    best_solution = run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None)
    print(f"Total elapsed: {time.perf_counter() - t0:.1f}s")

    res_list = []
    for a in best_solution.assignments:
        course = mk_df_raw.iloc[a['course_i']]
        room   = rooms_df.iloc[a['room']]
        t1     = timeslots_df.iloc[a['start_slot']]
        t2     = timeslots_df.iloc[a['end_slot']]
        res_list.append({
            'event_id':    course['event_id'],
            'course_name': course['course_name'],
            'teacher_id':  course['teacher_id'],
            'room_id':     room['room_id'],
            'day':         t1['day'],
            'time_start':  t1['time_start'],
            'time_end':    t2['time_end'],
        })

    res_df   = pd.DataFrame(res_list)
    out_path = 'scheduled_courses_poa_v5.2_fixed.csv'
    res_df.to_csv(out_path, index=False)

    m = best_solution.metrics
    print(f"\n{'=' * 65}")
    print(f"  FINAL RESULT")
    print(f"  HC Violations  : {m['hc_count']}  (unassigned: {m['hc_unassigned']}, ghost: {m['hc_ghost']})")
    print(f"  HC Penalty     : {m['hc_value']:,}")
    print(f"  Repaired by P2 : {m.get('repaired', 0)}")
    print(f"  SC Violations  : {m['sc_count']}  (penalty: {m['sc_value']})")
    print(f"  Total Fitness  : {best_solution.Cost:,}")
    print(f"  Courses scheduled: {len(res_list)} / {_N_COURSES}")
    print(f"{'=' * 65}")
    print(f"[INFO] Solusi disimpan di '{out_path}'")
# Out:
# [INFO] Memuat dan memproses dataset...
# [INFO] Parallel workers : 8
# [INFO] HC weight        : 10,000,000
# [INFO] Total courses    : 725
#
# Mengevaluasi populasi inisial...
#
# Initial Best  | Fitness:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC: 2530
#
# ====================================================================================================
#                   MEMULAI PROSES OPTIMASI PUMA — CONFLICT-DIRECTED REPAIR (fixed)
# ====================================================================================================
# Iter 001 | Best:    230002470 | Worst:    230004480 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2470 | 67.1s
# Iter 002 | Best:    230002420 | Worst:    230002720 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2420 | 134.0s
# Iter 003 | Best:    230002410 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2410 | 202.1s
# Iter 004 | Best:    230002410 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2410 | 236.7s
# Iter 005 | Best:    230002410 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2410 | 271.1s
# Iter 006 | Best:    230002410 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2410 | 305.4s
# Iter 007 | Best:    230002410 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2410 | 339.7s
# Iter 008 | Best:    230002410 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2410 | 374.0s
# Iter 009 | Best:    230002410 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2410 | 408.6s
# Iter 010 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 442.8s
# Iter 011 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 477.0s
# Iter 012 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 510.8s
# Iter 013 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 545.1s
# Iter 014 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 578.9s
# Iter 015 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 613.2s
# Iter 016 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 647.4s
# Iter 017 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 681.7s
# Iter 018 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 715.7s
# Iter 019 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 750.5s
# Iter 020 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 785.2s
# [WARN] Stagnation at iter 20 — injecting diversity...
# Iter 021 | Best:    230002400 | Worst:    230004970 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 830.7s
# Iter 022 | Best:    230002400 | Worst:    230003520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 864.9s
# Iter 023 | Best:    230002400 | Worst:    230002620 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 897.4s
# Iter 024 | Best:    230002400 | Worst:    230002620 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 930.4s
# Iter 025 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 963.6s
# Iter 026 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 995.9s
# Iter 027 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1028.3s
# Iter 028 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1060.8s
# Iter 029 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1093.9s
# Iter 030 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1126.8s
# [WARN] Stagnation at iter 30 — injecting diversity...
# Iter 031 | Best:    230002400 | Worst:    230004610 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1170.5s
# Iter 032 | Best:    230002400 | Worst:    230003780 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1203.4s
# Iter 033 | Best:    230002400 | Worst:    230003240 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1235.6s
# Iter 034 | Best:    230002400 | Worst:    230002760 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1268.0s
# Iter 035 | Best:    230002400 | Worst:    230002590 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1300.7s
# Iter 036 | Best:    230002400 | Worst:    230002540 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1333.2s
# Iter 037 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1365.9s
# Iter 038 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1398.8s
# Iter 039 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1431.3s
# Iter 040 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1464.1s
# [WARN] Stagnation at iter 40 — injecting diversity...
# Iter 041 | Best:    230002400 | Worst:    230004060 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1507.4s
# Iter 042 | Best:    230002400 | Worst:    230003560 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1540.2s
# Iter 043 | Best:    230002400 | Worst:    230003460 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1572.7s
# Iter 044 | Best:    230002400 | Worst:    230003460 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1605.0s
# Iter 045 | Best:    230002400 | Worst:    230002580 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1637.7s
# Iter 046 | Best:    230002400 | Worst:    230002540 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1670.6s
# Iter 047 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1703.4s
# Iter 048 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1735.9s
# Iter 049 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1766.6s
# Iter 050 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1795.8s
# [WARN] Stagnation at iter 50 — injecting diversity...
# Iter 051 | Best:    230002400 | Worst:    230004180 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1834.6s
# Iter 052 | Best:    230002400 | Worst:    230003330 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1864.0s
# Iter 053 | Best:    230002400 | Worst:    230002820 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1893.1s
# Iter 054 | Best:    230002400 | Worst:    230002820 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1922.4s
# Iter 055 | Best:    230002400 | Worst:    230002780 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1951.7s
# Iter 056 | Best:    230002400 | Worst:    230002570 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 1981.3s
# Iter 057 | Best:    230002400 | Worst:    230002570 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2014.6s
# Iter 058 | Best:    230002400 | Worst:    230002570 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2052.0s
# Iter 059 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2087.9s
# Iter 060 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2123.3s
# [WARN] Stagnation at iter 60 — injecting diversity...
# Iter 061 | Best:    230002400 | Worst:    230004360 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2169.4s
# Iter 062 | Best:    230002400 | Worst:    230004140 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2207.6s
# Iter 063 | Best:    230002400 | Worst:    230002590 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2247.8s
# Iter 064 | Best:    230002400 | Worst:    230002590 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2287.4s
# Iter 065 | Best:    230002400 | Worst:    230002590 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2327.6s
# Iter 066 | Best:    230002400 | Worst:    230002560 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2368.3s
# Iter 067 | Best:    230002400 | Worst:    230002550 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2408.0s
# Iter 068 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2448.1s
# Iter 069 | Best:    230002400 | Worst:    230002510 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2486.8s
# Iter 070 | Best:    230002400 | Worst:    230002480 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2525.3s
# [WARN] Stagnation at iter 70 — injecting diversity...
# Iter 071 | Best:    230002400 | Worst:    230004720 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2577.1s
# Iter 072 | Best:    230002400 | Worst:    230003230 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2615.6s
# Iter 073 | Best:    230002400 | Worst:    230002790 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2654.5s
# Iter 074 | Best:    230002400 | Worst:    230002660 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2693.8s
# Iter 075 | Best:    230002400 | Worst:    230002600 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2730.1s
# Iter 076 | Best:    230002400 | Worst:    230002570 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2763.8s
# Iter 077 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2799.7s
# Iter 078 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2834.0s
# Iter 079 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2867.3s
# Iter 080 | Best:    230002400 | Worst:    230002520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2900.9s
# [WARN] Stagnation at iter 80 — injecting diversity...
# Iter 081 | Best:    230002400 | Worst:    230004680 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2944.8s
# Iter 082 | Best:    230002400 | Worst:    230003520 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 2977.7s
# Iter 083 | Best:    230002400 | Worst:    230002730 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3010.9s
# Iter 084 | Best:    230002400 | Worst:    230002640 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3044.3s
# Iter 085 | Best:    230002400 | Worst:    230002580 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3084.8s
# Iter 086 | Best:    230002400 | Worst:    230002580 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3118.6s
# Iter 087 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3151.1s
# Iter 088 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3184.1s
# Iter 089 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3216.6s
# Iter 090 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3249.4s
# [WARN] Stagnation at iter 90 — injecting diversity...
# Iter 091 | Best:    230002400 | Worst:    230004930 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3293.7s
# Iter 092 | Best:    230002400 | Worst:    230003650 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3326.2s
# Iter 093 | Best:    230002400 | Worst:    230002930 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3365.8s
# Iter 094 | Best:    230002400 | Worst:    230002670 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3398.7s
# Iter 095 | Best:    230002400 | Worst:    230002560 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3431.5s
# Iter 096 | Best:    230002400 | Worst:    230002560 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3464.5s
# Iter 097 | Best:    230002400 | Worst:    230002560 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3497.7s
# Iter 098 | Best:    230002400 | Worst:    230002540 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3530.3s
# Iter 099 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3563.3s
# Iter 100 | Best:    230002400 | Worst:    230002530 | HC:  23 (unassigned:23 ghost:0) | Repaired:   0 | SC:   2400 | 3598.0s
# [WARN] Stagnation at iter 100 — injecting diversity...
#
# [INFO] Optimasi selesai dalam 3609.4s
# Total elapsed: 3638.1s
#
# =================================================================
#   FINAL RESULT
#   HC Violations  : 23  (unassigned: 23, ghost: 0)
#   HC Penalty     : 230,000,000
#   Repaired by P2 : 0
#   SC Violations  : 1  (penalty: 2400)
#   Total Fitness  : 230,002,400
#   Courses scheduled: 702 / 725
# =================================================================
# [INFO] Solusi disimpan di 'scheduled_courses_poa_v5.2_fixed.csv'

# %% [markdown]
# ### Update POA Optimizing Mechanism

# %%
import numpy as np
import pandas as pd
import time
import math
from concurrent.futures import ProcessPoolExecutor, as_completed
import os

# ==========================================
# 1. Deklarasi & Persiapan Dataset
# ==========================================
print("[INFO] Memuat dan memproses dataset...")
mk_df_raw = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_ganjil_praktikum_processed_v1.csv')
rooms_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv')
timeslots_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv')

valid_starts = [
    i for i in range(len(timeslots_df) - 1)
    if (timeslots_df.iloc[i]['day'] == timeslots_df.iloc[i + 1]['day'] and
        timeslots_df.iloc[i]['time_end'] == timeslots_df.iloc[i + 1]['time_start'])
]

rooms_prac = rooms_df[rooms_df['is_practicum'] == True].index.tolist()
rooms_theo = rooms_df[rooms_df['is_theory'] == True].index.tolist()

teacher_workload = mk_df_raw['teacher_id'].value_counts().to_dict()
mk_df_raw['teacher_degree'] = mk_df_raw['teacher_id'].map(teacher_workload)

PRAC_SLOTS = [(r, s) for r in rooms_prac for s in valid_starts]
THEO_SLOTS = [(r, s) for r in rooms_theo for s in valid_starts]

_REQ_PRAC   = mk_df_raw['requires_practicum_room'].to_numpy()
_TEACHER    = mk_df_raw['teacher_id'].to_numpy()
_T_PRIORITY = mk_df_raw['teacher_priority'].to_numpy()
_T_DEGREE   = mk_df_raw['teacher_degree'].to_numpy()
_TS_DAY     = timeslots_df['day'].to_numpy()
_TS_SESSION = timeslots_df['session_type'].to_numpy()
_N_COURSES  = len(mk_df_raw)

SESSION_MORNING   = (_TS_SESSION == 'Morning')
SESSION_AFTERNOON = (_TS_SESSION == 'Afternoon')

HC_WEIGHT = 10_000_000


# ==========================================
# 2. Levy Flight Helper
# ==========================================
def levy_flight(dim, beta=1.5):
    """
    Generate a Levy flight step vector (heavy-tailed distribution).

    Levy flight produces occasional large jumps alongside many small steps,
    which is ideal for escaping deep local optima. `beta` controls tail
    heaviness; 1.5 is a well-tested default for meta-heuristic optimizers.
    """
    sigma = (
        math.gamma(1 + beta) * math.sin(math.pi * beta / 2) /
        (math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))
    ) ** (1 / beta)
    u = np.random.randn(dim) * sigma
    v = np.abs(np.random.randn(dim)) + 1e-10
    step = u / (v ** (1 / beta))
    return step


# ==========================================
# 3. Fitness Function
# ==========================================
def fitness_function(sol_x):
    """
    Three-phase decoder with two-level conflict-directed repair.

    PHASE 1 — Greedy assignment (Most-Constrained-First + PO key ordering)
    PHASE 2 — Conflict-Directed Repair
      Level 1 (L1): Single-blocker swap — blocker owns BOTH t1 and t2 (same course)
      Level 2 (L2): Double-blocker chain — DIFFERENT courses own t1 and t2;
                    try to relocate BOTH simultaneously.
                    ── Why L2 was missing and why it caused Repaired=0 ──────────
                    FIX B (previous version) correctly skipped double-blocker slots
                    to prevent ghost conflicts.  But for overloaded teachers, every
                    timeslot pair is double-blocked by different back-to-back courses,
                    so FIX B caused ALL repair attempts to be skipped → Repaired=0
                    every iteration → POA had nothing to improve → total stagnation.
                    L2 resolves this by relocating both blockers atomically.
    PHASE 3 — SC evaluation + HC audit (ghost-conflict safety net)
    """
    hc_count = 0
    sc_value = 0
    sc_count = 0
    assignments     = []
    unassigned_idxs = []

    room_time_booked    = set()
    teacher_time_booked = set()
    teacher_day_rooms   = {}
    teacher_ts_to_asgn  = {}

    avail_prac = set(range(len(PRAC_SLOTS)))
    avail_theo = set(range(len(THEO_SLOTS)))

    # ── MCF + PO random-key ordering ─────────────────────────────────────────
    base_scores = (_REQ_PRAC.astype(float) * 1000) + (_T_DEGREE * 10)
    priorities  = base_scores + (sol_x * 100)
    queue_order = np.argsort(-priorities)

    # =========================================================================
    # PHASE 1 — GREEDY ASSIGNMENT
    # =========================================================================
    for idx in queue_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])
        slot_list  = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set  = avail_prac  if req_prac else avail_theo

        hc_fallback    = None
        best_sc        = float('inf')
        best_slot_info = None
        sc_scan_count  = 0

        for si in list(avail_set):
            r, s = slot_list[si]
            t1, t2 = s, s + 1

            # Defensive room guard (FIX A)
            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                avail_set.discard(si)
                continue
            if (teacher, t1) in teacher_time_booked or (teacher, t2) in teacher_time_booked:
                continue

            if hc_fallback is None:
                hc_fallback = (r, s, _TS_DAY[s], t1, t2, si)

            day    = _TS_DAY[s]
            temp_sc = 0
            if t_priority == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
                temp_sc += 10
            elif t_priority == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
                temp_sc += 10
            if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
                if r not in teacher_day_rooms[teacher][day]:
                    temp_sc += 50

            if temp_sc < best_sc:
                best_sc        = temp_sc
                best_slot_info = (r, s, day, t1, t2, si)
                if temp_sc == 0:
                    break
            sc_scan_count += 1
            if sc_scan_count >= 50:
                break

        chosen = best_slot_info if best_slot_info is not None else hc_fallback
        if chosen is not None:
            r, s, day, t1, t2, si = chosen
            _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                       assignments, room_time_booked, teacher_time_booked,
                       teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
        else:
            unassigned_idxs.append(int(idx))

    # =========================================================================
    # PHASE 2 — CONFLICT-DIRECTED REPAIR (L1 + L2)
    # =========================================================================
    still_unassigned = []

    # Scan cap per level to keep O(n) per unassigned course
    L1_SCAN_LIMIT = 200
    L2_SCAN_LIMIT = 150

    for idx in unassigned_idxs:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])
        slot_list  = PRAC_SLOTS if req_prac else THEO_SLOTS
        placed     = False

        # ─── LEVEL 1: Single-blocker swap ─────────────────────────────────────
        # Same blocker owns BOTH t1 and t2. Relocate it and place current course.
        l1_count = 0
        for r, s in slot_list:
            if l1_count >= L1_SCAN_LIMIT:
                break
            t1, t2 = s, s + 1

            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                continue

            blocked_t1 = (teacher, t1) in teacher_time_booked
            blocked_t2 = (teacher, t2) in teacher_time_booked

            # Direct assign (safety net)
            if not blocked_t1 and not blocked_t2:
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                placed = True
                break

            # L1 only handles single-blocker (same course owns both t1 and t2)
            if blocked_t1 and blocked_t2:
                b1_i = teacher_ts_to_asgn.get((teacher, t1))
                b2_i = teacher_ts_to_asgn.get((teacher, t2))
                if b1_i != b2_i:
                    l1_count += 1
                    continue      # ← double-blocker: skip L1, handled by L2
                blocker_key = (teacher, t1)
            else:
                blocker_key = (teacher, t1) if blocked_t1 else (teacher, t2)

            blocker_asgn_idx = teacher_ts_to_asgn.get(blocker_key)
            if blocker_asgn_idx is None:
                l1_count += 1
                continue

            blocker   = assignments[blocker_asgn_idx]
            b_idx     = blocker['course_i']
            b_rp      = bool(_REQ_PRAC[b_idx])
            b_teacher = blocker['teacher']
            b_t1_old  = blocker['start_slot']
            b_t2_old  = blocker['end_slot']
            b_r_old   = blocker['room']
            b_prio    = blocker['priority']
            b_day_old = blocker['day']

            # Temporarily unbook blocker
            _unbook(blocker_asgn_idx, b_r_old, b_t1_old, b_t2_old,
                    b_teacher, b_day_old, b_rp,
                    room_time_booked, teacher_time_booked,
                    teacher_day_rooms, teacher_ts_to_asgn,
                    avail_prac, avail_theo)

            # Search relocation slot for blocker (exclude current target)
            reloc = _find_reloc(b_idx, b_teacher, b_rp,
                                exclude_r=r, exclude_s=s,
                                room_time_booked=room_time_booked,
                                teacher_time_booked=teacher_time_booked,
                                avail_prac=avail_prac, avail_theo=avail_theo)

            if reloc is not None:
                r2, s2, day2, t1n, t2n, si2 = reloc
                _do_assign(b_idx, r2, s2, day2, t1n, t2n, b_prio, b_teacher, b_rp,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=blocker_asgn_idx)

                # Re-verify target (FIX D)
                day = _TS_DAY[s]
                if ((teacher, t1) not in teacher_time_booked and
                        (teacher, t2) not in teacher_time_booked and
                        (r, t1) not in room_time_booked and
                        (r, t2) not in room_time_booked):
                    _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                               assignments, room_time_booked, teacher_time_booked,
                               teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                    placed = True
                    break
                # else: blocker moved but slot invalidated — keep blocker's new slot, continue
            else:
                # Restore blocker
                _rebook(blocker_asgn_idx, b_r_old, b_t1_old, b_t2_old,
                        b_teacher, b_day_old, b_rp,
                        room_time_booked, teacher_time_booked,
                        teacher_day_rooms, teacher_ts_to_asgn,
                        avail_prac, avail_theo)

            l1_count += 1

        # ─── LEVEL 2: Double-blocker chain swap ───────────────────────────────
        # DIFFERENT courses own t1 (→ B1) and t2 (→ B2).
        # Try to relocate B1 and B2 simultaneously to free the slot.
        # This is the fix for the Repaired=0 stagnation caused by FIX B
        # skipping all double-blocked slots.
        if not placed:
            l2_count = 0
            for r, s in slot_list:
                if l2_count >= L2_SCAN_LIMIT:
                    break
                t1, t2 = s, s + 1

                if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                    continue

                b1_asgn_idx = teacher_ts_to_asgn.get((teacher, t1))
                b2_asgn_idx = teacher_ts_to_asgn.get((teacher, t2))

                # L2 only handles double-blocker with two distinct assignments
                if (b1_asgn_idx is None or b2_asgn_idx is None or
                        b1_asgn_idx == b2_asgn_idx):
                    continue

                l2_count += 1

                b1 = assignments[b1_asgn_idx]
                b2 = assignments[b2_asgn_idx]

                b1_idx, b1_rp = b1['course_i'], bool(_REQ_PRAC[b1['course_i']])
                b1_teacher, b1_t1, b1_t2 = b1['teacher'], b1['start_slot'], b1['end_slot']
                b1_r, b1_prio, b1_day    = b1['room'],    b1['priority'],  b1['day']

                b2_idx, b2_rp = b2['course_i'], bool(_REQ_PRAC[b2['course_i']])
                b2_teacher, b2_t1, b2_t2 = b2['teacher'], b2['start_slot'], b2['end_slot']
                b2_r, b2_prio, b2_day    = b2['room'],    b2['priority'],  b2['day']

                # Step 1: Temporarily unbook B1
                _unbook(b1_asgn_idx, b1_r, b1_t1, b1_t2,
                        b1_teacher, b1_day, b1_rp,
                        room_time_booked, teacher_time_booked,
                        teacher_day_rooms, teacher_ts_to_asgn,
                        avail_prac, avail_theo)

                # Step 2: Find relocation for B1 (exclude target and B2 area)
                b1_reloc = _find_reloc(b1_idx, b1_teacher, b1_rp,
                                       exclude_r=r, exclude_s=s,
                                       exclude_r2=b2_r, exclude_s2=b2_t1,
                                       room_time_booked=room_time_booked,
                                       teacher_time_booked=teacher_time_booked,
                                       avail_prac=avail_prac, avail_theo=avail_theo)

                if b1_reloc is None:
                    _rebook(b1_asgn_idx, b1_r, b1_t1, b1_t2,
                            b1_teacher, b1_day, b1_rp,
                            room_time_booked, teacher_time_booked,
                            teacher_day_rooms, teacher_ts_to_asgn,
                            avail_prac, avail_theo)
                    continue

                # Step 3: Temporarily unbook B2
                _unbook(b2_asgn_idx, b2_r, b2_t1, b2_t2,
                        b2_teacher, b2_day, b2_rp,
                        room_time_booked, teacher_time_booked,
                        teacher_day_rooms, teacher_ts_to_asgn,
                        avail_prac, avail_theo)

                # Step 4: Find relocation for B2 (exclude target, B1's original, B1's new slot)
                r1n, s1n = b1_reloc[0], b1_reloc[1]
                b2_reloc = _find_reloc(b2_idx, b2_teacher, b2_rp,
                                       exclude_r=r,   exclude_s=s,
                                       exclude_r2=r1n, exclude_s2=s1n,
                                       room_time_booked=room_time_booked,
                                       teacher_time_booked=teacher_time_booked,
                                       avail_prac=avail_prac, avail_theo=avail_theo)

                if b2_reloc is None:
                    # Restore both
                    _rebook(b2_asgn_idx, b2_r, b2_t1, b2_t2,
                            b2_teacher, b2_day, b2_rp,
                            room_time_booked, teacher_time_booked,
                            teacher_day_rooms, teacher_ts_to_asgn,
                            avail_prac, avail_theo)
                    _rebook(b1_asgn_idx, b1_r, b1_t1, b1_t2,
                            b1_teacher, b1_day, b1_rp,
                            room_time_booked, teacher_time_booked,
                            teacher_day_rooms, teacher_ts_to_asgn,
                            avail_prac, avail_theo)
                    continue

                # Step 5: Both relocations found — commit atomically
                r1n, s1n, d1n, t1_b1n, t2_b1n, si1n = b1_reloc
                _do_assign(b1_idx, r1n, s1n, d1n, t1_b1n, t2_b1n, b1_prio, b1_teacher, b1_rp,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=b1_asgn_idx)

                r2n, s2n, d2n, t1_b2n, t2_b2n, si2n = b2_reloc
                _do_assign(b2_idx, r2n, s2n, d2n, t1_b2n, t2_b2n, b2_prio, b2_teacher, b2_rp,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=b2_asgn_idx)

                # Step 6: Verify target slot is now clear (re-verify after commits)
                day = _TS_DAY[s]
                if ((teacher, t1) not in teacher_time_booked and
                        (teacher, t2) not in teacher_time_booked and
                        (r, t1) not in room_time_booked and
                        (r, t2) not in room_time_booked):
                    _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                               assignments, room_time_booked, teacher_time_booked,
                               teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                    placed = True
                    break
                # else: B1 and B2 moves stand, slot still invalid — continue search

        if not placed:
            still_unassigned.append(idx)

    # =========================================================================
    # PHASE 3 — SC EVALUATION + HC AUDIT
    # =========================================================================
    for asgn in assignments:
        t1 = asgn['start_slot']
        t2 = asgn['end_slot']
        tp = asgn['priority']
        if tp == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
            sc_value += 10
        elif tp == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
            sc_value += 10

    for teacher_id, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    # Ghost-conflict safety net (FIX E): scan assignments for real teacher/room conflicts
    real_teacher_slots = {}
    real_room_slots    = {}
    ghost_hc = 0
    for asgn in assignments:
        t1, t2   = asgn['start_slot'], asgn['end_slot']
        teacher  = asgn['teacher']
        room     = asgn['room']
        for ts in (t1, t2):
            tk = (teacher, ts)
            if tk in real_teacher_slots:
                ghost_hc += 1
            else:
                real_teacher_slots[tk] = asgn['course_i']
            rk = (room, ts)
            if rk in real_room_slots:
                ghost_hc += 1
            else:
                real_room_slots[rk] = asgn['course_i']

    hc_count = len(still_unassigned) + ghost_hc
    fitness  = hc_count * HC_WEIGHT + sc_value
    metrics  = {
        'hc_count':      hc_count,
        'hc_value':      hc_count * HC_WEIGHT,
        'hc_unassigned': len(still_unassigned),
        'hc_ghost':      ghost_hc,
        'sc_count':      sc_count,
        'sc_value':      sc_value,
        'repaired':      len(unassigned_idxs) - len(still_unassigned),
        'stuck_indices': list(still_unassigned),   # ← used by adaptive POA
    }
    return fitness, assignments, metrics


# ==========================================
# 4. Phase 2 Helper Functions
# ==========================================
def _unbook(asgn_idx, r, t1, t2, teacher, day, req_prac,
            room_time_booked, teacher_time_booked,
            teacher_day_rooms, teacher_ts_to_asgn,
            avail_prac, avail_theo):
    """Remove a single assignment from all booking structures."""
    room_time_booked.discard((r, t1));      room_time_booked.discard((r, t2))
    teacher_time_booked.discard((teacher, t1)); teacher_time_booked.discard((teacher, t2))
    teacher_ts_to_asgn.pop((teacher, t1), None)
    teacher_ts_to_asgn.pop((teacher, t2), None)
    if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
        try:
            teacher_day_rooms[teacher][day].remove(r)
        except ValueError:
            pass
        if not teacher_day_rooms[teacher][day]:
            del teacher_day_rooms[teacher][day]
    # Re-add room slot to availability
    slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
    avail_set = avail_prac  if req_prac else avail_theo
    try:
        si = slot_list.index((r, t1))
        avail_set.add(si)
    except ValueError:
        pass


def _rebook(asgn_idx, r, t1, t2, teacher, day, req_prac,
            room_time_booked, teacher_time_booked,
            teacher_day_rooms, teacher_ts_to_asgn,
            avail_prac, avail_theo):
    """Restore a temporarily unbooked assignment to all booking structures."""
    room_time_booked.add((r, t1));      room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))
    teacher_ts_to_asgn[(teacher, t1)] = asgn_idx
    teacher_ts_to_asgn[(teacher, t2)] = asgn_idx
    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)
    # Remove from availability
    slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
    avail_set = avail_prac  if req_prac else avail_theo
    try:
        si = slot_list.index((r, t1))
        avail_set.discard(si)
    except ValueError:
        pass


def _find_reloc(b_idx, b_teacher, b_req_prac,
                exclude_r, exclude_s,
                room_time_booked, teacher_time_booked,
                avail_prac, avail_theo,
                exclude_r2=None, exclude_s2=None,
                limit=120):
    """
    Find the first available slot for course b_idx (teacher b_teacher, type b_req_prac)
    that does not overlap with the exclusion zones (the course we're trying to place,
    and optionally a second course's slot).
    """
    slot_list = PRAC_SLOTS if b_req_prac else THEO_SLOTS
    avail_set = avail_prac  if b_req_prac else avail_theo
    count = 0
    for si in list(avail_set):
        if count >= limit:
            break
        r2, s2 = slot_list[si]
        t1n, t2n = s2, s2 + 1

        # Exclude the target course's slot
        if r2 == exclude_r and (abs(s2 - exclude_s) <= 1):
            continue
        # Exclude the second blocker's slot (for L2)
        if exclude_r2 is not None and r2 == exclude_r2 and (abs(s2 - exclude_s2) <= 1):
            continue

        if (r2, t1n) in room_time_booked or (r2, t2n) in room_time_booked:
            count += 1
            continue
        if (b_teacher, t1n) in teacher_time_booked or (b_teacher, t2n) in teacher_time_booked:
            continue
        return (r2, s2, _TS_DAY[s2], t1n, t2n, si)
    return None


# ==========================================
# 5. Assignment Helper
# ==========================================
def _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
               assignments, room_time_booked, teacher_time_booked,
               teacher_day_rooms, teacher_ts_to_asgn,
               avail_prac, avail_theo, update_idx=None):
    room_time_booked.add((r, t1));          room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))

    # Prune BOTH avail sets (not just same-type) to prevent cross-type stale entries
    for _sl, _av in [(PRAC_SLOTS, avail_prac), (THEO_SLOTS, avail_theo)]:
        for si2 in list(_av):
            r2, s2 = _sl[si2]
            if r2 == r and (s2 == t1 or s2 == t2 or s2 + 1 == t1):
                _av.discard(si2)

    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)

    asgn = {'course_i': int(idx), 'room': r, 'start_slot': s, 'end_slot': t2,
            'teacher': teacher, 'priority': t_priority, 'day': day}

    if update_idx is not None:
        assignments[update_idx] = asgn
        teacher_ts_to_asgn[(teacher, t1)] = update_idx
        teacher_ts_to_asgn[(teacher, t2)] = update_idx
    else:
        new_idx = len(assignments)
        assignments.append(asgn)
        teacher_ts_to_asgn[(teacher, t1)] = new_idx
        teacher_ts_to_asgn[(teacher, t2)] = new_idx


def _eval_worker(x):
    return fitness_function(x)


# ==========================================
# 6. Solution Class
# ==========================================
class Solution:
    __slots__ = ('X', 'Cost', 'assignments', 'metrics')

    def __init__(self, x, cost, assignments=None, metrics=None):
        self.X = x;  self.Cost = cost
        self.assignments = assignments;  self.metrics = metrics

    def clone(self):
        return Solution(self.X.copy(), self.Cost, self.assignments, self.metrics)


# ==========================================
# 7. Parallel Evaluator
# ==========================================
def parallel_eval(vectors, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), len(vectors))
    if n_workers <= 1 or len(vectors) <= 4:
        return [fitness_function(v) for v in vectors]
    results = [None] * len(vectors)
    with ProcessPoolExecutor(max_workers=n_workers) as pool:
        futures = {pool.submit(_eval_worker, v): i for i, v in enumerate(vectors)}
        for fut in as_completed(futures):
            results[futures[fut]] = fut.result()
    return results


# ==========================================
# 8. POA Operators (mechanism unchanged)
# ==========================================
def exploration(Sol, lb, ub, dim, nSol, n_workers):
    pCR = 0.20
    PCR = 1 - pCR
    p   = PCR / nSol
    Sol.sort(key=lambda s: s.Cost)
    new_vectors = []
    for i in range(nSol):
        x = Sol[i].X
        A = list(range(nSol)); A.remove(i); np.random.shuffle(A)
        a, b, c, d, e, f = A[:6]
        G = 2 * np.random.rand() - 1
        if np.random.rand() < 0.5:
            y = np.random.rand(dim) * (ub - lb) + lb
        else:
            da = Sol[a].X - Sol[b].X
            db = Sol[c].X - Sol[d].X
            dc = Sol[e].X - Sol[f].X
            y  = Sol[a].X + G * da + G * ((da - db) + (db - dc))
        y = np.clip(y, lb, ub)
        z = x.copy()
        j0 = np.random.randint(dim)
        mask = (np.random.rand(dim) <= pCR); mask[j0] = True
        z[mask] = y[mask]
        new_vectors.append(z)
    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
        else:
            pCR = pCR + p
    return Sol


def exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers):
    Q, Beta = 0.67, 2
    mbest = np.mean([s.X for s in Sol], axis=0)
    new_vectors = []
    for i in range(nSol):
        beta1 = 2 * np.random.rand()
        beta2 = np.random.randn(dim)
        w, v  = np.random.randn(dim), np.random.randn(dim)
        F1 = np.random.randn(dim) * np.exp(2 - Iter * (2 / MaxIter))
        F2 = w * (v ** 2) * np.cos(2 * np.random.rand() * w)
        R_1 = 2 * np.random.rand() - 1
        S1  = (2 * np.random.rand() - 1 + np.random.randn(dim))
        S2  = F1 * R_1 * Sol[i].X + F2 * (1 - R_1) * Best.X
        VEC = S2 / (S1 + 1e-10)
        if np.random.rand() <= 0.5:
            if np.random.rand() > Q:
                r_idx = np.random.randint(nSol)
                x_new = Best.X + beta1 * np.exp(beta2) * (Sol[r_idx].X - Sol[i].X)
            else:
                x_new = beta1 * VEC - Best.X
        else:
            r1   = np.random.randint(nSol)
            sign = (-1) ** np.random.randint(0, 2)
            x_new = (mbest * Sol[r1].X - sign * Sol[i].X) / (1 + Beta * np.random.rand())
        new_vectors.append(np.clip(x_new, lb, ub))
    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
    return Sol


# ==========================================
# 9. Adaptive Strategies
# ==========================================
def make_targeted_seed(stuck_indices, dim, lb, ub, best_x=None):
    """
    Create a new solution vector that gives maximum priority to stuck courses.
    Stuck courses get sol_x values near 1.0 so they are processed first in
    Phase 1, giving them first pick of available slots.
    Non-stuck courses inherit the best-known values (or random if no best_x).
    """
    x = best_x.copy() if best_x is not None else lb + (ub - lb) * np.random.rand(dim)
    for idx in stuck_indices:
        if idx < dim:
            # Push stuck courses to top of queue (high priority = near 1.0)
            x[idx] = 0.9 + np.random.rand() * 0.1
    return np.clip(x, lb, ub)


def levy_perturbation(x, lb, ub, scale=0.1):
    """Apply a Levy-flight perturbation to solution vector x."""
    step = levy_flight(len(x)) * scale
    return np.clip(x + step * (ub - lb), lb, ub)


def adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                  stuck_indices, stagnation_hc, n_workers):
    """
    Three-tier adaptive recovery based on HC-stagnation depth.

    Tier 1 (stagnation_hc 5–14):
      Targeted perturbation — push stuck course indices to top priority
      in the bottom third of the population.

    Tier 2 (stagnation_hc 15–29):
      Levy flight + targeted seeds. Replace bottom half. Injects heavy-tailed
      jumps so the optimizer can escape deep local optima basins.

    Tier 3 (stagnation_hc ≥ 30):
      Full adaptive restart. Keep top 20% (elitism). Rebuild remaining 80%
      with a mix of: targeted seeds (40%), Levy-perturbed best (20%),
      pure random (20%). Reset stagnation counter externally.
    """
    Sol.sort(key=lambda s: s.Cost)
    new_vecs = []
    indices  = []

    if stagnation_hc < 15:
        # Tier 1: targeted perturbation of bottom third
        n_replace = nSol // 3
        for k in range(n_replace):
            x = make_targeted_seed(stuck_indices, dim, lb, ub,
                                   best_x=Sol[-(k + 1)].X)
            new_vecs.append(x)
            indices.append(nSol - 1 - k)

    elif stagnation_hc < 30:
        # Tier 2: Levy flight + targeted seeds for bottom half
        n_replace = nSol // 2
        for k in range(n_replace):
            if k % 2 == 0:
                x = make_targeted_seed(stuck_indices, dim, lb, ub, best_x=Best.X)
                x = levy_perturbation(x, lb, ub, scale=0.15)
            else:
                x = levy_perturbation(Best.X, lb, ub, scale=0.25)
                for idx in stuck_indices:
                    if idx < dim:
                        x[idx] = np.clip(x[idx] + 0.4, lb, ub)
            new_vecs.append(x)
            indices.append(nSol - 1 - k)

    else:
        # Tier 3: Full adaptive restart — keep top 20%, rebuild rest
        n_keep = max(1, nSol // 5)
        n_replace = nSol - n_keep
        n_targeted = n_replace * 2 // 5
        n_levy     = n_replace // 5
        n_random   = n_replace - n_targeted - n_levy

        for k in range(n_targeted):
            x = make_targeted_seed(stuck_indices, dim, lb, ub, best_x=Best.X)
            x = levy_perturbation(x, lb, ub, scale=0.05)
            new_vecs.append(x)
            indices.append(n_keep + k)

        for k in range(n_levy):
            x = levy_perturbation(Best.X, lb, ub, scale=0.35)
            new_vecs.append(x)
            indices.append(n_keep + n_targeted + k)

        for k in range(n_random):
            x = lb + (ub - lb) * np.random.rand(dim)
            new_vecs.append(x)
            indices.append(n_keep + n_targeted + n_levy + k)

    if not new_vecs:
        return Sol

    results = parallel_eval(new_vecs, n_workers)
    for pos, (cost, asg, met) in zip(indices, results):
        Sol[pos] = Solution(new_vecs[indices.index(pos)], cost, asg, met)

    return Sol


# ==========================================
# 10. Logging
# ==========================================
def print_iteration_log(Iter, Sol, Best, elapsed, tag=''):
    worst = max(s.Cost for s in Sol)
    m = Best.metrics
    prefix = f"[{tag}] " if tag else ''
    print(
        f"{prefix}Iter {Iter:03d} | Best: {Best.Cost:12.0f} | Worst: {worst:12.0f} | "
        f"HC: {m['hc_count']:3d} (u:{m['hc_unassigned']} g:{m['hc_ghost']}) | "
        f"Repaired: {m['repaired']:3d} | SC: {m['sc_value']:6.0f} | {elapsed:.1f}s"
    )


# ==========================================
# 11. Main Optimizer
# ==========================================
def run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), nSol)
    print(f"[INFO] Parallel workers : {n_workers}")
    print(f"[INFO] HC weight        : {HC_WEIGHT:,}")
    print(f"[INFO] Total courses    : {_N_COURSES}")

    # ── Initial population ────────────────────────────────────────────────────
    print("\nMengevaluasi populasi inisial...")
    init_vectors    = [lb + (ub - lb) * np.random.rand(dim) for _ in range(nSol)]
    init_vectors[0] = np.full(dim, 0.5)      # seed: pure MCF order

    results      = parallel_eval(init_vectors, n_workers)
    Sol          = [Solution(init_vectors[i], *results[i]) for i in range(nSol)]
    Best         = min(Sol, key=lambda s: s.Cost)
    Initial_Best = Best.clone()

    m = Best.metrics
    print(f"\nInitial Best  | Fitness: {Best.Cost:12.0f} | "
          f"HC: {m['hc_count']:3d} (u:{m['hc_unassigned']} g:{m['hc_ghost']}) | "
          f"Repaired: {m['repaired']:3d} | SC: {m['sc_value']:.0f}")

    # if Best.metrics['hc_count'] == 0:
    #     print("[INFO] Zero HC violations at initialisation — skipping optimisation.")
    #     return Best

    # ── PO state variables ────────────────────────────────────────────────────
    UnSelected = [1, 1]
    F3_Explore = F3_Exploit = 0
    Seq_Time_Explore  = [1, 1, 1];  Seq_Time_Exploit  = [1, 1, 1]
    Seq_Cost_Explore  = [1, 1, 1];  Seq_Cost_Exploit  = [1, 1, 1]
    PF            = [0.5, 0.5, 0.3]
    PF_F3         = []
    Mega_Explor   = Mega_Exploit = 0.99
    Costs_Explor  = np.zeros(3)
    Costs_Exploit = np.zeros(3)
    Flag_Change   = 1

    # ── Adaptive tracking variables ───────────────────────────────────────────
    stagnation_sc  = 0      # iterations without any fitness improvement
    stagnation_hc  = 0      # iterations without HC count improvement
    prev_best_cost = Best.Cost
    prev_best_hc   = Best.metrics['hc_count']
    stuck_indices  = list(Best.metrics.get('stuck_indices', []))

    print("\n" + "=" * 110)
    print("  PUMA OPTIMISER — ADAPTIVE CONFLICT-DIRECTED REPAIR".center(110))
    print("=" * 110)

    t_start = time.perf_counter()

    # ── Bootstrap iterations 1–3 ──────────────────────────────────────────────
    for Iter in range(1, 4):
        Sol_E1 = exploration ([s.clone() for s in Sol], lb, ub, dim, nSol, n_workers)
        Sol_E2 = exploitation([s.clone() for s in Sol], lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
        Costs_Explor[Iter - 1]  = min(s.Cost for s in Sol_E1)
        Costs_Exploit[Iter - 1] = min(s.Cost for s in Sol_E2)

        merged = Sol + Sol_E1 + Sol_E2
        merged.sort(key=lambda s: s.Cost)
        Sol  = merged[:nSol]
        Best = Sol[0]
        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start)

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC achieved at bootstrap iter {Iter}.")
            return Best

    Seq_Cost_Explore[0] = abs(Initial_Best.Cost  - Costs_Explor[0])
    Seq_Cost_Explore[1] = abs(Costs_Explor[1]    - Costs_Explor[0])
    Seq_Cost_Explore[2] = abs(Costs_Explor[2]    - Costs_Explor[1])
    Seq_Cost_Exploit[0] = abs(Initial_Best.Cost  - Costs_Exploit[0])
    Seq_Cost_Exploit[1] = abs(Costs_Exploit[1]   - Costs_Exploit[0])
    Seq_Cost_Exploit[2] = abs(Costs_Exploit[2]   - Costs_Exploit[1])
    for v in Seq_Cost_Explore + Seq_Cost_Exploit:
        if v != 0:
            PF_F3.append(v)

    # ── Main loop ─────────────────────────────────────────────────────────────
    for Iter in range(4, MaxIter + 1):

        # ── Standard POA selection ────────────────────────────────────────────
        F1_Explor  = PF[0] * (Seq_Cost_Explore[0] / Seq_Time_Explore[0])
        F1_Exploit = PF[0] * (Seq_Cost_Exploit[0] / Seq_Time_Exploit[0])
        F2_Explor  = PF[1] * (sum(Seq_Cost_Explore) / sum(Seq_Time_Explore))
        F2_Exploit = PF[1] * (sum(Seq_Cost_Exploit) / sum(Seq_Time_Exploit))
        Score_Explore = Mega_Explor  * (F1_Explor  + F2_Explor)
        Score_Exploit = Mega_Exploit * (F1_Exploit + F2_Exploit)

        if Score_Explore > Score_Exploit:
            SelectFlag = 1
            Sol = exploration(Sol, lb, ub, dim, nSol, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[1] += 1;  UnSelected[0] = 1
            F3_Explore = PF[2];  F3_Exploit += PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Explore[2], Seq_Cost_Explore[1] = Seq_Cost_Explore[1], Seq_Cost_Explore[0]
            Seq_Cost_Explore[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Explore[0]: PF_F3.append(Seq_Cost_Explore[0])
        else:
            SelectFlag = 2
            Sol = exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[0] += 1;  UnSelected[1] = 1
            F3_Explore += PF[2];  F3_Exploit = PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Exploit[2], Seq_Cost_Exploit[1] = Seq_Cost_Exploit[1], Seq_Cost_Exploit[0]
            Seq_Cost_Exploit[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Exploit[0]: PF_F3.append(Seq_Cost_Exploit[0])

        if TBest.Cost < Best.Cost:
            Best = TBest

        if Flag_Change != SelectFlag:
            Flag_Change = SelectFlag
            Seq_Time_Explore[2], Seq_Time_Explore[1], Seq_Time_Explore[0] = \
                Seq_Time_Explore[1], Seq_Time_Explore[0], Count_select[0]
            Seq_Time_Exploit[2], Seq_Time_Exploit[1], Seq_Time_Exploit[0] = \
                Seq_Time_Exploit[1], Seq_Time_Exploit[0], Count_select[1]

        if Score_Explore < Score_Exploit:
            Mega_Explor  = max(Mega_Explor  - 0.01, 0.01)
            Mega_Exploit = 0.99
        else:
            Mega_Explor  = 0.99
            Mega_Exploit = max(Mega_Exploit - 0.01, 0.01)

        elapsed = time.perf_counter() - t_start
        print_iteration_log(Iter, Sol, Best, elapsed)

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC violations achieved at iteration {Iter}.")
            break

        # ── Adaptive stagnation tracking ──────────────────────────────────────
        cur_hc   = Best.metrics['hc_count']
        cur_cost = Best.Cost
        stuck_indices = list(Best.metrics.get('stuck_indices', []))

        if cur_hc < prev_best_hc:
            stagnation_hc = 0
            prev_best_hc  = cur_hc
            print(f"         ↳ HC improved: {prev_best_hc + (prev_best_hc - cur_hc)} → {cur_hc}")
        else:
            stagnation_hc += 1

        if cur_cost < prev_best_cost:
            stagnation_sc = 0
            prev_best_cost = cur_cost
        else:
            stagnation_sc += 1

        # ── Adaptive recovery (triggered by HC stagnation) ────────────────────
        #
        #  Tier 1 (every 5 HC-stagnant iters): targeted perturbation of
        #          bottom third — push stuck course indices to top priority.
        #
        #  Tier 2 (every 15 HC-stagnant iters): Levy flight + targeted seeds
        #          for bottom half, allowing heavy-tailed jumps out of local optima.
        #
        #  Tier 3 (every 30 HC-stagnant iters): full adaptive restart —
        #          keep top 20%, rebuild rest with mixed strategies.
        #
        if stagnation_hc > 0 and stagnation_hc % 30 == 0:
            print(f"[ADAPT-T3] Iter {Iter} — Full adaptive restart "
                  f"(HC stagnant {stagnation_hc} iters, stuck={len(stuck_indices)} courses)")
            Sol = adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                               stuck_indices, stagnation_hc, n_workers)
            Sol.sort(key=lambda s: s.Cost)
            new_best = Sol[0]
            if new_best.Cost < Best.Cost:
                Best = new_best
            stagnation_hc = 0
            stagnation_sc = 0

        elif stagnation_hc > 0 and stagnation_hc % 15 == 0:
            print(f"[ADAPT-T2] Iter {Iter} — Levy flight + targeted seeds "
                  f"(HC stagnant {stagnation_hc} iters)")
            Sol = adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                               stuck_indices, stagnation_hc, n_workers)
            Sol.sort(key=lambda s: s.Cost)
            if Sol[0].Cost < Best.Cost:
                Best = Sol[0]

        elif stagnation_hc > 0 and stagnation_hc % 5 == 0:
            print(f"[ADAPT-T1] Iter {Iter} — Targeted perturbation of stuck courses "
                  f"(HC stagnant {stagnation_hc} iters)")
            Sol = adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                               stuck_indices, stagnation_hc, n_workers)
            Sol.sort(key=lambda s: s.Cost)
            if Sol[0].Cost < Best.Cost:
                Best = Sol[0]

        # ── Legacy SC-stagnation recovery (unchanged behaviour) ───────────────
        elif stagnation_sc >= 10:
            print(f"[STAG-SC] Iter {Iter} — SC stagnation recovery (random diversity)")
            n_replace = nSol // 3
            new_vecs = [lb + (ub - lb) * np.random.rand(dim) for _ in range(n_replace)]
            res = parallel_eval(new_vecs, n_workers)
            for k, (c, a, met) in enumerate(res):
                Sol[-(k + 1)] = Solution(new_vecs[k], c, a, met)
            stagnation_sc = 0

    total = time.perf_counter() - t_start
    print(f"\n[INFO] Optimasi selesai dalam {total:.1f}s")

    # ── Post-run feasibility diagnosis ───────────────────────────────────────
    final_stuck = Best.metrics.get('stuck_indices', [])
    if final_stuck:
        print("\n" + "=" * 80)
        print("  FEASIBILITY DIAGNOSIS — Courses that could not be scheduled")
        print("=" * 80)
        teacher_counts = {}
        for cidx in final_stuck:
            tid = _TEACHER[cidx]
            cname = mk_df_raw['course_name'].iloc[cidx]
            teacher_counts[tid] = teacher_counts.get(tid, 0) + 1
            print(f"  Course idx {cidx:4d} | teacher: {tid:>8} | {cname}")
        print()
        print("  Teacher capacity summary:")
        for tid, n_stuck in sorted(teacher_counts.items(), key=lambda x: -x[1]):
            total_assigned = sum(
                1 for a in Best.assignments if a['teacher'] == tid
            )
            n_slots = len(valid_starts)
            print(f"    Teacher {tid:>8}: {n_stuck} stuck, "
                  f"{total_assigned} assigned, "
                  f"{n_slots} total timeslot pairs available per room type")
        print("=" * 80)
        print("  If stuck count = total slots available for teacher, the problem")
        print("  is infeasible for that teacher — reduce their course load in the dataset.")

    return Best


# ==========================================
# 12. Eksekusi & Ekspor
# ==========================================
if __name__ == '__main__':
    nSol    = 50
    MaxIter = 100
    dim     = _N_COURSES
    lb, ub  = 0.0, 1.0

    t0 = time.perf_counter()
    best_solution = run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None)
    print(f"Total elapsed: {time.perf_counter() - t0:.1f}s")

    res_list = []
    for a in best_solution.assignments:
        course = mk_df_raw.iloc[a['course_i']]
        room   = rooms_df.iloc[a['room']]
        t1     = timeslots_df.iloc[a['start_slot']]
        t2     = timeslots_df.iloc[a['end_slot']]
        res_list.append({
            'event_id':    course['event_id'],
            'course_name': course['course_name'],
            'teacher_id':  course['teacher_id'],
            'room_id':     room['room_id'],
            'day':         t1['day'],
            'time_start':  t1['time_start'],
            'time_end':    t2['time_end'],
        })

    res_df   = pd.DataFrame(res_list)
    out_path = 'scheduled_courses_poa_adaptive_ganjil_v1.csv'
    res_df.to_csv(out_path, index=False)

    m = best_solution.metrics
    print(f"\n{'=' * 65}")
    print(f"  FINAL RESULT")
    print(f"  HC Violations  : {m['hc_count']}  "
          f"(unassigned: {m['hc_unassigned']}, ghost: {m['hc_ghost']})")
    print(f"  HC Penalty     : {m['hc_value']:,}")
    print(f"  Repaired by P2 : {m['repaired']}")
    print(f"  SC Violations  : {m['sc_count']}  (penalty: {m['sc_value']})")
    print(f"  Total Fitness  : {best_solution.Cost:,}")
    print(f"  Courses scheduled: {len(res_list)} / {_N_COURSES}")
    print(f"{'=' * 65}")
    print(f"[INFO] Solusi disimpan di '{out_path}'")
# Out:
# [INFO] Memuat dan memproses dataset...
# [INFO] Parallel workers : 8
# [INFO] HC weight        : 10,000,000
# [INFO] Total courses    : 474
#
# Mengevaluasi populasi inisial...
#
# Initial Best  | Fitness:     30001490 | HC:   3 (u:1 g:2) | Repaired:   0 | SC: 1490
#
# ==============================================================================================================
#                                PUMA OPTIMISER — ADAPTIVE CONFLICT-DIRECTED REPAIR
# ==============================================================================================================
# Iter 001 | Best:     10002620 | Worst:     30002390 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   2620 | 3.6s
# Iter 002 | Best:     10002430 | Worst:     30001750 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   2430 | 7.6s
# Iter 003 | Best:     10002430 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   2430 | 12.6s
# Iter 004 | Best:     10002010 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   2010 | 15.2s
#          ↳ HC improved: 1 → 1
# Iter 005 | Best:     10002010 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   2010 | 17.7s
# Iter 006 | Best:     10002010 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   2010 | 20.3s
# Iter 007 | Best:     10002010 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   2010 | 22.8s
# Iter 008 | Best:     10001920 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 25.2s
# Iter 009 | Best:     10001920 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 27.7s
# [ADAPT-T1] Iter 9 — Targeted perturbation of stuck courses (HC stagnant 5 iters)
# Iter 010 | Best:     10001920 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 31.2s
# Iter 011 | Best:     10001920 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 33.8s
# Iter 012 | Best:     10001920 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 36.2s
# Iter 013 | Best:     10001920 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 38.8s
# Iter 014 | Best:     10001920 | Worst:     30001490 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 41.3s
# [ADAPT-T1] Iter 14 — Targeted perturbation of stuck courses (HC stagnant 10 iters)
# Iter 015 | Best:     10001920 | Worst:     30001890 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 44.8s
# Iter 016 | Best:     10001920 | Worst:     30001890 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 47.3s
# Iter 017 | Best:     10001920 | Worst:     30001890 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 50.0s
# Iter 018 | Best:     10001920 | Worst:     30001650 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 52.4s
# [STAG-SC] Iter 18 — SC stagnation recovery (random diversity)
# Iter 019 | Best:     10001920 | Worst:     30002700 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 55.7s
# [ADAPT-T2] Iter 19 — Levy flight + targeted seeds (HC stagnant 15 iters)
# Iter 020 | Best:     10001920 | Worst:     30002860 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 59.7s
# Iter 021 | Best:     10001920 | Worst:     30002660 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 62.3s
# Iter 022 | Best:     10001920 | Worst:     30002600 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 65.1s
# Iter 023 | Best:     10001920 | Worst:     30002600 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 67.8s
# Iter 024 | Best:     10001920 | Worst:     30002150 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 70.3s
# [ADAPT-T1] Iter 24 — Targeted perturbation of stuck courses (HC stagnant 20 iters)
# Iter 025 | Best:     10001920 | Worst:     30002780 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 73.9s
# Iter 026 | Best:     10001920 | Worst:     30002590 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 76.1s
# Iter 027 | Best:     10001920 | Worst:     30002280 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 78.5s
# Iter 028 | Best:     10001920 | Worst:     30002030 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 81.5s
# [STAG-SC] Iter 28 — SC stagnation recovery (random diversity)
# Iter 029 | Best:     10001920 | Worst:     30002710 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 84.9s
# [ADAPT-T1] Iter 29 — Targeted perturbation of stuck courses (HC stagnant 25 iters)
# Iter 030 | Best:     10001920 | Worst:     30002680 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 88.7s
# Iter 031 | Best:     10001920 | Worst:     30002480 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 91.4s
# Iter 032 | Best:     10001920 | Worst:     30002310 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 94.0s
# Iter 033 | Best:     10001920 | Worst:     30002310 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 96.5s
# Iter 034 | Best:     10001920 | Worst:     30001940 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 100.0s
# [ADAPT-T3] Iter 34 — Full adaptive restart (HC stagnant 30 iters, stuck=1 courses)
# Iter 035 | Best:     10001920 | Worst:     30002690 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 104.9s
# Iter 036 | Best:     10001920 | Worst:     30002500 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 107.5s
# Iter 037 | Best:     10001920 | Worst:     30002420 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 110.1s
# Iter 038 | Best:     10001920 | Worst:     30002230 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1920 | 112.4s
# Iter 039 | Best:     10001560 | Worst:     30001910 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 115.3s
# [ADAPT-T1] Iter 39 — Targeted perturbation of stuck courses (HC stagnant 5 iters)
# Iter 040 | Best:     10001560 | Worst:     30001910 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 119.7s
# Iter 041 | Best:     10001560 | Worst:     30001810 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 122.8s
# Iter 042 | Best:     10001560 | Worst:     30001750 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 125.7s
# Iter 043 | Best:     10001560 | Worst:     30001710 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 128.7s
# Iter 044 | Best:     10001560 | Worst:     30001710 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 131.8s
# [ADAPT-T1] Iter 44 — Targeted perturbation of stuck courses (HC stagnant 10 iters)
# Iter 045 | Best:     10001560 | Worst:     30001640 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 135.5s
# Iter 046 | Best:     10001560 | Worst:     30001640 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 138.2s
# Iter 047 | Best:     10001560 | Worst:     30001640 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 140.6s
# Iter 048 | Best:     10001560 | Worst:     30001640 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 143.1s
# Iter 049 | Best:     10001560 | Worst:     30001640 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 145.4s
# [ADAPT-T2] Iter 49 — Levy flight + targeted seeds (HC stagnant 15 iters)
# Iter 050 | Best:     10001560 | Worst:     30002330 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 149.3s
# [STAG-SC] Iter 50 — SC stagnation recovery (random diversity)
# Iter 051 | Best:     10001560 | Worst:     30002640 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 152.6s
# Iter 052 | Best:     10001560 | Worst:     30002390 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 155.1s
# Iter 053 | Best:     10001560 | Worst:     30002070 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 157.6s
# Iter 054 | Best:     10001560 | Worst:     30001940 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 160.4s
# [ADAPT-T1] Iter 54 — Targeted perturbation of stuck courses (HC stagnant 20 iters)
# Iter 055 | Best:     10001560 | Worst:     30002310 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 164.6s
# Iter 056 | Best:     10001560 | Worst:     30002050 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 167.1s
# Iter 057 | Best:     10001560 | Worst:     30002050 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 169.6s
# Iter 058 | Best:     10001560 | Worst:     30001810 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 172.1s
# Iter 059 | Best:     10001560 | Worst:     30001800 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 174.5s
# [ADAPT-T1] Iter 59 — Targeted perturbation of stuck courses (HC stagnant 25 iters)
# Iter 060 | Best:     10001560 | Worst:     30002400 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 178.2s
# [STAG-SC] Iter 60 — SC stagnation recovery (random diversity)
# Iter 061 | Best:     10001560 | Worst:     30002600 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 181.5s
# Iter 062 | Best:     10001560 | Worst:     30002350 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 183.8s
# Iter 063 | Best:     10001560 | Worst:     30002280 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 186.3s
# Iter 064 | Best:     10001560 | Worst:     30001900 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 188.6s
# [ADAPT-T3] Iter 64 — Full adaptive restart (HC stagnant 30 iters, stuck=1 courses)
# Iter 065 | Best:     10001560 | Worst:     30002710 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 193.0s
# Iter 066 | Best:     10001560 | Worst:     30002340 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 195.4s
# Iter 067 | Best:     10001560 | Worst:     30001930 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 197.9s
# Iter 068 | Best:     10001560 | Worst:     30001860 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 200.3s
# Iter 069 | Best:     10001560 | Worst:     30001860 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 202.7s
# [ADAPT-T1] Iter 69 — Targeted perturbation of stuck courses (HC stagnant 5 iters)
# Iter 070 | Best:     10001560 | Worst:     30001760 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 206.1s
# Iter 071 | Best:     10001560 | Worst:     30001750 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 208.7s
# Iter 072 | Best:     10001560 | Worst:     30001690 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 211.0s
# Iter 073 | Best:     10001560 | Worst:     30001690 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 213.7s
# Iter 074 | Best:     10001560 | Worst:     30001660 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 216.1s
# [ADAPT-T1] Iter 74 — Targeted perturbation of stuck courses (HC stagnant 10 iters)
# Iter 075 | Best:     10001560 | Worst:     30001590 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 219.3s
# [STAG-SC] Iter 75 — SC stagnation recovery (random diversity)
# Iter 076 | Best:     10001560 | Worst:     30002690 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 222.5s
# Iter 077 | Best:     10001560 | Worst:     30002400 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 224.9s
# Iter 078 | Best:     10001560 | Worst:     30001940 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 227.3s
# Iter 079 | Best:     10001560 | Worst:     30001940 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 229.7s
# [ADAPT-T2] Iter 79 — Levy flight + targeted seeds (HC stagnant 15 iters)
# Iter 080 | Best:     10001560 | Worst:     30002340 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 233.4s
# Iter 081 | Best:     10001560 | Worst:     30002050 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 235.8s
# Iter 082 | Best:     10001560 | Worst:     30001910 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 238.2s
# Iter 083 | Best:     10001560 | Worst:     30001830 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 240.6s
# Iter 084 | Best:     10001560 | Worst:     30001830 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 242.9s
# [ADAPT-T1] Iter 84 — Targeted perturbation of stuck courses (HC stagnant 20 iters)
# Iter 085 | Best:     10001560 | Worst:     30002220 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 246.7s
# [STAG-SC] Iter 85 — SC stagnation recovery (random diversity)
# Iter 086 | Best:     10001560 | Worst:     30002510 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 249.9s
# Iter 087 | Best:     10001560 | Worst:     30002130 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 252.3s
# Iter 088 | Best:     10001560 | Worst:     30002130 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 254.6s
# Iter 089 | Best:     10001560 | Worst:     30002130 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 257.2s
# [ADAPT-T1] Iter 89 — Targeted perturbation of stuck courses (HC stagnant 25 iters)
# Iter 090 | Best:     10001560 | Worst:     30002160 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 260.6s
# Iter 091 | Best:     10001560 | Worst:     30002010 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 263.3s
# Iter 092 | Best:     10001560 | Worst:     30001810 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 265.6s
# Iter 093 | Best:     10001560 | Worst:     30001800 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 268.0s
# Iter 094 | Best:     10001560 | Worst:     30001750 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 270.3s
# [ADAPT-T3] Iter 94 — Full adaptive restart (HC stagnant 30 iters, stuck=1 courses)
# Iter 095 | Best:     10001560 | Worst:     30002540 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 274.7s
# Iter 096 | Best:     10001560 | Worst:     30002240 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 277.4s
# Iter 097 | Best:     10001560 | Worst:     30001880 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 280.5s
# Iter 098 | Best:     10001560 | Worst:     30001840 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 282.8s
# Iter 099 | Best:     10001560 | Worst:     30001790 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 285.5s
# [ADAPT-T1] Iter 99 — Targeted perturbation of stuck courses (HC stagnant 5 iters)
# Iter 100 | Best:     10001560 | Worst:     30001910 | HC:   1 (u:1 g:0) | Repaired:   0 | SC:   1560 | 289.1s
#
# [INFO] Optimasi selesai dalam 289.1s
#
# ================================================================================
#   FEASIBILITY DIAGNOSIS — Courses that could not be scheduled
# ================================================================================
#   Course idx  133 | teacher:       47 | Pemrograman Dasar
#
#   Teacher capacity summary:
#     Teacher       47: 1 stuck, 30 assigned, 55 total timeslot pairs available per room type
# ================================================================================
#   If stuck count = total slots available for teacher, the problem
#   is infeasible for that teacher — reduce their course load in the dataset.
# Total elapsed: 290.9s
#
# =================================================================
#   FINAL RESULT
#   HC Violations  : 1  (unassigned: 1, ghost: 0)
#   HC Penalty     : 10,000,000
#   Repaired by P2 : 0
#   SC Violations  : 2  (penalty: 1560)
#   Total Fitness  : 10,001,560
#   Courses scheduled: 473 / 474
# =================================================================
# [INFO] Solusi disimpan di 'scheduled_courses_poa_adaptive_ganjil_v1.csv'

# %% [markdown]
# ### Random Initialization Process

# %%
import numpy as np
import pandas as pd
import time
import math
from concurrent.futures import ProcessPoolExecutor, as_completed
import os

# ==========================================
# 1. Deklarasi & Persiapan Dataset
# ==========================================
print("[INFO] Memuat dan memproses dataset...")
mk_df_raw = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/mk_dsi_genap_praktikum_processed_v2.csv')
rooms_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/rooms_processed.csv')
timeslots_df = pd.read_csv('/home/emery/Documents/Scheduling_Puma_Optimizer/app/assets/timeslots_processed.csv')

valid_starts = [
    i for i in range(len(timeslots_df) - 1)
    if (timeslots_df.iloc[i]['day'] == timeslots_df.iloc[i + 1]['day'] and
        timeslots_df.iloc[i]['time_end'] == timeslots_df.iloc[i + 1]['time_start'])
]

rooms_prac = rooms_df[rooms_df['is_practicum'] == True].index.tolist()
rooms_theo = rooms_df[rooms_df['is_theory'] == True].index.tolist()

teacher_workload = mk_df_raw['teacher_id'].value_counts().to_dict()
mk_df_raw['teacher_degree'] = mk_df_raw['teacher_id'].map(teacher_workload)

PRAC_SLOTS = [(r, s) for r in rooms_prac for s in valid_starts]
THEO_SLOTS = [(r, s) for r in rooms_theo for s in valid_starts]

_REQ_PRAC   = mk_df_raw['requires_practicum_room'].to_numpy()
_TEACHER    = mk_df_raw['teacher_id'].to_numpy()
_T_PRIORITY = mk_df_raw['teacher_priority'].to_numpy()
_T_DEGREE   = mk_df_raw['teacher_degree'].to_numpy()
_TS_DAY     = timeslots_df['day'].to_numpy()
_TS_SESSION = timeslots_df['session_type'].to_numpy()
_N_COURSES  = len(mk_df_raw)

SESSION_MORNING   = (_TS_SESSION == 'Morning')
SESSION_AFTERNOON = (_TS_SESSION == 'Afternoon')

HC_WEIGHT = 10_000_000


# ==========================================
# 2. Levy Flight Helper
# ==========================================
def levy_flight(dim, beta=1.5):
    """
    Generate a Levy flight step vector (heavy-tailed distribution).

    Levy flight produces occasional large jumps alongside many small steps,
    which is ideal for escaping deep local optima. `beta` controls tail
    heaviness; 1.5 is a well-tested default for meta-heuristic optimizers.
    """
    sigma = (
        math.gamma(1 + beta) * math.sin(math.pi * beta / 2) /
        (math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))
    ) ** (1 / beta)
    u = np.random.randn(dim) * sigma
    v = np.abs(np.random.randn(dim)) + 1e-10
    step = u / (v ** (1 / beta))
    return step


# ==========================================
# 3. Fitness Function
# ==========================================
def fitness_function(sol_x):
    """
    Three-phase decoder with two-level conflict-directed repair.

    PHASE 1 — Greedy assignment (Most-Constrained-First + PO key ordering)
    PHASE 2 — Conflict-Directed Repair
      Level 1 (L1): Single-blocker swap — blocker owns BOTH t1 and t2 (same course)
      Level 2 (L2): Double-blocker chain — DIFFERENT courses own t1 and t2;
                    try to relocate BOTH simultaneously.
                    ── Why L2 was missing and why it caused Repaired=0 ──────────
                    FIX B (previous version) correctly skipped double-blocker slots
                    to prevent ghost conflicts.  But for overloaded teachers, every
                    timeslot pair is double-blocked by different back-to-back courses,
                    so FIX B caused ALL repair attempts to be skipped → Repaired=0
                    every iteration → POA had nothing to improve → total stagnation.
                    L2 resolves this by relocating both blockers atomically.
    PHASE 3 — SC evaluation + HC audit (ghost-conflict safety net)
    """
    hc_count = 0
    sc_value = 0
    sc_count = 0
    assignments     = []
    unassigned_idxs = []

    room_time_booked    = set()
    teacher_time_booked = set()
    teacher_day_rooms   = {}
    teacher_ts_to_asgn  = {}

    avail_prac = set(range(len(PRAC_SLOTS)))
    avail_theo = set(range(len(THEO_SLOTS)))

    # ── MCF + PO random-key ordering ─────────────────────────────────────────
    base_scores = (_REQ_PRAC.astype(float) * 1000) + (_T_DEGREE * 10)
    priorities  = base_scores + (sol_x * 100)
    queue_order = np.argsort(-priorities)

    # =========================================================================
    # PHASE 1 — GREEDY ASSIGNMENT
    # =========================================================================
    for idx in queue_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])
        slot_list  = PRAC_SLOTS if req_prac else THEO_SLOTS
        avail_set  = avail_prac  if req_prac else avail_theo

        hc_fallback    = None
        best_sc        = float('inf')
        best_slot_info = None
        sc_scan_count  = 0

        for si in list(avail_set):
            r, s = slot_list[si]
            t1, t2 = s, s + 1

            # Defensive room guard (FIX A)
            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                avail_set.discard(si)
                continue
            if (teacher, t1) in teacher_time_booked or (teacher, t2) in teacher_time_booked:
                continue

            if hc_fallback is None:
                hc_fallback = (r, s, _TS_DAY[s], t1, t2, si)

            day    = _TS_DAY[s]
            temp_sc = 0
            if t_priority == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
                temp_sc += 10
            elif t_priority == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
                temp_sc += 10
            if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
                if r not in teacher_day_rooms[teacher][day]:
                    temp_sc += 50

            if temp_sc < best_sc:
                best_sc        = temp_sc
                best_slot_info = (r, s, day, t1, t2, si)
                if temp_sc == 0:
                    break
            sc_scan_count += 1
            if sc_scan_count >= 50:
                break

        chosen = best_slot_info if best_slot_info is not None else hc_fallback
        if chosen is not None:
            r, s, day, t1, t2, si = chosen
            _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                       assignments, room_time_booked, teacher_time_booked,
                       teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
        else:
            unassigned_idxs.append(int(idx))

    # =========================================================================
    # PHASE 2 — CONFLICT-DIRECTED REPAIR (L1 + L2)
    # =========================================================================
    still_unassigned = []

    # Scan cap per level to keep O(n) per unassigned course
    L1_SCAN_LIMIT = 200
    L2_SCAN_LIMIT = 150

    for idx in unassigned_idxs:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])
        slot_list  = PRAC_SLOTS if req_prac else THEO_SLOTS
        placed     = False

        # ─── LEVEL 1: Single-blocker swap ─────────────────────────────────────
        l1_count = 0
        for r, s in slot_list:
            if l1_count >= L1_SCAN_LIMIT:
                break
            t1, t2 = s, s + 1

            if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                continue

            blocked_t1 = (teacher, t1) in teacher_time_booked
            blocked_t2 = (teacher, t2) in teacher_time_booked

            if not blocked_t1 and not blocked_t2:
                day = _TS_DAY[s]
                _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                placed = True
                break

            if blocked_t1 and blocked_t2:
                b1_i = teacher_ts_to_asgn.get((teacher, t1))
                b2_i = teacher_ts_to_asgn.get((teacher, t2))
                if b1_i != b2_i:
                    l1_count += 1
                    continue
                blocker_key = (teacher, t1)
            else:
                blocker_key = (teacher, t1) if blocked_t1 else (teacher, t2)

            blocker_asgn_idx = teacher_ts_to_asgn.get(blocker_key)
            if blocker_asgn_idx is None:
                l1_count += 1
                continue

            blocker   = assignments[blocker_asgn_idx]
            b_idx     = blocker['course_i']
            b_rp      = bool(_REQ_PRAC[b_idx])
            b_teacher = blocker['teacher']
            b_t1_old  = blocker['start_slot']
            b_t2_old  = blocker['end_slot']
            b_r_old   = blocker['room']
            b_prio    = blocker['priority']
            b_day_old = blocker['day']

            _unbook(blocker_asgn_idx, b_r_old, b_t1_old, b_t2_old,
                    b_teacher, b_day_old, b_rp,
                    room_time_booked, teacher_time_booked,
                    teacher_day_rooms, teacher_ts_to_asgn,
                    avail_prac, avail_theo)

            reloc = _find_reloc(b_idx, b_teacher, b_rp,
                                exclude_r=r, exclude_s=s,
                                room_time_booked=room_time_booked,
                                teacher_time_booked=teacher_time_booked,
                                avail_prac=avail_prac, avail_theo=avail_theo)

            if reloc is not None:
                r2, s2, day2, t1n, t2n, si2 = reloc
                _do_assign(b_idx, r2, s2, day2, t1n, t2n, b_prio, b_teacher, b_rp,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=blocker_asgn_idx)

                day = _TS_DAY[s]
                if ((teacher, t1) not in teacher_time_booked and
                        (teacher, t2) not in teacher_time_booked and
                        (r, t1) not in room_time_booked and
                        (r, t2) not in room_time_booked):
                    _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                               assignments, room_time_booked, teacher_time_booked,
                               teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                    placed = True
                    break
            else:
                _rebook(blocker_asgn_idx, b_r_old, b_t1_old, b_t2_old,
                        b_teacher, b_day_old, b_rp,
                        room_time_booked, teacher_time_booked,
                        teacher_day_rooms, teacher_ts_to_asgn,
                        avail_prac, avail_theo)

            l1_count += 1

        # ─── LEVEL 2: Double-blocker chain swap ───────────────────────────────
        if not placed:
            l2_count = 0
            for r, s in slot_list:
                if l2_count >= L2_SCAN_LIMIT:
                    break
                t1, t2 = s, s + 1

                if (r, t1) in room_time_booked or (r, t2) in room_time_booked:
                    continue

                b1_asgn_idx = teacher_ts_to_asgn.get((teacher, t1))
                b2_asgn_idx = teacher_ts_to_asgn.get((teacher, t2))

                if (b1_asgn_idx is None or b2_asgn_idx is None or
                        b1_asgn_idx == b2_asgn_idx):
                    continue

                l2_count += 1

                b1 = assignments[b1_asgn_idx]
                b2 = assignments[b2_asgn_idx]

                b1_idx, b1_rp = b1['course_i'], bool(_REQ_PRAC[b1['course_i']])
                b1_teacher, b1_t1, b1_t2 = b1['teacher'], b1['start_slot'], b1['end_slot']
                b1_r, b1_prio, b1_day    = b1['room'],    b1['priority'],  b1['day']

                b2_idx, b2_rp = b2['course_i'], bool(_REQ_PRAC[b2['course_i']])
                b2_teacher, b2_t1, b2_t2 = b2['teacher'], b2['start_slot'], b2['end_slot']
                b2_r, b2_prio, b2_day    = b2['room'],    b2['priority'],  b2['day']

                _unbook(b1_asgn_idx, b1_r, b1_t1, b1_t2,
                        b1_teacher, b1_day, b1_rp,
                        room_time_booked, teacher_time_booked,
                        teacher_day_rooms, teacher_ts_to_asgn,
                        avail_prac, avail_theo)

                b1_reloc = _find_reloc(b1_idx, b1_teacher, b1_rp,
                                       exclude_r=r, exclude_s=s,
                                       exclude_r2=b2_r, exclude_s2=b2_t1,
                                       room_time_booked=room_time_booked,
                                       teacher_time_booked=teacher_time_booked,
                                       avail_prac=avail_prac, avail_theo=avail_theo)

                if b1_reloc is None:
                    _rebook(b1_asgn_idx, b1_r, b1_t1, b1_t2,
                            b1_teacher, b1_day, b1_rp,
                            room_time_booked, teacher_time_booked,
                            teacher_day_rooms, teacher_ts_to_asgn,
                            avail_prac, avail_theo)
                    continue

                _unbook(b2_asgn_idx, b2_r, b2_t1, b2_t2,
                        b2_teacher, b2_day, b2_rp,
                        room_time_booked, teacher_time_booked,
                        teacher_day_rooms, teacher_ts_to_asgn,
                        avail_prac, avail_theo)

                r1n, s1n = b1_reloc[0], b1_reloc[1]
                b2_reloc = _find_reloc(b2_idx, b2_teacher, b2_rp,
                                       exclude_r=r,   exclude_s=s,
                                       exclude_r2=r1n, exclude_s2=s1n,
                                       room_time_booked=room_time_booked,
                                       teacher_time_booked=teacher_time_booked,
                                       avail_prac=avail_prac, avail_theo=avail_theo)

                if b2_reloc is None:
                    _rebook(b2_asgn_idx, b2_r, b2_t1, b2_t2,
                            b2_teacher, b2_day, b2_rp,
                            room_time_booked, teacher_time_booked,
                            teacher_day_rooms, teacher_ts_to_asgn,
                            avail_prac, avail_theo)
                    _rebook(b1_asgn_idx, b1_r, b1_t1, b1_t2,
                            b1_teacher, b1_day, b1_rp,
                            room_time_booked, teacher_time_booked,
                            teacher_day_rooms, teacher_ts_to_asgn,
                            avail_prac, avail_theo)
                    continue

                r1n, s1n, d1n, t1_b1n, t2_b1n, si1n = b1_reloc
                _do_assign(b1_idx, r1n, s1n, d1n, t1_b1n, t2_b1n, b1_prio, b1_teacher, b1_rp,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=b1_asgn_idx)

                r2n, s2n, d2n, t1_b2n, t2_b2n, si2n = b2_reloc
                _do_assign(b2_idx, r2n, s2n, d2n, t1_b2n, t2_b2n, b2_prio, b2_teacher, b2_rp,
                           assignments, room_time_booked, teacher_time_booked,
                           teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo,
                           update_idx=b2_asgn_idx)

                day = _TS_DAY[s]
                if ((teacher, t1) not in teacher_time_booked and
                        (teacher, t2) not in teacher_time_booked and
                        (r, t1) not in room_time_booked and
                        (r, t2) not in room_time_booked):
                    _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
                               assignments, room_time_booked, teacher_time_booked,
                               teacher_day_rooms, teacher_ts_to_asgn, avail_prac, avail_theo)
                    placed = True
                    break

        if not placed:
            still_unassigned.append(idx)

    # =========================================================================
    # PHASE 3 — SC EVALUATION + HC AUDIT
    # =========================================================================
    for asgn in assignments:
        t1 = asgn['start_slot']
        t2 = asgn['end_slot']
        tp = asgn['priority']
        if tp == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
            sc_value += 10
        elif tp == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
            sc_value += 10

    for teacher_id, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    real_teacher_slots = {}
    real_room_slots    = {}
    ghost_hc = 0
    for asgn in assignments:
        t1, t2   = asgn['start_slot'], asgn['end_slot']
        teacher  = asgn['teacher']
        room     = asgn['room']
        for ts in (t1, t2):
            tk = (teacher, ts)
            if tk in real_teacher_slots:
                ghost_hc += 1
            else:
                real_teacher_slots[tk] = asgn['course_i']
            rk = (room, ts)
            if rk in real_room_slots:
                ghost_hc += 1
            else:
                real_room_slots[rk] = asgn['course_i']

    hc_count = len(still_unassigned) + ghost_hc
    fitness  = hc_count * HC_WEIGHT + sc_value
    metrics  = {
        'hc_count':      hc_count,
        'hc_value':      hc_count * HC_WEIGHT,
        'hc_unassigned': len(still_unassigned),
        'hc_ghost':      ghost_hc,
        'sc_count':      sc_count,
        'sc_value':      sc_value,
        'repaired':      len(unassigned_idxs) - len(still_unassigned),
        'stuck_indices': list(still_unassigned),
    }
    return fitness, assignments, metrics


# ==========================================
# 4. Phase 2 Helper Functions
# ==========================================
def _unbook(asgn_idx, r, t1, t2, teacher, day, req_prac,
            room_time_booked, teacher_time_booked,
            teacher_day_rooms, teacher_ts_to_asgn,
            avail_prac, avail_theo):
    """Remove a single assignment from all booking structures."""
    room_time_booked.discard((r, t1));      room_time_booked.discard((r, t2))
    teacher_time_booked.discard((teacher, t1)); teacher_time_booked.discard((teacher, t2))
    teacher_ts_to_asgn.pop((teacher, t1), None)
    teacher_ts_to_asgn.pop((teacher, t2), None)
    if teacher in teacher_day_rooms and day in teacher_day_rooms[teacher]:
        try:
            teacher_day_rooms[teacher][day].remove(r)
        except ValueError:
            pass
        if not teacher_day_rooms[teacher][day]:
            del teacher_day_rooms[teacher][day]
    slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
    avail_set = avail_prac  if req_prac else avail_theo
    try:
        si = slot_list.index((r, t1))
        avail_set.add(si)
    except ValueError:
        pass


def _rebook(asgn_idx, r, t1, t2, teacher, day, req_prac,
            room_time_booked, teacher_time_booked,
            teacher_day_rooms, teacher_ts_to_asgn,
            avail_prac, avail_theo):
    """Restore a temporarily unbooked assignment to all booking structures."""
    room_time_booked.add((r, t1));      room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))
    teacher_ts_to_asgn[(teacher, t1)] = asgn_idx
    teacher_ts_to_asgn[(teacher, t2)] = asgn_idx
    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)
    slot_list = PRAC_SLOTS if req_prac else THEO_SLOTS
    avail_set = avail_prac  if req_prac else avail_theo
    try:
        si = slot_list.index((r, t1))
        avail_set.discard(si)
    except ValueError:
        pass


def _find_reloc(b_idx, b_teacher, b_req_prac,
                exclude_r, exclude_s,
                room_time_booked, teacher_time_booked,
                avail_prac, avail_theo,
                exclude_r2=None, exclude_s2=None,
                limit=120):
    """
    Find the first available slot for course b_idx (teacher b_teacher, type b_req_prac)
    that does not overlap with the exclusion zones.
    """
    slot_list = PRAC_SLOTS if b_req_prac else THEO_SLOTS
    avail_set = avail_prac  if b_req_prac else avail_theo
    count = 0
    for si in list(avail_set):
        if count >= limit:
            break
        r2, s2 = slot_list[si]
        t1n, t2n = s2, s2 + 1

        if r2 == exclude_r and (abs(s2 - exclude_s) <= 1):
            continue
        if exclude_r2 is not None and r2 == exclude_r2 and (abs(s2 - exclude_s2) <= 1):
            continue

        if (r2, t1n) in room_time_booked or (r2, t2n) in room_time_booked:
            count += 1
            continue
        if (b_teacher, t1n) in teacher_time_booked or (b_teacher, t2n) in teacher_time_booked:
            continue
        return (r2, s2, _TS_DAY[s2], t1n, t2n, si)
    return None


# ==========================================
# 5. Assignment Helper
# ==========================================
def _do_assign(idx, r, s, day, t1, t2, t_priority, teacher, req_prac,
               assignments, room_time_booked, teacher_time_booked,
               teacher_day_rooms, teacher_ts_to_asgn,
               avail_prac, avail_theo, update_idx=None):
    room_time_booked.add((r, t1));          room_time_booked.add((r, t2))
    teacher_time_booked.add((teacher, t1)); teacher_time_booked.add((teacher, t2))

    for _sl, _av in [(PRAC_SLOTS, avail_prac), (THEO_SLOTS, avail_theo)]:
        for si2 in list(_av):
            r2, s2 = _sl[si2]
            if r2 == r and (s2 == t1 or s2 == t2 or s2 + 1 == t1):
                _av.discard(si2)

    if teacher not in teacher_day_rooms:
        teacher_day_rooms[teacher] = {}
    if day not in teacher_day_rooms[teacher]:
        teacher_day_rooms[teacher][day] = []
    teacher_day_rooms[teacher][day].append(r)

    asgn = {'course_i': int(idx), 'room': r, 'start_slot': s, 'end_slot': t2,
            'teacher': teacher, 'priority': t_priority, 'day': day}

    if update_idx is not None:
        assignments[update_idx] = asgn
        teacher_ts_to_asgn[(teacher, t1)] = update_idx
        teacher_ts_to_asgn[(teacher, t2)] = update_idx
    else:
        new_idx = len(assignments)
        assignments.append(asgn)
        teacher_ts_to_asgn[(teacher, t1)] = new_idx
        teacher_ts_to_asgn[(teacher, t2)] = new_idx


def _eval_worker(x):
    return fitness_function(x)


# ==========================================
# 6. Random Initial Solution Builder
# ==========================================
def build_random_solution():
    """
    Build a random initial representative by directly mix-matching every course
    with a randomly chosen compatible room and a randomly chosen timeslot.

    ── Design intent ────────────────────────────────────────────────────────────
    This is intentionally naive: NO conflict checking is performed.
    The resulting assignment will have many room and teacher clashes.
    This conflicting state becomes the starting representative (guide / alpha)
    for POA. The optimizer's job over MaxIter iterations is to discover a
    conflict-free solution from this chaotic starting point — demonstrating
    that POA can escape any feasible neighbourhood regardless of where it begins.

    ── Why this matters for research ───────────────────────────────────────────
    Using the greedy-best evaluated solution as the initial guide biases POA
    toward a single heuristic ordering from the very first iteration.
    Starting from a random representative removes that bias: every population
    member is on equal footing, and the selection/update pressure inside POA
    itself drives convergence to zero HC without any heuristic head start.

    Returns
    -------
    Solution
        A Solution object whose assignments are random (conflicting),
        whose metrics reflect the real HC/SC counts of that random state,
        and whose sol_x vector is a fresh random draw in [0, 1]^N.
    """
    assignments   = []
    teacher_day_rooms = {}
    sc_value      = 0
    sc_count      = 0

    # ── Randomly shuffle course order ────────────────────────────────────────
    # Shuffling removes all MCF bias: every course has an equal chance of
    # being assigned to whichever room+slot comes up first at random.
    course_order = np.random.permutation(_N_COURSES)

    for idx in course_order:
        req_prac   = bool(_REQ_PRAC[idx])
        teacher    = _TEACHER[idx]
        t_priority = int(_T_PRIORITY[idx])
        slot_list  = PRAC_SLOTS if req_prac else THEO_SLOTS

        # ── Random room + timeslot (no conflict guard) ────────────────────────
        si      = np.random.randint(len(slot_list))
        r, s    = slot_list[si]
        t1, t2  = s, s + 1
        day     = _TS_DAY[s]

        asgn = {
            'course_i':   int(idx),
            'room':       r,
            'start_slot': s,
            'end_slot':   t2,
            'teacher':    teacher,
            'priority':   t_priority,
            'day':        day,
        }
        assignments.append(asgn)

        # Track day-rooms for SC calculation
        if teacher not in teacher_day_rooms:
            teacher_day_rooms[teacher] = {}
        if day not in teacher_day_rooms[teacher]:
            teacher_day_rooms[teacher][day] = []
        teacher_day_rooms[teacher][day].append(r)

    # ── SC: session preference ────────────────────────────────────────────────
    for asgn in assignments:
        t1 = asgn['start_slot']
        t2 = asgn['end_slot']
        tp = asgn['priority']
        if tp == 1 and not (SESSION_MORNING[t1] and SESSION_MORNING[t2]):
            sc_value += 10
        elif tp == 2 and not (SESSION_AFTERNOON[t1] and SESSION_AFTERNOON[t2]):
            sc_value += 10

    # ── SC: room consistency per teacher per day ──────────────────────────────
    for teacher_id, days in teacher_day_rooms.items():
        for day, rooms in days.items():
            unique_rooms = len(set(rooms))
            if unique_rooms > 1:
                v = unique_rooms - 1
                sc_count += v
                sc_value += 50 * v

    # ── HC: count real clashes produced by the random assignment ─────────────
    # Since no conflict checking was done, overlapping teachers or rooms
    # will appear here. ghost_hc is the true hard-constraint violation count.
    real_teacher_slots = {}
    real_room_slots    = {}
    ghost_hc = 0
    for asgn in assignments:
        t1, t2  = asgn['start_slot'], asgn['end_slot']
        teacher = asgn['teacher']
        room    = asgn['room']
        for ts in (t1, t2):
            tk = (teacher, ts)
            if tk in real_teacher_slots:
                ghost_hc += 1
            else:
                real_teacher_slots[tk] = asgn['course_i']
            rk = (room, ts)
            if rk in real_room_slots:
                ghost_hc += 1
            else:
                real_room_slots[rk] = asgn['course_i']

    hc_count = ghost_hc   # all courses assigned; conflicts are clashes, not gaps
    fitness  = hc_count * HC_WEIGHT + sc_value

    metrics = {
        'hc_count':      hc_count,
        'hc_value':      hc_count * HC_WEIGHT,
        'hc_unassigned': 0,          # every course got a slot (possibly clashing)
        'hc_ghost':      ghost_hc,
        'sc_count':      sc_count,
        'sc_value':      sc_value,
        'repaired':      0,
        'stuck_indices': [],         # no courses are "stuck"; all are placed
    }

    # sol_x is a fresh random vector — representative of this random state
    sol_x = np.random.rand(_N_COURSES)

    return Solution(sol_x, fitness, assignments, metrics)


# ==========================================
# 7. Solution Class
# ==========================================
class Solution:
    __slots__ = ('X', 'Cost', 'assignments', 'metrics')

    def __init__(self, x, cost, assignments=None, metrics=None):
        self.X = x;  self.Cost = cost
        self.assignments = assignments;  self.metrics = metrics

    def clone(self):
        return Solution(self.X.copy(), self.Cost, self.assignments, self.metrics)


# ==========================================
# 8. Parallel Evaluator
# ==========================================
def parallel_eval(vectors, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), len(vectors))
    if n_workers <= 1 or len(vectors) <= 4:
        return [fitness_function(v) for v in vectors]
    results = [None] * len(vectors)
    with ProcessPoolExecutor(max_workers=n_workers) as pool:
        futures = {pool.submit(_eval_worker, v): i for i, v in enumerate(vectors)}
        for fut in as_completed(futures):
            results[futures[fut]] = fut.result()
    return results


# ==========================================
# 9. POA Operators (mechanism unchanged)
# ==========================================
def exploration(Sol, lb, ub, dim, nSol, n_workers):
    pCR = 0.20
    PCR = 1 - pCR
    p   = PCR / nSol
    Sol.sort(key=lambda s: s.Cost)
    new_vectors = []
    for i in range(nSol):
        x = Sol[i].X
        A = list(range(nSol)); A.remove(i); np.random.shuffle(A)
        a, b, c, d, e, f = A[:6]
        G = 2 * np.random.rand() - 1
        if np.random.rand() < 0.5:
            y = np.random.rand(dim) * (ub - lb) + lb
        else:
            da = Sol[a].X - Sol[b].X
            db = Sol[c].X - Sol[d].X
            dc = Sol[e].X - Sol[f].X
            y  = Sol[a].X + G * da + G * ((da - db) + (db - dc))
        y = np.clip(y, lb, ub)
        z = x.copy()
        j0 = np.random.randint(dim)
        mask = (np.random.rand(dim) <= pCR); mask[j0] = True
        z[mask] = y[mask]
        new_vectors.append(z)
    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
        else:
            pCR = pCR + p
    return Sol


def exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers):
    Q, Beta = 0.67, 2
    mbest = np.mean([s.X for s in Sol], axis=0)
    new_vectors = []
    for i in range(nSol):
        beta1 = 2 * np.random.rand()
        beta2 = np.random.randn(dim)
        w, v  = np.random.randn(dim), np.random.randn(dim)
        F1 = np.random.randn(dim) * np.exp(2 - Iter * (2 / MaxIter))
        F2 = w * (v ** 2) * np.cos(2 * np.random.rand() * w)
        R_1 = 2 * np.random.rand() - 1
        S1  = (2 * np.random.rand() - 1 + np.random.randn(dim))
        S2  = F1 * R_1 * Sol[i].X + F2 * (1 - R_1) * Best.X
        VEC = S2 / (S1 + 1e-10)
        if np.random.rand() <= 0.5:
            if np.random.rand() > Q:
                r_idx = np.random.randint(nSol)
                x_new = Best.X + beta1 * np.exp(beta2) * (Sol[r_idx].X - Sol[i].X)
            else:
                x_new = beta1 * VEC - Best.X
        else:
            r1   = np.random.randint(nSol)
            sign = (-1) ** np.random.randint(0, 2)
            x_new = (mbest * Sol[r1].X - sign * Sol[i].X) / (1 + Beta * np.random.rand())
        new_vectors.append(np.clip(x_new, lb, ub))
    results = parallel_eval(new_vectors, n_workers)
    for i, (cost, asg, met) in enumerate(results):
        candidate = Solution(new_vectors[i], cost, asg, met)
        if candidate.Cost < Sol[i].Cost:
            Sol[i] = candidate
    return Sol


# ==========================================
# 10. Adaptive Strategies
# ==========================================
def make_targeted_seed(stuck_indices, dim, lb, ub, best_x=None):
    """
    Create a new solution vector that gives maximum priority to stuck courses.
    """
    x = best_x.copy() if best_x is not None else lb + (ub - lb) * np.random.rand(dim)
    for idx in stuck_indices:
        if idx < dim:
            x[idx] = 0.9 + np.random.rand() * 0.1
    return np.clip(x, lb, ub)


def levy_perturbation(x, lb, ub, scale=0.1):
    """Apply a Levy-flight perturbation to solution vector x."""
    step = levy_flight(len(x)) * scale
    return np.clip(x + step * (ub - lb), lb, ub)


def adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                  stuck_indices, stagnation_hc, n_workers):
    """
    Three-tier adaptive recovery based on HC-stagnation depth.
    """
    Sol.sort(key=lambda s: s.Cost)
    new_vecs = []
    indices  = []

    if stagnation_hc < 15:
        n_replace = nSol // 3
        for k in range(n_replace):
            x = make_targeted_seed(stuck_indices, dim, lb, ub,
                                   best_x=Sol[-(k + 1)].X)
            new_vecs.append(x)
            indices.append(nSol - 1 - k)

    elif stagnation_hc < 30:
        n_replace = nSol // 2
        for k in range(n_replace):
            if k % 2 == 0:
                x = make_targeted_seed(stuck_indices, dim, lb, ub, best_x=Best.X)
                x = levy_perturbation(x, lb, ub, scale=0.15)
            else:
                x = levy_perturbation(Best.X, lb, ub, scale=0.25)
                for idx in stuck_indices:
                    if idx < dim:
                        x[idx] = np.clip(x[idx] + 0.4, lb, ub)
            new_vecs.append(x)
            indices.append(nSol - 1 - k)

    else:
        n_keep     = max(1, nSol // 5)
        n_replace  = nSol - n_keep
        n_targeted = n_replace * 2 // 5
        n_levy     = n_replace // 5
        n_random   = n_replace - n_targeted - n_levy

        for k in range(n_targeted):
            x = make_targeted_seed(stuck_indices, dim, lb, ub, best_x=Best.X)
            x = levy_perturbation(x, lb, ub, scale=0.05)
            new_vecs.append(x)
            indices.append(n_keep + k)

        for k in range(n_levy):
            x = levy_perturbation(Best.X, lb, ub, scale=0.35)
            new_vecs.append(x)
            indices.append(n_keep + n_targeted + k)

        for k in range(n_random):
            x = lb + (ub - lb) * np.random.rand(dim)
            new_vecs.append(x)
            indices.append(n_keep + n_targeted + n_levy + k)

    if not new_vecs:
        return Sol

    results = parallel_eval(new_vecs, n_workers)
    for pos, (cost, asg, met) in zip(indices, results):
        Sol[pos] = Solution(new_vecs[indices.index(pos)], cost, asg, met)

    return Sol


# ==========================================
# 11. Logging
# ==========================================
def print_iteration_log(Iter, Sol, Best, elapsed, tag=''):
    worst = max(s.Cost for s in Sol)
    m = Best.metrics
    prefix = f"[{tag}] " if tag else ''
    print(
        f"{prefix}Iter {Iter:03d} | Best: {Best.Cost:12.0f} | Worst: {worst:12.0f} | "
        f"HC: {m['hc_count']:3d} (u:{m['hc_unassigned']} g:{m['hc_ghost']}) | "
        f"Repaired: {m['repaired']:3d} | SC: {m['sc_value']:6.0f} | {elapsed:.1f}s"
    )


# ==========================================
# 12. Main Optimizer
# ==========================================
def run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None):
    n_workers = n_workers or min(os.cpu_count(), nSol)
    print(f"[INFO] Parallel workers : {n_workers}")
    print(f"[INFO] HC weight        : {HC_WEIGHT:,}")
    print(f"[INFO] Total courses    : {_N_COURSES}")

    # ── Random initial representative ─────────────────────────────────────────
    # Build a random mix-matched assignment as the starting guide.
    # This representative is intentionally conflicting — it assigns every
    # course to a random compatible room and timeslot without any conflict
    # checking. No greedy ordering, no MCF, no heuristic bias.
    #
    # POA will use this conflicting state as its initial Best/alpha for the
    # first iterations, then progressively discover conflict-free regions of
    # the search space entirely through its own exploration/exploitation
    # mechanism.
    #
    # This is distinct from the population: the population vectors are still
    # random sol_x draws that get decoded by fitness_function(). The
    # representative is a direct random assignment used only as the initial
    # guide vector before the population's best takes over.
    print("\n[INFO] Membuat solusi representatif awal secara acak (random mix-match)...")
    Best         = build_random_solution()
    Initial_Best = Best.clone()

    m = Best.metrics
    print(f"\nRandom Representative | Fitness: {Best.Cost:12.0f} | "
          f"HC: {m['hc_count']:3d} (u:{m['hc_unassigned']} g:{m['hc_ghost']}) | "
          f"SC: {m['sc_value']:.0f}")
    print(f"[INFO] Catatan: HC violations ini berasal dari penugasan acak tanpa conflict-check.\n"
          f"       POA akan mereduksi ke 0 dalam {MaxIter} iterasi.")

    # ── Initial population (all purely random — no MCF seed) ─────────────────
    # Every population member starts as a uniform random vector in [0, 1]^N.
    # Removing the MCF seed means no single vector gets a heuristic head start;
    # the fitness decoder still applies MCF inside Phase 1, but the ordering
    # weight comes from the random sol_x values, not a hand-crafted initializer.
    print("Mengevaluasi populasi inisial (semua acak)...")
    init_vectors = [lb + (ub - lb) * np.random.rand(dim) for _ in range(nSol)]
    results      = parallel_eval(init_vectors, n_workers)
    Sol          = [Solution(init_vectors[i], *results[i]) for i in range(nSol)]

    # Population best is tracked separately — it does NOT replace the
    # random representative as the initial guide. POA starts from Best
    # (the random mix-match) and the population improves around it.
    pop_best = min(Sol, key=lambda s: s.Cost)
    print(f"Population Best  | Fitness: {pop_best.Cost:12.0f} | "
          f"HC: {pop_best.metrics['hc_count']:3d} | "
          f"SC: {pop_best.metrics['sc_value']:.0f}")
    print(f"\n[INFO] Guide awal = solusi acak (HC={Best.metrics['hc_count']}), "
          f"bukan population best (HC={pop_best.metrics['hc_count']}).")

    # ── POA state variables ───────────────────────────────────────────────────
    UnSelected = [1, 1]
    F3_Explore = F3_Exploit = 0
    Seq_Time_Explore  = [1, 1, 1];  Seq_Time_Exploit  = [1, 1, 1]
    Seq_Cost_Explore  = [1, 1, 1];  Seq_Cost_Exploit  = [1, 1, 1]
    PF            = [0.5, 0.5, 0.3]
    PF_F3         = []
    Mega_Explor   = Mega_Exploit = 0.99
    Costs_Explor  = np.zeros(3)
    Costs_Exploit = np.zeros(3)
    Flag_Change   = 1

    # ── Adaptive tracking variables ───────────────────────────────────────────
    stagnation_sc  = 0
    stagnation_hc  = 0
    prev_best_cost = Best.Cost
    prev_best_hc   = Best.metrics['hc_count']
    stuck_indices  = list(Best.metrics.get('stuck_indices', []))

    print("\n" + "=" * 110)
    print("  PUMA OPTIMISER — ADAPTIVE CONFLICT-DIRECTED REPAIR  [Random Init Representative]".center(110))
    print("=" * 110)

    t_start = time.perf_counter()

    # ── Bootstrap iterations 1–3 ──────────────────────────────────────────────
    # During bootstrap, Best is still the random representative.
    # Exploitation uses Best.X as the guide vector, spreading the population
    # away from the random starting state. By the end of iter 3, Best is
    # updated to the best solution found so far by the population.
    for Iter in range(1, 4):
        Sol_E1 = exploration ([s.clone() for s in Sol], lb, ub, dim, nSol, n_workers)
        Sol_E2 = exploitation([s.clone() for s in Sol], lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
        Costs_Explor[Iter - 1]  = min(s.Cost for s in Sol_E1)
        Costs_Exploit[Iter - 1] = min(s.Cost for s in Sol_E2)

        merged = Sol + Sol_E1 + Sol_E2
        merged.sort(key=lambda s: s.Cost)
        Sol  = merged[:nSol]

        # After each bootstrap iter, update Best to the best population member
        # if it has improved beyond the random representative.
        pop_candidate = Sol[0]
        if pop_candidate.Cost < Best.Cost:
            Best = pop_candidate

        print_iteration_log(Iter, Sol, Best, time.perf_counter() - t_start, tag='BOOT')

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC achieved at bootstrap iter {Iter}.")
            return Best

    Seq_Cost_Explore[0] = abs(Initial_Best.Cost  - Costs_Explor[0])
    Seq_Cost_Explore[1] = abs(Costs_Explor[1]    - Costs_Explor[0])
    Seq_Cost_Explore[2] = abs(Costs_Explor[2]    - Costs_Explor[1])
    Seq_Cost_Exploit[0] = abs(Initial_Best.Cost  - Costs_Exploit[0])
    Seq_Cost_Exploit[1] = abs(Costs_Exploit[1]   - Costs_Exploit[0])
    Seq_Cost_Exploit[2] = abs(Costs_Exploit[2]   - Costs_Exploit[1])
    for v in Seq_Cost_Explore + Seq_Cost_Exploit:
        if v != 0:
            PF_F3.append(v)

    # Update stagnation baseline to post-bootstrap Best
    prev_best_cost = Best.Cost
    prev_best_hc   = Best.metrics['hc_count']
    stuck_indices  = list(Best.metrics.get('stuck_indices', []))

    # ── Main loop ─────────────────────────────────────────────────────────────
    for Iter in range(4, MaxIter + 1):

        F1_Explor  = PF[0] * (Seq_Cost_Explore[0] / Seq_Time_Explore[0])
        F1_Exploit = PF[0] * (Seq_Cost_Exploit[0] / Seq_Time_Exploit[0])
        F2_Explor  = PF[1] * (sum(Seq_Cost_Explore) / sum(Seq_Time_Explore))
        F2_Exploit = PF[1] * (sum(Seq_Cost_Exploit) / sum(Seq_Time_Exploit))
        Score_Explore = Mega_Explor  * (F1_Explor  + F2_Explor)
        Score_Exploit = Mega_Exploit * (F1_Exploit + F2_Exploit)

        if Score_Explore > Score_Exploit:
            SelectFlag = 1
            Sol = exploration(Sol, lb, ub, dim, nSol, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[1] += 1;  UnSelected[0] = 1
            F3_Explore = PF[2];  F3_Exploit += PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Explore[2], Seq_Cost_Explore[1] = Seq_Cost_Explore[1], Seq_Cost_Explore[0]
            Seq_Cost_Explore[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Explore[0]: PF_F3.append(Seq_Cost_Explore[0])
        else:
            SelectFlag = 2
            Sol = exploitation(Sol, lb, ub, dim, nSol, Best, MaxIter, Iter, n_workers)
            Count_select = UnSelected.copy()
            UnSelected[0] += 1;  UnSelected[1] = 1
            F3_Explore += PF[2];  F3_Exploit = PF[2]
            TBest = min(Sol, key=lambda s: s.Cost)
            Seq_Cost_Exploit[2], Seq_Cost_Exploit[1] = Seq_Cost_Exploit[1], Seq_Cost_Exploit[0]
            Seq_Cost_Exploit[0] = abs(Best.Cost - TBest.Cost)
            if Seq_Cost_Exploit[0]: PF_F3.append(Seq_Cost_Exploit[0])

        if TBest.Cost < Best.Cost:
            Best = TBest

        if Flag_Change != SelectFlag:
            Flag_Change = SelectFlag
            Seq_Time_Explore[2], Seq_Time_Explore[1], Seq_Time_Explore[0] = \
                Seq_Time_Explore[1], Seq_Time_Explore[0], Count_select[0]
            Seq_Time_Exploit[2], Seq_Time_Exploit[1], Seq_Time_Exploit[0] = \
                Seq_Time_Exploit[1], Seq_Time_Exploit[0], Count_select[1]

        if Score_Explore < Score_Exploit:
            Mega_Explor  = max(Mega_Explor  - 0.01, 0.01)
            Mega_Exploit = 0.99
        else:
            Mega_Explor  = 0.99
            Mega_Exploit = max(Mega_Exploit - 0.01, 0.01)

        elapsed = time.perf_counter() - t_start
        print_iteration_log(Iter, Sol, Best, elapsed)

        if Best.metrics['hc_count'] == 0:
            print(f"[INFO] Zero HC violations achieved at iteration {Iter}.")
            break

        # ── Adaptive stagnation tracking ──────────────────────────────────────
        cur_hc   = Best.metrics['hc_count']
        cur_cost = Best.Cost
        stuck_indices = list(Best.metrics.get('stuck_indices', []))

        if cur_hc < prev_best_hc:
            stagnation_hc = 0
            prev_best_hc  = cur_hc
            print(f"         ↳ HC improved: {prev_best_hc + (prev_best_hc - cur_hc)} → {cur_hc}")
        else:
            stagnation_hc += 1

        if cur_cost < prev_best_cost:
            stagnation_sc = 0
            prev_best_cost = cur_cost
        else:
            stagnation_sc += 1

        if stagnation_hc > 0 and stagnation_hc % 30 == 0:
            print(f"[ADAPT-T3] Iter {Iter} — Full adaptive restart "
                  f"(HC stagnant {stagnation_hc} iters, stuck={len(stuck_indices)} courses)")
            Sol = adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                               stuck_indices, stagnation_hc, n_workers)
            Sol.sort(key=lambda s: s.Cost)
            new_best = Sol[0]
            if new_best.Cost < Best.Cost:
                Best = new_best
            stagnation_hc = 0
            stagnation_sc = 0

        elif stagnation_hc > 0 and stagnation_hc % 15 == 0:
            print(f"[ADAPT-T2] Iter {Iter} — Levy flight + targeted seeds "
                  f"(HC stagnant {stagnation_hc} iters)")
            Sol = adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                               stuck_indices, stagnation_hc, n_workers)
            Sol.sort(key=lambda s: s.Cost)
            if Sol[0].Cost < Best.Cost:
                Best = Sol[0]

        elif stagnation_hc > 0 and stagnation_hc % 5 == 0:
            print(f"[ADAPT-T1] Iter {Iter} — Targeted perturbation of stuck courses "
                  f"(HC stagnant {stagnation_hc} iters)")
            Sol = adaptive_stagnation_recovery(Sol, Best, lb, ub, dim, nSol,
                                               stuck_indices, stagnation_hc, n_workers)
            Sol.sort(key=lambda s: s.Cost)
            if Sol[0].Cost < Best.Cost:
                Best = Sol[0]

        elif stagnation_sc >= 10:
            print(f"[STAG-SC] Iter {Iter} — SC stagnation recovery (random diversity)")
            n_replace = nSol // 3
            new_vecs = [lb + (ub - lb) * np.random.rand(dim) for _ in range(n_replace)]
            res = parallel_eval(new_vecs, n_workers)
            for k, (c, a, met) in enumerate(res):
                Sol[-(k + 1)] = Solution(new_vecs[k], c, a, met)
            stagnation_sc = 0

    total = time.perf_counter() - t_start
    print(f"\n[INFO] Optimasi selesai dalam {total:.1f}s")

    # ── Post-run feasibility diagnosis ────────────────────────────────────────
    final_stuck = Best.metrics.get('stuck_indices', [])
    if final_stuck:
        print("\n" + "=" * 80)
        print("  FEASIBILITY DIAGNOSIS — Courses that could not be scheduled")
        print("=" * 80)
        teacher_counts = {}
        for cidx in final_stuck:
            tid = _TEACHER[cidx]
            cname = mk_df_raw['course_name'].iloc[cidx]
            teacher_counts[tid] = teacher_counts.get(tid, 0) + 1
            print(f"  Course idx {cidx:4d} | teacher: {tid:>8} | {cname}")
        print()
        print("  Teacher capacity summary:")
        for tid, n_stuck in sorted(teacher_counts.items(), key=lambda x: -x[1]):
            total_assigned = sum(
                1 for a in Best.assignments if a['teacher'] == tid
            )
            n_slots = len(valid_starts)
            print(f"    Teacher {tid:>8}: {n_stuck} stuck, "
                  f"{total_assigned} assigned, "
                  f"{n_slots} total timeslot pairs available per room type")
        print("=" * 80)
        print("  If stuck count = total slots available for teacher, the problem")
        print("  is infeasible for that teacher — reduce their course load in the dataset.")

    return Best


# ==========================================
# 13. Eksekusi & Ekspor
# ==========================================
if __name__ == '__main__':
    nSol    = 50
    MaxIter = 100
    dim     = _N_COURSES
    lb, ub  = 0.0, 1.0

    t0 = time.perf_counter()
    best_solution = run_puma_optimizer(nSol, MaxIter, lb, ub, dim, n_workers=None)
    print(f"Total elapsed: {time.perf_counter() - t0:.1f}s")

    res_list = []
    for a in best_solution.assignments:
        course = mk_df_raw.iloc[a['course_i']]
        room   = rooms_df.iloc[a['room']]
        t1     = timeslots_df.iloc[a['start_slot']]
        t2     = timeslots_df.iloc[a['end_slot']]
        res_list.append({
            'event_id':    course['event_id'],
            'course_name': course['course_name'],
            'teacher_id':  course['teacher_id'],
            'room_id':     room['room_id'],
            'day':         t1['day'],
            'time_start':  t1['time_start'],
            'time_end':    t2['time_end'],
        })

    res_df   = pd.DataFrame(res_list)
    out_path = 'scheduled_courses_poa_random_init_v2.csv'
    res_df.to_csv(out_path, index=False)

    m = best_solution.metrics
    print(f"\n{'=' * 65}")
    print(f"  FINAL RESULT")
    print(f"  HC Violations  : {m['hc_count']}  "
          f"(unassigned: {m['hc_unassigned']}, ghost: {m['hc_ghost']})")
    print(f"  HC Penalty     : {m['hc_value']:,}")
    print(f"  Repaired by P2 : {m['repaired']}")
    print(f"  SC Violations  : {m['sc_count']}  (penalty: {m['sc_value']})")
    print(f"  Total Fitness  : {best_solution.Cost:,}")
    print(f"  Courses scheduled: {len(res_list)} / {_N_COURSES}")
    print(f"{'=' * 65}")
    print(f"[INFO] Solusi disimpan di '{out_path}'")
# Out:
# [INFO] Memuat dan memproses dataset...
# [INFO] Parallel workers : 8
# [INFO] HC weight        : 10,000,000
# [INFO] Total courses    : 725
#
# [INFO] Membuat solusi representatif awal secara acak (random mix-match)...
#
# Random Representative | Fitness:   4880017440 | HC: 488 (u:0 g:488) | SC: 17440
# [INFO] Catatan: HC violations ini berasal dari penugasan acak tanpa conflict-check.
#        POA akan mereduksi ke 0 dalam 100 iterasi.
# Mengevaluasi populasi inisial (semua acak)...
# Population Best  | Fitness:         4960 | HC:   0 | SC: 4960
#
# [INFO] Guide awal = solusi acak (HC=488), bukan population best (HC=0).
#
# ==============================================================================================================
#                 PUMA OPTIMISER — ADAPTIVE CONFLICT-DIRECTED REPAIR  [Random Init Representative]
# ==============================================================================================================
# [BOOT] Iter 001 | Best:         2810 | Worst:         5110 | HC:   0 (u:0 g:0) | Repaired:   0 | SC:   2810 | 6.7s
# [INFO] Zero HC achieved at bootstrap iter 1.
# Total elapsed: 10.4s
#
# =================================================================
#   FINAL RESULT
#   HC Violations  : 0  (unassigned: 0, ghost: 0)
#   HC Penalty     : 0
#   Repaired by P2 : 0
#   SC Violations  : 7  (penalty: 2810)
#   Total Fitness  : 2,810
#   Courses scheduled: 725 / 725
# =================================================================
# [INFO] Solusi disimpan di 'scheduled_courses_poa_random_init_v2.csv'
