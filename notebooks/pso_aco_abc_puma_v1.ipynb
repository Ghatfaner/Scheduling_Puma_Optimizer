# %% [markdown]
# # Import library

# %%
import pandas as pd
import numpy as np
import random
import datetime
from collections import defaultdict
import copy
import matplotlib.pyplot as plt

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# # Dataset Configuration

# %%
# Memuat dataset
try:
    df_mk = pd.read_csv('./mk_dsi.csv')
    df_ruang = pd.read_csv('./ruang_kuliah.csv')

    # Langsung ganti nama kolom setelah memuat untuk menghindari error
    # dan membuat kode lebih robust (tahan banting).
    df_mk.columns = ['kode_mk', 'nama_mk', 'prodi', 'prioritas', 'berminat', 'dosen_id']
    df_ruang.columns = ['kode_ruang', 'lokasi', 'lantai', 'keterangan']

    # Mengisi nilai kosong di kolom dosen_id dan memastikan tipe data string.
    df_mk['dosen_id'] = df_mk['dosen_id'].fillna('Belum Ada Dosen').astype(str)

except FileNotFoundError:
    print("--- GAGAL MEMUAT FILE ---")
    print("Pastikan file 'mk_dsi.csv' dan 'ruang_kuliah.csv' ada di direktori yang sama dengan notebook ini.")
    df_mk, df_ruang = pd.DataFrame(), pd.DataFrame() # Buat dataframe kosong jika gagal

# Cek apakah dataframe berhasil dimuat sebelum melanjutkan
if not df_mk.empty:
    # --- PERUBAHAN UTAMA ---
    # Tidak lagi menghapus duplikat. Setiap baris di CSV dianggap sebagai
    # satu item unik yang harus dijadwalkan.
    list_of_courses_to_schedule = df_mk.to_dict('records')

    # Menyesuaikan struktur data agar kompatibel dengan sisa kode.
    # Fungsi fitness di sel berikutnya mengharapkan adanya 'dosen_list',
    # jadi kita buat list yang berisi satu dosen untuk setiap baris mata kuliah.
    for course in list_of_courses_to_schedule:
        # Dosen ID sudah ada, kita hanya perlu membungkusnya dalam sebuah list.
        course['dosen_list'] = [course['dosen_id']]

    list_ruang = df_ruang['kode_ruang'].unique().tolist()

    print("Pemuatan dan pra-pemrosesan data berhasil (setiap baris dianggap unik).")
    print(f"Total item mata kuliah yang akan dijadwalkan: {len(list_of_courses_to_schedule)}")
    print(f"Total Ruangan Tersedia: {len(list_ruang)}")
else:
    print("\nDataFrame kosong karena file tidak ditemukan. Eksekusi sel berikutnya kemungkinan akan gagal.")
    # Inisialisasi variabel agar tidak error di sel berikutnya
    list_of_courses_to_schedule = []
    list_ruang = []
# Out:
# Pemuatan dan pra-pemrosesan data berhasil (setiap baris dianggap unik).
# Total item mata kuliah yang akan dijadwalkan: 845
# Total Ruangan Tersedia: 44

# %% [markdown]
# # Define Time Slot & Rooms

# %%
# --- Definisi Slot Waktu ---
def generate_time_slots():
    slots = []
    days = {"Senin": 0, "Selasa": 1, "Rabu": 2, "Kamis": 3, "Jumat": 4}
    
    for day_name, day_index in days.items():
        start_time = datetime.datetime.strptime("07:00", "%H:%M")
        end_time = datetime.datetime.strptime("18:00", "%H:%M")
        
        if day_name in ["Senin", "Selasa", "Rabu", "Kamis"]:
            break_start = datetime.datetime.strptime("12:10", "%H:%M")
            break_end = datetime.datetime.strptime("12:30", "%H:%M")
        else: # Jumat
            break_start = datetime.datetime.strptime("11:15", "%H:%M")
            break_end = datetime.datetime.strptime("12:30", "%H:%M")
        
        current_time = start_time
        while current_time < end_time:
            slot_end_time = current_time + datetime.timedelta(minutes=50)
            if not (current_time >= break_start and current_time < break_end):
                 slots.append(f"{day_name}_{current_time.strftime('%H:%M')}-{slot_end_time.strftime('%H:%M')}")
            current_time = slot_end_time
            
    # Menambahkan slot khusus untuk pelajaran agama non-islam di hari Jumat
    # Asumsi: kita sediakan slotnya, penugasan MK-nya memerlukan logika tambahan
    special_break_start = datetime.datetime.strptime("11:15", "%H:%M")
    special_slot_end = special_break_start + datetime.timedelta(minutes=50)
    slots.append(f"Jumat_{special_break_start.strftime('%H:%M')}-{special_slot_end.strftime('%H:%M')}_AGAMA_KHUSUS")

    return slots

time_slots = generate_time_slots()

# --- Definisi Ruangan ---
ruang_lab = [r['kode_ruang'] for i, r in df_ruang.iterrows() if 'lab' in r['keterangan'].lower()]
ruang_reguler = [r for r in list_ruang if r not in ruang_lab]

# Menandai MK yang memerlukan lab
for mk in list_mk_unique:
    mk['jenis'] = 'lab' if 'praktikum' in mk['nama_mk'].lower() else 'reguler'

print(f"Total Slot Waktu Tersedia: {len(time_slots)}")
print(f"Total Ruang Reguler: {len(ruang_reguler)}, Total Ruang Lab: {len(ruang_lab)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 39
#      36 ruang_reguler = [r for r in list_ruang if r not in ruang_lab]
#      38 # Menandai MK yang memerlukan lab
# ---> 39 for mk in list_mk_unique:
#      40     mk['jenis'] = 'lab' if 'praktikum' in mk['nama_mk'].lower() else 'reguler'
#      42 print(f"Total Slot Waktu Tersedia: {len(time_slots)}")
#
# NameError: name 'list_mk_unique' is not defined

# %% [markdown]
# # Function to Evaluate

# %%
HARD_CONSTRAINT_PENALTY = 100
SOFT_CONSTRAINT_PENALTY = 1

def calculate_fitness(schedule, df_ruang_details, time_slots_list):
    """Menghitung skor fitness untuk satu jadwal (solusi). Semakin rendah semakin baik."""
    hard_violations = 0
    soft_score = 0
    
    room_time_usage = defaultdict(int)
    dosen_time_usage = defaultdict(list)

    # Iterasi untuk setiap alokasi MK dalam jadwal
    for slot in schedule:
        # Hard Constraint #1: Konflik Ruang dan Waktu
        room_time_key = (slot['ruang'], slot['waktu'])
        room_time_usage[room_time_key] += 1
        if room_time_usage[room_time_key] > 1:
            hard_violations += 1
            
        # Hard Constraint #2 & #3: Konflik Dosen
        for dosen in slot['dosen_list']:
            if dosen in dosen_time_usage[slot['waktu']]:
                hard_violations += 1
            dosen_time_usage[slot['waktu']].append(dosen)

    # Soft Constraint #1: Prioritas MK
    total_priority = sum(s['prioritas'] for s in schedule)
    soft_score += total_priority

    # Soft Constraint #2: Pergerakan Dosen
    dosen_schedule = defaultdict(list)
    for s in schedule:
        for dosen in s['dosen_list']:
            dosen_schedule[dosen].append({'waktu': s['waktu'], 'ruang': s['ruang']})

    for dosen, movements in dosen_schedule.items():
        if len(movements) > 1:
            sorted_movements = sorted(movements, key=lambda x: time_slots_list.index(x['waktu']))
            for i in range(len(sorted_movements) - 1):
                # Cek jika jadwal berurutan
                if time_slots_list.index(sorted_movements[i+1]['waktu']) == time_slots_list.index(sorted_movements[i]['waktu']) + 1:
                    try:
                        lantai_1 = df_ruang_details[df_ruang_details['kode_ruang'] == sorted_movements[i]['ruang']]['lantai'].iloc[0]
                        lantai_2 = df_ruang_details[df_ruang_details['kode_ruang'] == sorted_movements[i+1]['ruang']]['lantai'].iloc[0]
                        perbedaan_lantai = abs(lantai_1 - lantai_2)
                        if perbedaan_lantai > 1:
                            soft_score += perbedaan_lantai * SOFT_CONSTRAINT_PENALTY
                    except IndexError:
                        continue # Ruang tidak ditemukan

    return (hard_violations * HARD_CONSTRAINT_PENALTY) + soft_score, hard_violations

# Fungsi bantuan untuk membuat jadwal acak
def create_random_schedule(courses, rooms_reg, rooms_lab, times):
    schedule = []
    for course in courses:
        slot = copy.deepcopy(course)
        slot['ruang'] = random.choice(rooms_lab) if course['jenis'] == 'lab' else random.choice(rooms_reg)
        slot['waktu'] = random.choice(times)
        schedule.append(slot)
    return schedule

# %% [markdown]
# # Implementing PSO

# %%
class Particle:
    def __init__(self, courses, rooms_reg, rooms_lab, times):
        self.position = create_random_schedule(courses, rooms_reg, rooms_lab, times)
        self.velocity = [0] * len(courses) # Velocity sederhana, bisa dikembangkan
        self.best_position = copy.deepcopy(self.position)
        self.fitness, self.violations = float('inf'), float('inf')
        self.best_fitness = float('inf')

def pso_optimizer(courses, rooms_reg, rooms_lab, times, df_ruang_details, time_slots_list,
                  n_particles=30, n_iterations=100, w=0.5, c1=1.5, c2=1.5):
    
    swarm = [Particle(courses, rooms_reg, rooms_lab, times) for _ in range(n_particles)]
    global_best_position = None
    global_best_fitness = float('inf')
    fitness_history = []

    for i in range(n_iterations):
        for particle in swarm:
            particle.fitness, particle.violations = calculate_fitness(particle.position, df_ruang_details, time_slots_list)
            
            if particle.fitness < particle.best_fitness:
                particle.best_fitness = particle.fitness
                particle.best_position = copy.deepcopy(particle.position)
            
            if particle.fitness < global_best_fitness:
                global_best_fitness = particle.fitness
                global_best_position = copy.deepcopy(particle.position)

        # Update velocity and position
        for particle in swarm:
            new_position = copy.deepcopy(particle.position)
            for j in range(len(courses)):
                # Cognitive component (menuju pbest)
                if random.random() < c1:
                    new_position[j]['ruang'] = particle.best_position[j]['ruang']
                    new_position[j]['waktu'] = particle.best_position[j]['waktu']
                
                # Social component (menuju gbest)
                if random.random() < c2:
                    new_position[j]['ruang'] = global_best_position[j]['ruang']
                    new_position[j]['waktu'] = global_best_position[j]['waktu']
            
            particle.position = new_position
        
        fitness_history.append(global_best_fitness)
        print(f"PSO Iteration {i+1}/{n_iterations} | Best Fitness: {global_best_fitness}")
        
    final_fitness, final_violations = calculate_fitness(global_best_position, df_ruang_details, time_slots_list)
    return global_best_position, final_fitness, final_violations, fitness_history

# %% [markdown]
# # Run the PSO Algorithm

# %%
print("\n--- Menjalankan Particle Swarm Optimization ---")
PSO_PARTICLES = 50
PSO_ITERATIONS = 100

pso_best_schedule, pso_fitness, pso_violations, pso_history = pso_optimizer(
    list_mk_unique, ruang_reguler, ruang_lab, time_slots, df_ruang, time_slots,
    n_particles=PSO_PARTICLES, n_iterations=PSO_ITERATIONS
)

print("\n--- Hasil PSO ---")
print(f"Skor Fitness Terbaik: {pso_fitness}")
print(f"Jumlah Pelanggaran Hard Constraint: {pso_violations}")
pd.DataFrame(pso_best_schedule).to_csv('jadwal_pso.csv', index=False)
print("Jadwal terbaik dari PSO disimpan sebagai 'jadwal_pso.csv'")
# Out:
# --- Menjalankan Particle Swarm Optimization ---
# PSO Iteration 1/100 | Best Fitness: 20572
# PSO Iteration 2/100 | Best Fitness: 20572
# PSO Iteration 3/100 | Best Fitness: 20572
# PSO Iteration 4/100 | Best Fitness: 20572
# PSO Iteration 5/100 | Best Fitness: 20572
# PSO Iteration 6/100 | Best Fitness: 20572
# PSO Iteration 7/100 | Best Fitness: 20572
# PSO Iteration 8/100 | Best Fitness: 20572
# PSO Iteration 9/100 | Best Fitness: 20572
# PSO Iteration 10/100 | Best Fitness: 20572
# PSO Iteration 11/100 | Best Fitness: 20572
# PSO Iteration 12/100 | Best Fitness: 20572
# PSO Iteration 13/100 | Best Fitness: 20572
# PSO Iteration 14/100 | Best Fitness: 20572
# PSO Iteration 15/100 | Best Fitness: 20572
# PSO Iteration 16/100 | Best Fitness: 20572
# PSO Iteration 17/100 | Best Fitness: 20572
# PSO Iteration 18/100 | Best Fitness: 20572
# PSO Iteration 19/100 | Best Fitness: 20572
# PSO Iteration 20/100 | Best Fitness: 20572
# PSO Iteration 21/100 | Best Fitness: 20572
# PSO Iteration 22/100 | Best Fitness: 20572
# PSO Iteration 23/100 | Best Fitness: 20572
# PSO Iteration 24/100 | Best Fitness: 20572
# PSO Iteration 25/100 | Best Fitness: 20572
# PSO Iteration 26/100 | Best Fitness: 20572
# PSO Iteration 27/100 | Best Fitness: 20572
# PSO Iteration 28/100 | Best Fitness: 20572
# PSO Iteration 29/100 | Best Fitness: 20572
# PSO Iteration 30/100 | Best Fitness: 20572
# PSO Iteration 31/100 | Best Fitness: 20572
# PSO Iteration 32/100 | Best Fitness: 20572
# PSO Iteration 33/100 | Best Fitness: 20572
# PSO Iteration 34/100 | Best Fitness: 20572
# PSO Iteration 35/100 | Best Fitness: 20572
# PSO Iteration 36/100 | Best Fitness: 20572
# PSO Iteration 37/100 | Best Fitness: 20572
# PSO Iteration 38/100 | Best Fitness: 20572
# PSO Iteration 39/100 | Best Fitness: 20572
# PSO Iteration 40/100 | Best Fitness: 20572
# PSO Iteration 41/100 | Best Fitness: 20572
# PSO Iteration 42/100 | Best Fitness: 20572
# PSO Iteration 43/100 | Best Fitness: 20572
# PSO Iteration 44/100 | Best Fitness: 20572
# PSO Iteration 45/100 | Best Fitness: 20572
# PSO Iteration 46/100 | Best Fitness: 20572
# PSO Iteration 47/100 | Best Fitness: 20572
# PSO Iteration 48/100 | Best Fitness: 20572
# PSO Iteration 49/100 | Best Fitness: 20572
# PSO Iteration 50/100 | Best Fitness: 20572
# PSO Iteration 51/100 | Best Fitness: 20572
# PSO Iteration 52/100 | Best Fitness: 20572
# PSO Iteration 53/100 | Best Fitness: 20572
# PSO Iteration 54/100 | Best Fitness: 20572
# PSO Iteration 55/100 | Best Fitness: 20572
# PSO Iteration 56/100 | Best Fitness: 20572
# PSO Iteration 57/100 | Best Fitness: 20572
# PSO Iteration 58/100 | Best Fitness: 20572
# PSO Iteration 59/100 | Best Fitness: 20572
# PSO Iteration 60/100 | Best Fitness: 20572
# PSO Iteration 61/100 | Best Fitness: 20572
# PSO Iteration 62/100 | Best Fitness: 20572
# PSO Iteration 63/100 | Best Fitness: 20572
# PSO Iteration 64/100 | Best Fitness: 20572
# PSO Iteration 65/100 | Best Fitness: 20572
# PSO Iteration 66/100 | Best Fitness: 20572
# PSO Iteration 67/100 | Best Fitness: 20572
# PSO Iteration 68/100 | Best Fitness: 20572
# PSO Iteration 69/100 | Best Fitness: 20572
# PSO Iteration 70/100 | Best Fitness: 20572
# PSO Iteration 71/100 | Best Fitness: 20572
# PSO Iteration 72/100 | Best Fitness: 20572
# PSO Iteration 73/100 | Best Fitness: 20572
# PSO Iteration 74/100 | Best Fitness: 20572
# PSO Iteration 75/100 | Best Fitness: 20572
# PSO Iteration 76/100 | Best Fitness: 20572
# PSO Iteration 77/100 | Best Fitness: 20572
# PSO Iteration 78/100 | Best Fitness: 20572
# PSO Iteration 79/100 | Best Fitness: 20572
# PSO Iteration 80/100 | Best Fitness: 20572
# PSO Iteration 81/100 | Best Fitness: 20572
# PSO Iteration 82/100 | Best Fitness: 20572
# PSO Iteration 83/100 | Best Fitness: 20572
# PSO Iteration 84/100 | Best Fitness: 20572
# PSO Iteration 85/100 | Best Fitness: 20572
# PSO Iteration 86/100 | Best Fitness: 20572
# PSO Iteration 87/100 | Best Fitness: 20572
# PSO Iteration 88/100 | Best Fitness: 20572
# PSO Iteration 89/100 | Best Fitness: 20572
# PSO Iteration 90/100 | Best Fitness: 20572
# PSO Iteration 91/100 | Best Fitness: 20572
# PSO Iteration 92/100 | Best Fitness: 20572
# PSO Iteration 93/100 | Best Fitness: 20572
# PSO Iteration 94/100 | Best Fitness: 20572
# PSO Iteration 95/100 | Best Fitness: 20572
# PSO Iteration 96/100 | Best Fitness: 20572
# PSO Iteration 97/100 | Best Fitness: 20572
# PSO Iteration 98/100 | Best Fitness: 20572
# PSO Iteration 99/100 | Best Fitness: 20572
# PSO Iteration 100/100 | Best Fitness: 20572
#
# --- Hasil PSO ---
# Skor Fitness Terbaik: 20572
# Jumlah Pelanggaran Hard Constraint: 202
# Jadwal terbaik dari PSO disimpan sebagai 'jadwal_pso.csv'

# %% [markdown]
# # Implementing Ant Colony Optimization (ACO)

# %%
def aco_optimizer(courses, rooms_reg, rooms_lab, times, df_ruang_details, time_slots_list,
                  n_ants=10, n_iterations=100, alpha=1.0, beta=2.0, evaporation_rate=0.5):

    pheromones = defaultdict(lambda: 1.0)
    best_schedule_overall = None
    best_fitness_overall = float('inf')
    fitness_history = []

    for i in range(n_iterations):
        schedules = []
        for ant in range(n_ants):
            schedule = []
            available_courses = copy.deepcopy(courses)
            random.shuffle(available_courses)
            
            for course in available_courses:
                # Memilih kombinasi ruang & waktu
                choices = []
                possible_rooms = rooms_lab if course['jenis'] == 'lab' else rooms_reg
                for room in possible_rooms:
                    for time in times:
                        # Heuristic (sederhana): preferensi acak
                        heuristic = random.random() 
                        pheromone_level = pheromones[(course['kode_mk'], room, time)]
                        prob = (pheromone_level ** alpha) * (heuristic ** beta)
                        choices.append({'prob': prob, 'room': room, 'time': time})
                
                # Normalisasi probabilitas dan pilih
                total_prob = sum(c['prob'] for c in choices)
                if total_prob == 0: # Jika tidak ada pilihan, pilih acak
                    chosen_room = random.choice(possible_rooms)
                    chosen_time = random.choice(times)
                else:
                    r = random.uniform(0, total_prob)
                    upto = 0
                    for c in choices:
                        if upto + c['prob'] >= r:
                            chosen_room = c['room']
                            chosen_time = c['time']
                            break
                        upto += c['prob']

                slot = copy.deepcopy(course)
                slot['ruang'] = chosen_room
                slot['waktu'] = chosen_time
                schedule.append(slot)
            
            schedules.append(schedule)

        # Evaporasi feromon
        for key in pheromones:
            pheromones[key] *= (1 - evaporation_rate)

        # Deposit feromon oleh semut
        best_schedule_iter = None
        best_fitness_iter = float('inf')
        for schedule in schedules:
            fitness, violations = calculate_fitness(schedule, df_ruang_details, time_slots_list)
            if fitness < best_fitness_iter:
                best_fitness_iter = fitness
                best_schedule_iter = schedule
            
            # Deposit berdasarkan kualitas
            for slot in schedule:
                pheromones[(slot['kode_mk'], slot['ruang'], slot['waktu'])] += 1.0 / (1.0 + fitness)

        if best_fitness_iter < best_fitness_overall:
            best_fitness_overall = best_fitness_iter
            best_schedule_overall = best_schedule_iter

        fitness_history.append(best_fitness_overall)
        print(f"ACO Iteration {i+1}/{n_iterations} | Best Fitness: {best_fitness_overall}")

    final_fitness, final_violations = calculate_fitness(best_schedule_overall, df_ruang_details, time_slots_list)
    return best_schedule_overall, final_fitness, final_violations, fitness_history

# %% [markdown]
# # Run the ACO Algorithm

# %%
print("\n--- Menjalankan Ant Colony Optimization ---")
ACO_ANTS = 50
ACO_ITERATIONS = 100

aco_best_schedule, aco_fitness, aco_violations, aco_history = aco_optimizer(
    list_mk_unique, ruang_reguler, ruang_lab, time_slots, df_ruang, time_slots,
    n_ants=ACO_ANTS, n_iterations=ACO_ITERATIONS
)

print("\n--- Hasil ACO ---")
print(f"Skor Fitness Terbaik: {aco_fitness}")
print(f"Jumlah Pelanggaran Hard Constraint: {aco_violations}")
pd.DataFrame(aco_best_schedule).to_csv('jadwal_aco.csv', index=False)
print("Jadwal terbaik dari ACO disimpan sebagai 'jadwal_aco.csv'")
# Out:
# --- Menjalankan Ant Colony Optimization ---
# ACO Iteration 1/100 | Best Fitness: 19987
# ACO Iteration 2/100 | Best Fitness: 19987
# ACO Iteration 3/100 | Best Fitness: 19987
# ACO Iteration 4/100 | Best Fitness: 19987
# ACO Iteration 5/100 | Best Fitness: 19987
# ACO Iteration 6/100 | Best Fitness: 19987
# ACO Iteration 7/100 | Best Fitness: 19987
# ACO Iteration 8/100 | Best Fitness: 19987
# ACO Iteration 9/100 | Best Fitness: 19987
# ACO Iteration 10/100 | Best Fitness: 19987
# ACO Iteration 11/100 | Best Fitness: 19987
# ACO Iteration 12/100 | Best Fitness: 19987
# ACO Iteration 13/100 | Best Fitness: 19874
# ACO Iteration 14/100 | Best Fitness: 19874
# ACO Iteration 15/100 | Best Fitness: 19874
# ACO Iteration 16/100 | Best Fitness: 19337
# ACO Iteration 17/100 | Best Fitness: 19337
# ACO Iteration 18/100 | Best Fitness: 19337
# ACO Iteration 19/100 | Best Fitness: 19337
# ACO Iteration 20/100 | Best Fitness: 19337
# ACO Iteration 21/100 | Best Fitness: 19337
# ACO Iteration 22/100 | Best Fitness: 19337
# ACO Iteration 23/100 | Best Fitness: 19337
# ACO Iteration 24/100 | Best Fitness: 19337
# ACO Iteration 25/100 | Best Fitness: 19337
# ACO Iteration 26/100 | Best Fitness: 19337
# ACO Iteration 27/100 | Best Fitness: 19337
# ACO Iteration 28/100 | Best Fitness: 19337
# ACO Iteration 29/100 | Best Fitness: 19337
# ACO Iteration 30/100 | Best Fitness: 19337
# ACO Iteration 31/100 | Best Fitness: 19337
# ACO Iteration 32/100 | Best Fitness: 19337
# ACO Iteration 33/100 | Best Fitness: 19337
# ACO Iteration 34/100 | Best Fitness: 19337
# ACO Iteration 35/100 | Best Fitness: 19337
# ACO Iteration 36/100 | Best Fitness: 19337
# ACO Iteration 37/100 | Best Fitness: 19337
# ACO Iteration 38/100 | Best Fitness: 19337
# ACO Iteration 39/100 | Best Fitness: 19337
# ACO Iteration 40/100 | Best Fitness: 19337
# ACO Iteration 41/100 | Best Fitness: 19337
# ACO Iteration 42/100 | Best Fitness: 19337
# ACO Iteration 43/100 | Best Fitness: 19337
# ACO Iteration 44/100 | Best Fitness: 19337
# ACO Iteration 45/100 | Best Fitness: 19337
# ACO Iteration 46/100 | Best Fitness: 19337
# ACO Iteration 47/100 | Best Fitness: 19337
# ACO Iteration 48/100 | Best Fitness: 19337
# ACO Iteration 49/100 | Best Fitness: 19337
# ACO Iteration 50/100 | Best Fitness: 19337
# ACO Iteration 51/100 | Best Fitness: 19337
# ACO Iteration 52/100 | Best Fitness: 19337
# ACO Iteration 53/100 | Best Fitness: 19337
# ACO Iteration 54/100 | Best Fitness: 19337
# ACO Iteration 55/100 | Best Fitness: 19337
# ACO Iteration 56/100 | Best Fitness: 19337
# ACO Iteration 57/100 | Best Fitness: 19337
# ACO Iteration 58/100 | Best Fitness: 19337
# ACO Iteration 59/100 | Best Fitness: 19337
# ACO Iteration 60/100 | Best Fitness: 19337
# ACO Iteration 61/100 | Best Fitness: 19337
# ACO Iteration 62/100 | Best Fitness: 19337
# ACO Iteration 63/100 | Best Fitness: 19337
# ACO Iteration 64/100 | Best Fitness: 19337
# ACO Iteration 65/100 | Best Fitness: 19337
# ACO Iteration 66/100 | Best Fitness: 19337
# ACO Iteration 67/100 | Best Fitness: 19337
# ACO Iteration 68/100 | Best Fitness: 19337
# ACO Iteration 69/100 | Best Fitness: 19337
# ACO Iteration 70/100 | Best Fitness: 19337
# ACO Iteration 71/100 | Best Fitness: 19337
# ACO Iteration 72/100 | Best Fitness: 19337
# ACO Iteration 73/100 | Best Fitness: 19337
# ACO Iteration 74/100 | Best Fitness: 19337
# ACO Iteration 75/100 | Best Fitness: 19337
# ACO Iteration 76/100 | Best Fitness: 19337
# ACO Iteration 77/100 | Best Fitness: 19337
# ACO Iteration 78/100 | Best Fitness: 19303
# ACO Iteration 79/100 | Best Fitness: 19303
# ACO Iteration 80/100 | Best Fitness: 19303
# ACO Iteration 81/100 | Best Fitness: 19303
# ACO Iteration 82/100 | Best Fitness: 19303
# ACO Iteration 83/100 | Best Fitness: 19303
# ACO Iteration 84/100 | Best Fitness: 19303
# ACO Iteration 85/100 | Best Fitness: 19303
# ACO Iteration 86/100 | Best Fitness: 19303
# ACO Iteration 87/100 | Best Fitness: 19303
# ACO Iteration 88/100 | Best Fitness: 19303
# ACO Iteration 89/100 | Best Fitness: 19303
# ACO Iteration 90/100 | Best Fitness: 19303
# ACO Iteration 91/100 | Best Fitness: 19303
# ACO Iteration 92/100 | Best Fitness: 19303
# ACO Iteration 93/100 | Best Fitness: 19303
# ACO Iteration 94/100 | Best Fitness: 19303
# ACO Iteration 95/100 | Best Fitness: 19303
# ACO Iteration 96/100 | Best Fitness: 19303
# ACO Iteration 97/100 | Best Fitness: 19303
# ACO Iteration 98/100 | Best Fitness: 19303
# ACO Iteration 99/100 | Best Fitness: 19303
# ACO Iteration 100/100 | Best Fitness: 19303
#
# --- Hasil ACO ---
# Skor Fitness Terbaik: 19303
# Jumlah Pelanggaran Hard Constraint: 190
# Jadwal terbaik dari ACO disimpan sebagai 'jadwal_aco.csv'

# %% [markdown]
# # Implementing Artificial Bee Colony

# %%
class FoodSource:
    def __init__(self, courses, rooms_reg, rooms_lab, times, df_ruang_details, time_slots_list):
        self.solution = create_random_schedule(courses, rooms_reg, rooms_lab, times)
        self.fitness, self.violations = calculate_fitness(self.solution, df_ruang_details, time_slots_list)
        self.trials = 0

def abc_optimizer(courses, rooms_reg, rooms_lab, times, df_ruang_details, time_slots_list,
                  n_bees=30, n_iterations=100, limit=10):
    
    colony = [FoodSource(courses, rooms_reg, rooms_lab, times, df_ruang_details, time_slots_list) for _ in range(n_bees)]
    best_solution_overall = None
    best_fitness_overall = float('inf')
    fitness_history = []

    for i in range(n_iterations):
        # Employed Bee Phase
        for j in range(n_bees):
            # Ciptakan solusi tetangga
            k = random.randint(0, len(courses) - 1)
            neighbor_solution = copy.deepcopy(colony[j].solution)
            
            # Ubah satu alokasi secara acak
            course_to_change = neighbor_solution[k]
            course_to_change['ruang'] = random.choice(rooms_lab) if courses[k]['jenis'] == 'lab' else random.choice(rooms_reg)
            course_to_change['waktu'] = random.choice(times)

            neighbor_fitness, _ = calculate_fitness(neighbor_solution, df_ruang_details, time_slots_list)
            
            if neighbor_fitness < colony[j].fitness:
                colony[j].solution = neighbor_solution
                colony[j].fitness = neighbor_fitness
                colony[j].trials = 0
            else:
                colony[j].trials += 1

        # Onlooker Bee Phase
        total_fitness = sum(1.0 / (1.0 + fs.fitness) for fs in colony)
        for j in range(n_bees):
            # Pilih sumber makanan berdasarkan probabilitas
            r = random.uniform(0, total_fitness)
            upto = 0
            selected_source_idx = -1
            for k, fs in enumerate(colony):
                upto += (1.0 / (1.0 + fs.fitness))
                if upto >= r:
                    selected_source_idx = k
                    break
            
            # Proses sama seperti employed bee
            k = random.randint(0, len(courses) - 1)
            neighbor_solution = copy.deepcopy(colony[selected_source_idx].solution)
            course_to_change = neighbor_solution[k]
            course_to_change['ruang'] = random.choice(rooms_lab) if courses[k]['jenis'] == 'lab' else random.choice(rooms_reg)
            course_to_change['waktu'] = random.choice(times)
            neighbor_fitness, _ = calculate_fitness(neighbor_solution, df_ruang_details, time_slots_list)

            if neighbor_fitness < colony[selected_source_idx].fitness:
                colony[selected_source_idx].solution = neighbor_solution
                colony[selected_source_idx].fitness = neighbor_fitness
                colony[selected_source_idx].trials = 0
            else:
                colony[selected_source_idx].trials += 1

        # Scout Bee Phase
        for j in range(n_bees):
            if colony[j].trials > limit:
                colony[j] = FoodSource(courses, rooms_reg, rooms_lab, times, df_ruang_details, time_slots_list)

        # Update best solution
        current_best = min(colony, key=lambda fs: fs.fitness)
        if current_best.fitness < best_fitness_overall:
            best_fitness_overall = current_best.fitness
            best_solution_overall = current_best.solution
        
        fitness_history.append(best_fitness_overall)
        print(f"ABC Iteration {i+1}/{n_iterations} | Best Fitness: {best_fitness_overall} ")

    final_fitness, final_violations = calculate_fitness(best_solution_overall, df_ruang_details, time_slots_list)
    return best_solution_overall, final_fitness, final_violations, fitness_history

# %% [markdown]
# # Run the ABC Algorithm

# %%
print("\n--- Menjalankan Artificial Bee Colony Optimization ---")
ABC_BEES = 50
ABC_ITERATIONS = 100
ABC_LIMIT = 50

abc_best_schedule, abc_fitness, abc_violations, abc_history = abc_optimizer(
    list_mk_unique, ruang_reguler, ruang_lab, time_slots, df_ruang, time_slots,
    n_bees=ABC_BEES, n_iterations=ABC_ITERATIONS, limit=ABC_LIMIT
)

print("\n--- Hasil ABC ---")
print(f"Skor Fitness Terbaik: {abc_fitness}")
print(f"Jumlah Pelanggaran Hard Constraint: {abc_violations}")
pd.DataFrame(abc_best_schedule).to_csv('jadwal_abc.csv', index=False)
print("Jadwal terbaik dari ABC disimpan sebagai 'jadwal_abc.csv'")
# Out:
# --- Menjalankan Artificial Bee Colony Optimization ---
# ABC Iteration 1/100 | Best Fitness: 20079
# ABC Iteration 2/100 | Best Fitness: 20077
# ABC Iteration 3/100 | Best Fitness: 20077
# ABC Iteration 4/100 | Best Fitness: 20071
# ABC Iteration 5/100 | Best Fitness: 20071
# ABC Iteration 6/100 | Best Fitness: 19996
# ABC Iteration 7/100 | Best Fitness: 19896
# ABC Iteration 8/100 | Best Fitness: 19782
# ABC Iteration 9/100 | Best Fitness: 19782
# ABC Iteration 10/100 | Best Fitness: 19782
# ABC Iteration 11/100 | Best Fitness: 19676
# ABC Iteration 12/100 | Best Fitness: 19493
# ABC Iteration 13/100 | Best Fitness: 19385
# ABC Iteration 14/100 | Best Fitness: 19385
# ABC Iteration 15/100 | Best Fitness: 19285
# ABC Iteration 16/100 | Best Fitness: 19083
# ABC Iteration 17/100 | Best Fitness: 18685
# ABC Iteration 18/100 | Best Fitness: 18685
# ABC Iteration 19/100 | Best Fitness: 18662
# ABC Iteration 20/100 | Best Fitness: 18662
# ABC Iteration 21/100 | Best Fitness: 18555
# ABC Iteration 22/100 | Best Fitness: 18555
# ABC Iteration 23/100 | Best Fitness: 18457
# ABC Iteration 24/100 | Best Fitness: 18285
# ABC Iteration 25/100 | Best Fitness: 18285
# ABC Iteration 26/100 | Best Fitness: 18285
# ABC Iteration 27/100 | Best Fitness: 18182
# ABC Iteration 28/100 | Best Fitness: 18182
# ABC Iteration 29/100 | Best Fitness: 18182
# ABC Iteration 30/100 | Best Fitness: 18060
# ABC Iteration 31/100 | Best Fitness: 18058
# ABC Iteration 32/100 | Best Fitness: 17958
# ABC Iteration 33/100 | Best Fitness: 17958
# ABC Iteration 34/100 | Best Fitness: 17899
# ABC Iteration 35/100 | Best Fitness: 17899
# ABC Iteration 36/100 | Best Fitness: 17899
# ABC Iteration 37/100 | Best Fitness: 17899
# ABC Iteration 38/100 | Best Fitness: 17899
# ABC Iteration 39/100 | Best Fitness: 17799
# ABC Iteration 40/100 | Best Fitness: 17799
# ABC Iteration 41/100 | Best Fitness: 17799
# ABC Iteration 42/100 | Best Fitness: 17799
# ABC Iteration 43/100 | Best Fitness: 17799
# ABC Iteration 44/100 | Best Fitness: 17799
# ABC Iteration 45/100 | Best Fitness: 17788
# ABC Iteration 46/100 | Best Fitness: 17788
# ABC Iteration 47/100 | Best Fitness: 17278
# ABC Iteration 48/100 | Best Fitness: 17178
# ABC Iteration 49/100 | Best Fitness: 17176
# ABC Iteration 50/100 | Best Fitness: 17176
# ABC Iteration 51/100 | Best Fitness: 17176
# ABC Iteration 52/100 | Best Fitness: 17176
# ABC Iteration 53/100 | Best Fitness: 17176
# ABC Iteration 54/100 | Best Fitness: 17176
# ABC Iteration 55/100 | Best Fitness: 17176
# ABC Iteration 56/100 | Best Fitness: 17176
# ABC Iteration 57/100 | Best Fitness: 17176
# ABC Iteration 58/100 | Best Fitness: 17076
# ABC Iteration 59/100 | Best Fitness: 17076
# ABC Iteration 60/100 | Best Fitness: 17068
# ABC Iteration 61/100 | Best Fitness: 16968
# ABC Iteration 62/100 | Best Fitness: 16960
# ABC Iteration 63/100 | Best Fitness: 16960
# ABC Iteration 64/100 | Best Fitness: 16860
# ABC Iteration 65/100 | Best Fitness: 16860
# ABC Iteration 66/100 | Best Fitness: 16860
# ABC Iteration 67/100 | Best Fitness: 16860
# ABC Iteration 68/100 | Best Fitness: 16860
# ABC Iteration 69/100 | Best Fitness: 16815
# ABC Iteration 70/100 | Best Fitness: 16813
# ABC Iteration 71/100 | Best Fitness: 16813
# ABC Iteration 72/100 | Best Fitness: 16813
# ABC Iteration 73/100 | Best Fitness: 16562
# ABC Iteration 74/100 | Best Fitness: 16562
# ABC Iteration 75/100 | Best Fitness: 16562
# ABC Iteration 76/100 | Best Fitness: 16562
# ABC Iteration 77/100 | Best Fitness: 16562
# ABC Iteration 78/100 | Best Fitness: 16456
# ABC Iteration 79/100 | Best Fitness: 16456
# ABC Iteration 80/100 | Best Fitness: 16456
# ABC Iteration 81/100 | Best Fitness: 16325
# ABC Iteration 82/100 | Best Fitness: 16323
# ABC Iteration 83/100 | Best Fitness: 16146
# ABC Iteration 84/100 | Best Fitness: 16123
# ABC Iteration 85/100 | Best Fitness: 16123
# ABC Iteration 86/100 | Best Fitness: 16123
# ABC Iteration 87/100 | Best Fitness: 16117
# ABC Iteration 88/100 | Best Fitness: 15904
# ABC Iteration 89/100 | Best Fitness: 15903
# ABC Iteration 90/100 | Best Fitness: 15903
# ABC Iteration 91/100 | Best Fitness: 15903
# ABC Iteration 92/100 | Best Fitness: 15903
# ABC Iteration 93/100 | Best Fitness: 15827
# ABC Iteration 94/100 | Best Fitness: 15827
# ABC Iteration 95/100 | Best Fitness: 15827
# ABC Iteration 96/100 | Best Fitness: 15727
# ABC Iteration 97/100 | Best Fitness: 15708
# ABC Iteration 98/100 | Best Fitness: 15708
# ABC Iteration 99/100 | Best Fitness: 15708
# ABC Iteration 100/100 | Best Fitness: 15700
#
# --- Hasil ABC ---
# Skor Fitness Terbaik: 15700
# Jumlah Pelanggaran Hard Constraint: 154
# Jadwal terbaik dari ABC disimpan sebagai 'jadwal_abc.csv'

# %% [markdown]
# # Puma Optimzer Algorithm

# %%
def poa_optimizer(courses, rooms_reg, rooms_lab, times, df_ruang_details, time_slots_list,
                  n_population=50, n_generations=100, mutation_rate=0.2):
    """Fungsi untuk menjalankan algoritma optimasi Puma."""
    
    # Inisialisasi Populasi
    population = [create_random_schedule(courses, rooms_reg, rooms_lab, times) for _ in range(n_population)]
    
    # Evaluasi populasi awal
    pop_fitness = [(ind, calculate_fitness(ind, df_ruang_details, time_slots_list)) for ind in population]
    
    # Simpan jejak fitness terbaik
    best_fitness_history = []

    for gen in range(n_generations):
        # Urutkan populasi berdasarkan fitness (terendah ke tertinggi)
        pop_fitness.sort(key=lambda x: x[1][0])
        
        # Ambil individu terbaik (Alpha Puma)
        best_individual = pop_fitness[0][0]
        best_fitness = pop_fitness[0][1][0]
        best_violations = pop_fitness[0][1][1]
        
        best_fitness_history.append(best_fitness)
        
        print(f"POA Generation {gen+1}/{n_generations} | Best Fitness: {best_fitness} | Hard Violations: {best_violations}")
        
        # Buat populasi baru
        new_population = [best_individual] # Elitisme: individu terbaik langsung masuk ke generasi baru
        
        # Update Populasi (Pergerakan Puma)
        for i in range(1, len(population)):
            current_individual = pop_fitness[i][0]
            new_individual = copy.deepcopy(current_individual)
            
            # 1. Bergerak ke arah Puma Alfa (Eksploitasi)
            for j in range(len(courses)):
                if random.random() < 0.7: # Probabilitas meniru puma alfa
                    new_individual[j] = best_individual[j]
            
            # 2. Mutasi (Eksplorasi/Lompatan Acak)
            if random.random() < mutation_rate:
                gene_to_mutate = random.randint(0, len(courses) - 1)
                
                # Pilih waktu atau ruang baru secara acak
                if random.random() < 0.5:
                     new_individual[gene_to_mutate]['waktu'] = random.choice(times)
                else:
                    course_type = new_individual[gene_to_mutate]['nama_mk']
                    if 'praktikum' in course_type.lower():
                        new_individual[gene_to_mutate]['ruang'] = random.choice(rooms_lab)
                    else:
                        new_individual[gene_to_mutate]['ruang'] = random.choice(rooms_reg)

            new_population.append(new_individual)
            
        population = new_population
        pop_fitness = [(ind, calculate_fitness(ind, df_ruang_details, time_slots_list)) for ind in population]
        
    # Kembalikan jadwal terbaik yang ditemukan
    final_best_individual = min(pop_fitness, key=lambda x: x[1][0])
    final_best_schedule = final_best_individual[0]
    final_fitness, final_violations = final_best_individual[1]
    
    return final_best_schedule, final_fitness, final_violations, best_fitness_history

# %% [markdown]
# # Run the POA Algorithm

# %%
print("\n--- Menjalankan Puma Optimization Algorithm ---")
POA_POPULATION = 50
POA_GENERATIONS = 100
POA_MUTATION_RATE = 0.2

poa_best_schedule, poa_fitness, poa_violations, poa_history = poa_optimizer(
    list_mk_unique, ruang_reguler, ruang_lab, time_slots, df_ruang, time_slots,
    n_population=POA_POPULATION, n_generations=POA_GENERATIONS, mutation_rate=POA_MUTATION_RATE
)

print("\n--- Hasil POA ---")
print(f"Skor Fitness Terbaik: {poa_fitness}")
print(f"Jumlah Pelanggaran Hard Constraint: {poa_violations}")
pd.DataFrame(poa_best_schedule).to_csv('jadwal_poa.csv', index=False)
print("Jadwal terbaik dari POA disimpan sebagai 'jadwal_poa.csv'")
# Out:
# --- Menjalankan Puma Optimization Algorithm ---
# POA Generation 1/100 | Best Fitness: 20906 | Hard Violations: 206
# POA Generation 2/100 | Best Fitness: 20076 | Hard Violations: 198
# POA Generation 3/100 | Best Fitness: 19204 | Hard Violations: 189
# POA Generation 4/100 | Best Fitness: 19239 | Hard Violations: 189
# POA Generation 5/100 | Best Fitness: 19107 | Hard Violations: 188
# POA Generation 6/100 | Best Fitness: 19196 | Hard Violations: 189
# POA Generation 7/100 | Best Fitness: 18994 | Hard Violations: 187
# POA Generation 8/100 | Best Fitness: 18796 | Hard Violations: 185
# POA Generation 9/100 | Best Fitness: 18596 | Hard Violations: 183
# POA Generation 10/100 | Best Fitness: 18696 | Hard Violations: 184
# POA Generation 11/100 | Best Fitness: 18696 | Hard Violations: 184
# POA Generation 12/100 | Best Fitness: 18791 | Hard Violations: 185
# POA Generation 13/100 | Best Fitness: 18687 | Hard Violations: 184
# POA Generation 14/100 | Best Fitness: 18687 | Hard Violations: 184
# POA Generation 15/100 | Best Fitness: 18585 | Hard Violations: 183
# POA Generation 16/100 | Best Fitness: 18648 | Hard Violations: 184
# POA Generation 17/100 | Best Fitness: 18548 | Hard Violations: 183
# POA Generation 18/100 | Best Fitness: 18547 | Hard Violations: 183
# POA Generation 19/100 | Best Fitness: 18541 | Hard Violations: 183
# POA Generation 20/100 | Best Fitness: 18541 | Hard Violations: 183
# POA Generation 21/100 | Best Fitness: 18445 | Hard Violations: 182
# POA Generation 22/100 | Best Fitness: 18537 | Hard Violations: 183
# POA Generation 23/100 | Best Fitness: 18342 | Hard Violations: 181
# POA Generation 24/100 | Best Fitness: 18392 | Hard Violations: 182
# POA Generation 25/100 | Best Fitness: 18198 | Hard Violations: 180
# POA Generation 26/100 | Best Fitness: 18234 | Hard Violations: 180
# POA Generation 27/100 | Best Fitness: 17889 | Hard Violations: 177
# POA Generation 28/100 | Best Fitness: 17985 | Hard Violations: 178
# POA Generation 29/100 | Best Fitness: 18187 | Hard Violations: 180
# POA Generation 30/100 | Best Fitness: 17789 | Hard Violations: 176
# POA Generation 31/100 | Best Fitness: 17686 | Hard Violations: 175
# POA Generation 32/100 | Best Fitness: 17689 | Hard Violations: 175
# POA Generation 33/100 | Best Fitness: 17789 | Hard Violations: 176
# POA Generation 34/100 | Best Fitness: 17791 | Hard Violations: 176
# POA Generation 35/100 | Best Fitness: 17797 | Hard Violations: 176
# POA Generation 36/100 | Best Fitness: 17792 | Hard Violations: 176
# POA Generation 37/100 | Best Fitness: 17690 | Hard Violations: 175
# POA Generation 38/100 | Best Fitness: 17690 | Hard Violations: 175
# POA Generation 39/100 | Best Fitness: 17498 | Hard Violations: 173
# POA Generation 40/100 | Best Fitness: 17223 | Hard Violations: 170
# POA Generation 41/100 | Best Fitness: 17223 | Hard Violations: 170
# POA Generation 42/100 | Best Fitness: 17223 | Hard Violations: 170
# POA Generation 43/100 | Best Fitness: 17223 | Hard Violations: 170
# POA Generation 44/100 | Best Fitness: 17257 | Hard Violations: 170
# POA Generation 45/100 | Best Fitness: 17231 | Hard Violations: 170
# POA Generation 46/100 | Best Fitness: 17031 | Hard Violations: 168
# POA Generation 47/100 | Best Fitness: 16955 | Hard Violations: 167
# POA Generation 48/100 | Best Fitness: 16927 | Hard Violations: 167
# POA Generation 49/100 | Best Fitness: 17033 | Hard Violations: 168
# POA Generation 50/100 | Best Fitness: 17433 | Hard Violations: 172
# POA Generation 51/100 | Best Fitness: 17431 | Hard Violations: 172
# POA Generation 52/100 | Best Fitness: 17531 | Hard Violations: 173
# POA Generation 53/100 | Best Fitness: 17251 | Hard Violations: 170
# POA Generation 54/100 | Best Fitness: 17129 | Hard Violations: 169
# POA Generation 55/100 | Best Fitness: 17122 | Hard Violations: 169
# POA Generation 56/100 | Best Fitness: 17116 | Hard Violations: 169
# POA Generation 57/100 | Best Fitness: 17116 | Hard Violations: 169
# POA Generation 58/100 | Best Fitness: 17129 | Hard Violations: 169
# POA Generation 59/100 | Best Fitness: 17032 | Hard Violations: 168
# POA Generation 60/100 | Best Fitness: 16940 | Hard Violations: 167
# POA Generation 61/100 | Best Fitness: 17133 | Hard Violations: 169
# POA Generation 62/100 | Best Fitness: 17231 | Hard Violations: 170
# POA Generation 63/100 | Best Fitness: 16933 | Hard Violations: 167
# POA Generation 64/100 | Best Fitness: 16899 | Hard Violations: 167
# POA Generation 65/100 | Best Fitness: 16997 | Hard Violations: 168
# POA Generation 66/100 | Best Fitness: 16999 | Hard Violations: 168
# POA Generation 67/100 | Best Fitness: 16999 | Hard Violations: 168
# POA Generation 68/100 | Best Fitness: 16897 | Hard Violations: 167
# POA Generation 69/100 | Best Fitness: 17002 | Hard Violations: 168
# POA Generation 70/100 | Best Fitness: 16995 | Hard Violations: 168
# POA Generation 71/100 | Best Fitness: 17043 | Hard Violations: 168
# POA Generation 72/100 | Best Fitness: 17025 | Hard Violations: 168
# POA Generation 73/100 | Best Fitness: 16832 | Hard Violations: 166
# POA Generation 74/100 | Best Fitness: 16940 | Hard Violations: 167
# POA Generation 75/100 | Best Fitness: 16866 | Hard Violations: 166
# POA Generation 76/100 | Best Fitness: 16840 | Hard Violations: 166
# POA Generation 77/100 | Best Fitness: 16820 | Hard Violations: 166
# POA Generation 78/100 | Best Fitness: 16940 | Hard Violations: 167
# POA Generation 79/100 | Best Fitness: 16820 | Hard Violations: 166
# POA Generation 80/100 | Best Fitness: 16818 | Hard Violations: 166
# POA Generation 81/100 | Best Fitness: 16918 | Hard Violations: 167
# POA Generation 82/100 | Best Fitness: 17118 | Hard Violations: 169
# POA Generation 83/100 | Best Fitness: 17118 | Hard Violations: 169
# POA Generation 84/100 | Best Fitness: 17020 | Hard Violations: 168
# POA Generation 85/100 | Best Fitness: 17022 | Hard Violations: 168
# POA Generation 86/100 | Best Fitness: 17254 | Hard Violations: 170
# POA Generation 87/100 | Best Fitness: 16952 | Hard Violations: 167
# POA Generation 88/100 | Best Fitness: 16950 | Hard Violations: 167
# POA Generation 89/100 | Best Fitness: 16752 | Hard Violations: 165
# POA Generation 90/100 | Best Fitness: 16828 | Hard Violations: 166
# POA Generation 91/100 | Best Fitness: 16728 | Hard Violations: 165
# POA Generation 92/100 | Best Fitness: 17028 | Hard Violations: 168
# POA Generation 93/100 | Best Fitness: 16828 | Hard Violations: 166
# POA Generation 94/100 | Best Fitness: 16821 | Hard Violations: 166
# POA Generation 95/100 | Best Fitness: 16717 | Hard Violations: 165
# POA Generation 96/100 | Best Fitness: 16916 | Hard Violations: 167
# POA Generation 97/100 | Best Fitness: 17010 | Hard Violations: 168
# POA Generation 98/100 | Best Fitness: 16782 | Hard Violations: 166
# POA Generation 99/100 | Best Fitness: 16588 | Hard Violations: 164
# POA Generation 100/100 | Best Fitness: 16488 | Hard Violations: 163
#
# --- Hasil POA ---
# Skor Fitness Terbaik: 16493
# Jumlah Pelanggaran Hard Constraint: 163
# Jadwal terbaik dari POA disimpan sebagai 'jadwal_poa.csv'

# %% [markdown]
# # Comparison between PSO, ACO, ABC, POA

# %%
print("\n--- PERBANDINGAN HASIL AKHIR ---")
results = {
    "Algorithm": ["PSO", "ACO", "ABC", "POA"],
    "Best Fitness Score": [pso_fitness, aco_fitness, abc_fitness, poa_fitness],
    "Hard Constraint Violations": [pso_violations, aco_violations, abc_violations, poa_violations]
}
df_results = pd.DataFrame(results)
print(df_results.to_string())

# Plotting Konvergensi
plt.figure(figsize=(14, 8))
plt.plot(pso_history, label="PSO", color="blue", linestyle='--')
plt.plot(aco_history, label="ACO", color="green", linestyle='-.')
plt.plot(abc_history, label="ABC", color="red", linestyle=':')
plt.plot(poa_history, label="POA", color="purple", linestyle='-')

plt.title("Perbandingan Konvergensi Algoritma Optimasi", fontsize=16)
plt.xlabel("Iterasi", fontsize=12)
plt.ylabel("Skor Fitness (Lebih Rendah Lebih Baik)", fontsize=12)
plt.legend()
plt.grid(True)
plt.savefig("convergence_comparison_3.png")
plt.show()

print("\nGrafik perbandingan konvergensi disimpan sebagai 'convergence_comparison.png'")
# Out:
# --- PERBANDINGAN HASIL AKHIR ---
#   Algorithm  Best Fitness Score  Hard Constraint Violations
# 0       PSO               20572                         202
# 1       ACO               19303                         190
# 2       ABC               15700                         154
# 3       POA               16493                         163
# Grafik perbandingan konvergensi disimpan sebagai 'convergence_comparison.png'
